# %%
# code to test if you can get the table from the site

import requests
from bs4 import BeautifulSoup

# URL of the webpage
url = "https://www.baseballmusings.com/cgi-bin/CurStreak.py"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the table in the HTML
    table = soup.find('table')
    
    # Extract table rows
    rows = table.find_all('tr')
    
    # Extract table data
    table_data = []
    for row in rows:
        cells = row.find_all(['td', 'th'])  # Include both header and data cells
        table_data.append([cell.get_text(strip=True) for cell in cells])
    
    # Print the table data
    for row in table_data:
        print(row)
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# ['Please help support the Day by Day Database with a donation during theBaseball Musings Pledge Drive.']
# ["Baseball Musings Day By Day Database, Current Hit StreaksThrough Games of 05/04/2025Or enter a Games Through Date:PlayerGamesAt BatsRunsHitsHRRBIBBKBAOBASlug%Last Game DateAaron Judge14571227411614.474.524.8252025-05-04J.P. Crawford124891831369.375.444.5832025-05-04CJ Abrams10437150618.349.404.5122025-05-04Zach Neto104251535111.357.372.6672025-05-04Freddie Freeman93381521065.455.538.7272025-05-04Gunnar Henderson9354131226.371.405.5432025-05-04Jeremy Pena8344131424.382.432.5292025-05-04Harrison Bader8286120235.429.484.5362025-05-04Victor Robles8373120206.324.342.4052025-04-06Alek Thomas8303110304.367.367.4672025-05-04Riley Greene7287134813.464.500.8932025-05-04Javier Baez72891231016.429.467.8932025-05-04Ryan Jeffers7274102844.370.452.7042025-05-04Hunter Goodman727291606.333.333.4442025-05-04Vladimir Guerrero Jr.728582628.286.323.5002025-05-04Gabriel Moreno726680326.308.379.3852025-05-04Ian Happ6246100234.417.481.5002025-05-04Dansby Swanson622693316.409.435.8182025-05-04Travis D'Arnaud620280026.400.455.6002025-05-03Luke Keaschall619470252.368.538.5262025-04-25PlayerGamesAt BatsRunsHitsHRRBIBBKBAOBASlug%Last Game DateMauricio Dubon621260500.286.286.2862025-05-04Ryan Bliss620161316.300.333.5002025-04-08Brooks Lee623161113.261.292.4782025-05-04Santiago Espinal5192100514.526.550.6322025-05-04Jake Meyers516392831.562.6321.1252025-05-04Jonny Deluca518490103.500.500.6112025-04-06Byron Buxton522181116.364.391.5002025-05-04Manny Machado519481336.421.500.6322025-05-04Trey Sweeney520382706.400.400.7002025-05-04Carson Kelly519381432.421.500.6322025-05-03Salvador Perez520180201.400.400.5502025-05-04Victor Scott516371535.438.526.6882025-05-04Spencer Steer519371324.368.429.5792025-05-04Jackson Holliday515472301.467.467.8672025-05-04Brendan Donovan517460331.353.476.3532025-05-04Isaac Paredes518350142.278.409.3892025-05-03The information used here was obtained free of charge from and is copyrighted by Retrosheet.  Interested parties may contactRetrosheetat 20 Sunset Rd., Newark, DE 19711. Newer data was purchased fromBaseball Info Solutions.", 'Player', 'Games', 'At Bats', 'Runs', 'Hits', 'HR', 'RBI', 'BB', 'K', 'BA', 'OBA', 'Slug%', 'Last Game Date', 'Aaron Judge', '14', '57', '12', '27', '4', '11', '6', '14', '.474', '.524', '.825', '2025-05-04', 'J.P. Crawford', '12', '48', '9', '18', '3', '13', '6', '9', '.375', '.444', '.583', '2025-05-04', 'CJ Abrams', '10', '43', '7', '15', '0', '6', '1', '8', '.349', '.404', '.512', '2025-05-04', 'Zach Neto', '10', '42', '5', '15', '3', '5', '1', '11', '.357', '.372', '.667', '2025-05-04', 'Freddie Freeman', '9', '33', '8', '15', '2', '10', '6', '5', '.455', '.538', '.727', '2025-05-04', 'Gunnar Henderson', '9', '35', '4', '13', '1', '2', '2', '6', '.371', '.405', '.543', '2025-05-04', 'Jeremy Pena', '8', '34', '4', '13', '1', '4', '2', '4', '.382', '.432', '.529', '2025-05-04', 'Harrison Bader', '8', '28', '6', '12', '0', '2', '3', '5', '.429', '.484', '.536', '2025-05-04', 'Victor Robles', '8', '37', '3', '12', '0', '2', '0', '6', '.324', '.342', '.405', '2025-04-06', 'Alek Thomas', '8', '30', '3', '11', '0', '3', '0', '4', '.367', '.367', '.467', '2025-05-04', 'Riley Greene', '7', '28', '7', '13', '4', '8', '1', '3', '.464', '.500', '.893', '2025-05-04', 'Javier Baez', '7', '28', '9', '12', '3', '10', '1', '6', '.429', '.467', '.893', '2025-05-04', 'Ryan Jeffers', '7', '27', '4', '10', '2', '8', '4', '4', '.370', '.452', '.704', '2025-05-04', 'Hunter Goodman', '7', '27', '2', '9', '1', '6', '0', '6', '.333', '.333', '.444', '2025-05-04', 'Vladimir Guerrero Jr.', '7', '28', '5', '8', '2', '6', '2', '8', '.286', '.323', '.500', '2025-05-04', 'Gabriel Moreno', '7', '26', '6', '8', '0', '3', '2', '6', '.308', '.379', '.385', '2025-05-04', 'Ian Happ', '6', '24', '6', '10', '0', '2', '3', '4', '.417', '.481', '.500', '2025-05-04', 'Dansby Swanson', '6', '22', '6', '9', '3', '3', '1', '6', '.409', '.435', '.818', '2025-05-04', "Travis D'Arnaud", '6', '20', '2', '8', '0', '0', '2', '6', '.400', '.455', '.60 ...
# ['Player', 'Games', 'At Bats', 'Runs', 'Hits', 'HR', 'RBI', 'BB', 'K', 'BA', 'OBA', 'Slug%', 'Last Game Date']
# ['Aaron Judge', '14', '57', '12', '27', '4', '11', '6', '14', '.474', '.524', '.825', '2025-05-04']
# ['J.P. Crawford', '12', '48', '9', '18', '3', '13', '6', '9', '.375', '.444', '.583', '2025-05-04']
# ['CJ Abrams', '10', '43', '7', '15', '0', '6', '1', '8', '.349', '.404', '.512', '2025-05-04']
# ['Zach Neto', '10', '42', '5', '15', '3', '5', '1', '11', '.357', '.372', '.667', '2025-05-04']
# ['Freddie Freeman', '9', '33', '8', '15', '2', '10', '6', '5', '.455', '.538', '.727', '2025-05-04']
# ['Gunnar Henderson', '9', '35', '4', '13', '1', '2', '2', '6', '.371', '.405', '.543', '2025-05-04']
# ['Jeremy Pena', '8', '34', '4', '13', '1', '4', '2', '4', '.382', '.432', '.529', '2025-05-04']
# ['Harrison Bader', '8', '28', '6', '12', '0', '2', '3', '5', '.429', '.484', '.536', '2025-05-04']
# ['Victor Robles', '8', '37', '3', '12', '0', '2', '0', '6', '.324', '.342', '.405', '2025-04-06']
# ['Alek Thomas', '8', '30', '3', '11', '0', '3', '0', '4', '.367', '.367', '.467', '2025-05-04']
# ['Riley Greene', '7', '28', '7', '13', '4', '8', '1', '3', '.464', '.500', '.893', '2025-05-04']
# ['Javier Baez', '7', '28', '9', '12', '3', '10', '1', '6', '.429', '.467', '.893', '2025-05-04']
# ['Ryan Jeffers', '7', '27', '4', '10', '2', '8', '4', '4', '.370', '.452', '.704', '2025-05-04']
# ['Hunter Goodman', '7', '27', '2', '9', '1', '6', '0', '6', '.333', '.333', '.444', '2025-05-04']
# ['Vladimir Guerrero Jr.', '7', '28', '5', '8', '2', '6', '2', '8', '.286', '.323', '.500', '2025-05-04']
# ['Gabriel Moreno', '7', '26', '6', '8', '0', '3', '2', '6', '.308', '.379', '.385', '2025-05-04']
# ['Ian Happ', '6', '24', '6', '10', '0', '2', '3', '4', '.417', '.481', '.500', '2025-05-04']
# ['Dansby Swanson', '6', '22', '6', '9', '3', '3', '1', '6', '.409', '.435', '.818', '2025-05-04']
# ["Travis D'Arnaud", '6', '20', '2', '8', '0', '0', '2', '6', '.400', '.455', '.600', '2025-05-03']
# ['Luke Keaschall', '6', '19', '4', '7', '0', '2', '5', '2', '.368', '.538', '.526', '2025-04-25']
# ['Player', 'Games', 'At Bats', 'Runs', 'Hits', 'HR', 'RBI', 'BB', 'K', 'BA', 'OBA', 'Slug%', 'Last Game Date']
# ['Mauricio Dubon', '6', '21', '2', '6', '0', '5', '0', '0', '.286', '.286', '.286', '2025-05-04']
# ['Ryan Bliss', '6', '20', '1', '6', '1', '3', '1', '6', '.300', '.333', '.500', '2025-04-08']
# ['Brooks Lee', '6', '23', '1', '6', '1', '1', '1', '3', '.261', '.292', '.478', '2025-05-04']
# ['Santiago Espinal', '5', '19', '2', '10', '0', '5', '1', '4', '.526', '.550', '.632', '2025-05-04']
# ['Jake Meyers', '5', '16', '3', '9', '2', '8', '3', '1', '.562', '.632', '1.125', '2025-05-04']
# ['Jonny Deluca', '5', '18', '4', '9', '0', '1', '0', '3', '.500', '.500', '.611', '2025-04-06']
# ['Byron Buxton', '5', '22', '1', '8', '1', '1', '1', '6', '.364', '.391', '.500', '2025-05-04']
# ['Manny Machado', '5', '19', '4', '8', '1', '3', '3', '6', '.421', '.500', '.632', '2025-05-04']
# ['Trey Sweeney', '5', '20', '3', '8', '2', '7', '0', '6', '.400', '.400', '.700', '2025-05-04']
# ['Carson Kelly', '5', '19', '3', '8', '1', '4', '3', '2', '.421', '.500', '.632', '2025-05-03']
# ['Salvador Perez', '5', '20', '1', '8', '0', '2', '0', '1', '.400', '.400', '.550', '2025-05-04']
# ['Victor Scott', '5', '16', '3', '7', '1', '5', '3', '5', '.438', '.526', '.688', '2025-05-04']
# ['Spencer Steer', '5', '19', '3', '7', '1', '3', '2', '4', '.368', '.429', '.579', '2025-05-04']
# ['Jackson Holliday', '5', '15', '4', '7', '2', '3', '0', '1', '.467', '.467', '.867', '2025-05-04']
# ['Brendan Donovan', '5', '17', '4', '6', '0', '3', '3', '1', '.353', '.476', '.353', '2025-05-04']
# ['Isaac Paredes', '5', '18', '3', '5', '0', '1', '4', '2', '.278', '.409', '.389', '2025-05-03']

# %%
# test to see that if i want i can transform it into a dictionary

# Extract the keys from the first row of the data
keys = table_data[2]

# Convert the remaining rows into dictionaries
data_as_dicts = [dict(zip(keys, row)) for row in table_data[3:]]

# Print the resulting list of dictionaries
for item in data_as_dicts:
    print(item)
# Out:
# {'Player': 'Bobby Witt Jr.', 'Games': '21', 'At Bats': '77', 'Runs': '13', 'Hits': '28', 'HR': '1', 'RBI': '7', 'BB': '9', 'K': '12', 'BA': '.364', 'OBA': '.427', 'Slug%': '.519', 'Last Game Date': '2025-04-30'}
# {'Player': 'Elly De La Cruz', 'Games': '14', 'At Bats': '54', 'Runs': '10', 'Hits': '19', 'HR': '2', 'RBI': '6', 'BB': '7', 'K': '17', 'BA': '.352', 'OBA': '.429', 'Slug%': '.481', 'Last Game Date': '2025-04-30'}
# {'Player': 'Aaron Judge', 'Games': '11', 'At Bats': '44', 'Runs': '9', 'Hits': '22', 'HR': '3', 'RBI': '10', 'BB': '6', 'K': '11', 'BA': '.500', 'OBA': '.560', 'Slug%': '.795', 'Last Game Date': '2025-04-30'}
# {'Player': 'Alex Bregman', 'Games': '10', 'At Bats': '40', 'Runs': '10', 'Hits': '16', 'HR': '3', 'RBI': '8', 'BB': '5', 'K': '7', 'BA': '.400', 'OBA': '.489', 'Slug%': '.725', 'Last Game Date': '2025-04-30'}
# {'Player': 'Zach McKinstry', 'Games': '10', 'At Bats': '38', 'Runs': '4', 'Hits': '16', 'HR': '0', 'RBI': '5', 'BB': '4', 'K': '14', 'BA': '.421', 'OBA': '.465', 'Slug%': '.605', 'Last Game Date': '2025-04-30'}
# {'Player': "Ke'Bryan Hayes", 'Games': '10', 'At Bats': '39', 'Runs': '0', 'Hits': '13', 'HR': '0', 'RBI': '5', 'BB': '1', 'K': '8', 'BA': '.333', 'OBA': '.381', 'Slug%': '.359', 'Last Game Date': '2025-04-30'}
# {'Player': 'Teoscar Hernandez', 'Games': '9', 'At Bats': '40', 'Runs': '10', 'Hits': '17', 'HR': '4', 'RBI': '15', 'BB': '0', 'K': '4', 'BA': '.425', 'OBA': '.425', 'Slug%': '.875', 'Last Game Date': '2025-04-30'}
# {'Player': 'J.P. Crawford', 'Games': '9', 'At Bats': '33', 'Runs': '8', 'Hits': '14', 'HR': '2', 'RBI': '10', 'BB': '6', 'K': '7', 'BA': '.424', 'OBA': '.513', 'Slug%': '.606', 'Last Game Date': '2025-04-30'}
# {'Player': 'William Contreras', 'Games': '9', 'At Bats': '33', 'Runs': '6', 'Hits': '11', 'HR': '0', 'RBI': '6', 'BB': '9', 'K': '5', 'BA': '.333', 'OBA': '.476', 'Slug%': '.333', 'Last Game Date': '2025-04-30'}
# {'Player': 'Andy Pages', 'Games': '8', 'At Bats': '33', 'Runs': '9', 'Hits': '18', 'HR': '4', 'RBI': '9', 'BB': '2', 'K': '4', 'BA': '.545', 'OBA': '.571', 'Slug%': '1.000', 'Last Game Date': '2025-04-30'}
# {'Player': 'Victor Robles', 'Games': '8', 'At Bats': '37', 'Runs': '3', 'Hits': '12', 'HR': '0', 'RBI': '2', 'BB': '0', 'K': '6', 'BA': '.324', 'OBA': '.342', 'Slug%': '.405', 'Last Game Date': '2025-04-06'}
# {'Player': 'Eli White', 'Games': '8', 'At Bats': '31', 'Runs': '11', 'Hits': '12', 'HR': '2', 'RBI': '7', 'BB': '2', 'K': '5', 'BA': '.387', 'OBA': '.424', 'Slug%': '.774', 'Last Game Date': '2025-04-30'}
# {'Player': 'Josh Jung', 'Games': '8', 'At Bats': '28', 'Runs': '2', 'Hits': '10', 'HR': '1', 'RBI': '2', 'BB': '3', 'K': '5', 'BA': '.357', 'OBA': '.419', 'Slug%': '.500', 'Last Game Date': '2025-04-30'}
# {'Player': 'Miguel Vargas', 'Games': '7', 'At Bats': '26', 'Runs': '4', 'Hits': '12', 'HR': '1', 'RBI': '3', 'BB': '3', 'K': '2', 'BA': '.462', 'OBA': '.517', 'Slug%': '.615', 'Last Game Date': '2025-04-30'}
# {'Player': 'Jonah Heim', 'Games': '7', 'At Bats': '28', 'Runs': '4', 'Hits': '9', 'HR': '1', 'RBI': '2', 'BB': '2', 'K': '7', 'BA': '.321', 'OBA': '.367', 'Slug%': '.464', 'Last Game Date': '2025-04-30'}
# {'Player': 'Jung Hoo Lee', 'Games': '7', 'At Bats': '27', 'Runs': '3', 'Hits': '9', 'HR': '0', 'RBI': '3', 'BB': '2', 'K': '3', 'BA': '.333', 'OBA': '.379', 'Slug%': '.370', 'Last Game Date': '2025-04-30'}
# {'Player': 'Zach Neto', 'Games': '6', 'At Bats': '25', 'Runs': '3', 'Hits': '10', 'HR': '2', 'RBI': '3', 'BB': '1', 'K': '5', 'BA': '.400', 'OBA': '.423', 'Slug%': '.760', 'Last Game Date': '2025-04-30'}
# {'Player': 'CJ Abrams', 'Games': '6', 'At Bats': '26', 'Runs': '3', 'Hits': '10', 'HR': '0', 'RBI': '4', 'BB': '0', 'K': '5', 'BA': '.385', 'OBA': '.407', 'Slug%': '.577', 'Last Game Date': '2025-04-30'}
# {'Player': 'Alex Verdugo', 'Games': '6', 'At Bats': '27', 'Runs': '3', 'Hits': '10', 'HR': '0', 'RBI': '5', 'BB': '3', 'K': '1', 'BA': '.370', 'OBA': '.433', 'Slug%': '.481', 'Last Game Date': '2025-04-29'}
# {'Player': 'Freddie Freeman', 'Games': '6', 'At Bats': '21', 'Runs': '6', 'Hits': '10', 'HR': '1', 'RBI': '6', 'BB': '5', 'K': '3', 'BA': '.476', 'OBA': '.577', 'Slug%': '.762', 'Last Game Date': '2025-04-30'}
# {'Player': 'Player', 'Games': 'Games', 'At Bats': 'At Bats', 'Runs': 'Runs', 'Hits': 'Hits', 'HR': 'HR', 'RBI': 'RBI', 'BB': 'BB', 'K': 'K', 'BA': 'BA', 'OBA': 'OBA', 'Slug%': 'Slug%', 'Last Game Date': 'Last Game Date'}
# {'Player': 'Anthony Volpe', 'Games': '6', 'At Bats': '23', 'Runs': '4', 'Hits': '9', 'HR': '1', 'RBI': '4', 'BB': '2', 'K': '4', 'BA': '.391', 'OBA': '.462', 'Slug%': '.739', 'Last Game Date': '2025-04-30'}
# {'Player': 'Austin Wells', 'Games': '6', 'At Bats': '27', 'Runs': '2', 'Hits': '8', 'HR': '1', 'RBI': '7', 'BB': '0', 'K': '6', 'BA': '.296', 'OBA': '.286', 'Slug%': '.556', 'Last Game Date': '2025-04-30'}
# {'Player': 'Luke Keaschall', 'Games': '6', 'At Bats': '19', 'Runs': '4', 'Hits': '7', 'HR': '0', 'RBI': '2', 'BB': '5', 'K': '2', 'BA': '.368', 'OBA': '.538', 'Slug%': '.526', 'Last Game Date': '2025-04-25'}
# {'Player': 'Gunnar Henderson', 'Games': '6', 'At Bats': '23', 'Runs': '3', 'Hits': '7', 'HR': '1', 'RBI': '2', 'BB': '1', 'K': '4', 'BA': '.304', 'OBA': '.333', 'Slug%': '.522', 'Last Game Date': '2025-04-30'}
# {'Player': 'Ryan Bliss', 'Games': '6', 'At Bats': '20', 'Runs': '1', 'Hits': '6', 'HR': '1', 'RBI': '3', 'BB': '1', 'K': '6', 'BA': '.300', 'OBA': '.333', 'Slug%': '.500', 'Last Game Date': '2025-04-08'}
# {'Player': 'Jeremy Pena', 'Games': '5', 'At Bats': '20', 'Runs': '4', 'Hits': '9', 'HR': '1', 'RBI': '4', 'BB': '2', 'K': '4', 'BA': '.450', 'OBA': '.522', 'Slug%': '.700', 'Last Game Date': '2025-04-30'}
# {'Player': 'Jonny Deluca', 'Games': '5', 'At Bats': '18', 'Runs': '4', 'Hits': '9', 'HR': '0', 'RBI': '1', 'BB': '0', 'K': '3', 'BA': '.500', 'OBA': '.500', 'Slug%': '.611', 'Last Game Date': '2025-04-06'}
# {'Player': 'Ty France', 'Games': '5', 'At Bats': '20', 'Runs': '4', 'Hits': '9', 'HR': '1', 'RBI': '6', 'BB': '0', 'K': '2', 'BA': '.450', 'OBA': '.429', 'Slug%': '.750', 'Last Game Date': '2025-04-30'}
# {'Player': 'Shohei Ohtani', 'Games': '5', 'At Bats': '19', 'Runs': '9', 'Hits': '8', 'HR': '1', 'RBI': '2', 'BB': '6', 'K': '6', 'BA': '.421', 'OBA': '.560', 'Slug%': '.947', 'Last Game Date': '2025-04-30'}
# {'Player': 'Rafael Devers', 'Games': '5', 'At Bats': '22', 'Runs': '7', 'Hits': '8', 'HR': '3', 'RBI': '5', 'BB': '3', 'K': '4', 'BA': '.364', 'OBA': '.462', 'Slug%': '.909', 'Last Game Date': '2025-04-30'}
# {'Player': 'Marcus Semien', 'Games': '5', 'At Bats': '18', 'Runs': '3', 'Hits': '7', 'HR': '0', 'RBI': '3', 'BB': '3', 'K': '5', 'BA': '.389', 'OBA': '.476', 'Slug%': '.389', 'Last Game Date': '2025-04-30'}
# {'Player': 'Jose Trevino', 'Games': '5', 'At Bats': '17', 'Runs': '4', 'Hits': '7', 'HR': '1', 'RBI': '1', 'BB': '1', 'K': '2', 'BA': '.412', 'OBA': '.444', 'Slug%': '.647', 'Last Game Date': '2025-04-30'}
# {'Player': 'Miguel Rojas', 'Games': '5', 'At Bats': '10', 'Runs': '2', 'Hits': '7', 'HR': '0', 'RBI': '2', 'BB': '0', 'K': '2', 'BA': '.700', 'OBA': '.700', 'Slug%': '.900', 'Last Game Date': '2025-04-30'}
# {'Player': 'Luis Robert', 'Games': '5', 'At Bats': '20', 'Runs': '6', 'Hits': '6', 'HR': '2', 'RBI': '3', 'BB': '4', 'K': '7', 'BA': '.300', 'OBA': '.417', 'Slug%': '.600', 'Last Game Date': '2025-04-30'}
# {'Player': 'Gabriel Moreno', 'Games': '5', 'At Bats': '18', 'Runs': '4', 'Hits': '5', 'HR': '0', 'RBI': '3', 'BB': '2', 'K': '4', 'BA': '.278', 'OBA': '.350', 'Slug%': '.333', 'Last Game Date': '2025-04-30'}
# {'Player': 'Christian Koss', 'Games': '5', 'At Bats': '17', 'Runs': '3', 'Hits': '5', 'HR': '0', 'RBI': '1', 'BB': '0', 'K': '6', 'BA': '.294', 'OBA': '.333', 'Slug%': '.294', 'Last Game Date': '2025-04-27'}
# {'Player': 'Isaac Collins', 'Games': '5', 'At Bats': '12', 'Runs': '5', 'Hits': '5', 'HR': '1', 'RBI': '2', 'BB': '2', 'K': '2', 'BA': '.417', 'OBA': '.533', 'Slug%': '.750', 'Last Game Date': '2025-04-30'}
# {'Player': 'Nicholas Kurtz', 'Games': '5', 'At Bats': '18', 'Runs': '0', 'Hits': '5', 'HR': '0', 'RBI': '2', 'BB': '0', 'K': '10', 'BA': '.278', 'OBA': '.263', 'Slug%': '.278', 'Last Game Date': '2025-04-30'}
# {'Player': 'Cal Raleigh', 'Games': '5', 'At Bats': '17', 'Runs': '5', 'Hits': '5', 'HR': '1', 'RBI': '2', 'BB': '4', 'K': '3', 'BA': '.294', 'OBA': '.429', 'Slug%': '.529', 'Last Game Date': '2025-04-30'}
# {'Player': 'Mauricio Dubon', 'Games': '5', 'At Bats': '18', 'Runs': '2', 'Hits': '5', 'HR': '0', 'RBI': '3', 'BB': '0', 'K': '0', 'BA': '.278', 'OBA': '.278', 'Slug%': '.278', 'Last Game Date': '2025-04-30'}
# {'Player': 'Player', 'Games': 'Games', 'At Bats': 'At Bats', 'Runs': 'Runs', 'Hits': 'Hits', 'HR': 'HR', 'RBI': 'RBI', 'BB': 'BB', 'K': 'K', 'BA': 'BA', 'OBA': 'OBA', 'Slug%': 'Slug%', 'Last Game Date': 'Last Game Date'}

# %%
# this gets the table but keeps the html for it intact

import requests
from bs4 import BeautifulSoup

# URL of the webpage
url = "https://www.baseballmusings.com/cgi-bin/CurStreak.py"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the table in the HTML
    table = soup.find('table')
    
    # Convert the table to an HTML string
    if table:
        table_html = str(table)
        print(table_html)
    else:
        print("No table found on the page.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# <table><tr><td align="center" colspan="2" valign="top">
# <!-- SMG_BaseballMusings/728x90_1a/sports/baseball/mlb.general -->
# <!--
# <div id="usmg_ad_mlb.general_baseball_sports_728x90_1a">
# <script type='text/javascript'>
# googletag.defineSlot('/7103/SMG_BaseballMusings/728x90_1a/sports/baseball/mlb.general', [728,90], 'usmg_ad_mlb.general_baseball_sports_728x90_1a').addService(googletag.pubads());
# googletag.enableServices();
# googletag.display('usmg_ad_mlb.general_baseball_sports_728x90_1a');
# </script>
# </div>
# -->
# <h3>Please help support the Day by Day Database with a donation during the <a href="https://www.baseballmusings.com/?p=155911" target="_blank">Baseball Musings Pledge Drive</a>.</h3>
# </td></tr>
# <tr><td valign="top">
# <h1>Baseball Musings Day By Day Database, Current Hit Streaks</h1>
# <h2>Through Games of 05/04/2025</h2>
# <form action="https://www.baseballmusings.com/cgi-bin/CurStreak.py" method="get" name="StreakDate">
# <br/>Or enter a Games Through Date: <input name="EndDate" type"text"="" value="05/04/2025"/>
# <br/><input type="submit" value="Submit"/></form><br/>
# <table border="4" class="dbd">
# <tr class="toprow"><th class="letter">Player</th><th class="number">Games</th><th class="number">At Bats</th><th class="number">Runs</th> <th class="number">Hits</th> <th class="number">HR</th><th class="number">RBI</th><th class="number">BB</th><th class="number">K</th><th class="number">BA</th><th class="number">OBA</th><th class="number">Slug%</th><th class="number">Last Game Date</th></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=15640&amp;StartDate=04%2F19%2F2025&amp;EndDate=05%2F04%2F2025">Aaron Judge</a>
# </td><td class="number">14</td><td class="number">57</td><td class="number">12</td><td class="number">27</td>
# <td class="number">4</td> <td class="number">11</td><td class="number">6</td><td class="number">14</td>
# <td class="number">.474</td>
# <td class="number">.524</td>
# <td class="number">.825</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=15491&amp;StartDate=04%2F19%2F2025&amp;EndDate=05%2F04%2F2025">J.P. Crawford</a>
# </td><td class="number">12</td><td class="number">48</td><td class="number">9</td><td class="number">18</td>
# <td class="number">3</td> <td class="number">13</td><td class="number">6</td><td class="number">9</td>
# <td class="number">.375</td>
# <td class="number">.444</td>
# <td class="number">.583</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=25768&amp;StartDate=04%2F25%2F2025&amp;EndDate=05%2F04%2F2025">CJ Abrams</a>
# </td><td class="number">10</td><td class="number">43</td><td class="number">7</td><td class="number">15</td>
# <td class="number">0</td> <td class="number">6</td><td class="number">1</td><td class="number">8</td>
# <td class="number">.349</td>
# <td class="number">.404</td>
# <td class="number">.512</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=31347&amp;StartDate=04%2F24%2F2025&amp;EndDate=05%2F04%2F2025">Zach Neto</a>
# </td><td class="number">10</td><td class="number">42</td><td class="number">5</td><td class="number">15</td>
# <td class="number">3</td> <td class="number">5</td><td class="number">1</td><td class="number">11</td>
# <td class="number">.357</td>
# <td class="number">.372</td>
# <td class="number">.667</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=5361&amp;StartDate=04%2F25%2F2025&amp;EndDate=05%2F04%2F2025">Freddie Freeman</a>
# </td><td class="number">9</td><td class="number">33</td><td class="number">8</td><td class="number">15</td>
# <td class="number">2</td> <td class="number">10</td><td class="number">6</td><td class="number">5</td>
# <td class="number">.455</td>
# <td class="number">.538</td>
# <td class="number">.727</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=26289&amp;StartDate=04%2F26%2F2025&amp;EndDate=05%2F04%2F2025">Gunnar Henderson</a>
# </td><td class="number">9</td><td class="number">35</td><td class="number">4</td><td class="number">13</td>
# <td class="number">1</td> <td class="number">2</td><td class="number">2</td><td class="number">6</td>
# <td class="number">.371</td>
# <td class="number">.405</td>
# <td class="number">.543</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=21636&amp;StartDate=04%2F26%2F2025&amp;EndDate=05%2F04%2F2025">Jeremy Pena</a>
# </td><td class="number">8</td><td class="number">34</td><td class="number">4</td><td class="number">13</td>
# <td class="number">1</td> <td class="number">4</td><td class="number">2</td><td class="number">4</td>
# <td class="number">.382</td>
# <td class="number">.432</td>
# <td class="number">.529</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=18030&amp;StartDate=04%2F26%2F2025&amp;EndDate=05%2F04%2F2025">Harrison Bader</a>
# </td><td class="number">8</td><td class="number">28</td><td class="number">6</td><td class="number">12</td>
# <td class="number">0</td> <td class="number">2</td><td class="number">3</td><td class="number">5</td>
# <td class="number">.429</td>
# <td class="number">.484</td>
# <td class="number">.536</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=18363&amp;StartDate=03%2F29%2F2025&amp;EndDate=04%2F06%2F2025">Victor Robles</a>
# </td><td class="number">8</td><td class="number">37</td><td class="number">3</td><td class="number">12</td>
# <td class="number">0</td> <td class="number">2</td><td class="number">0</td><td class="number">6</td>
# <td class="number">.324</td>
# <td class="number">.342</td>
# <td class="number">.405</td><td class="number">2025-04-06</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=23792&amp;StartDate=04%2F23%2F2025&amp;EndDate=05%2F04%2F2025">Alek Thomas</a>
# </td><td class="number">8</td><td class="number">30</td><td class="number">3</td><td class="number">11</td>
# <td class="number">0</td> <td class="number">3</td><td class="number">0</td><td class="number">4</td>
# <td class="number">.367</td>
# <td class="number">.367</td>
# <td class="number">.467</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=25976&amp;StartDate=04%2F28%2F2025&amp;EndDate=05%2F04%2F2025">Riley Greene</a>
# </td><td class="number">7</td><td class="number">28</td><td class="number">7</td><td class="number">13</td>
# <td class="number">4</td> <td class="number">8</td><td class="number">1</td><td class="number">3</td>
# <td class="number">.464</td>
# <td class="number">.500</td>
# <td class="number">.893</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=12979&amp;StartDate=04%2F26%2F2025&amp;EndDate=05%2F04%2F2025">Javier Baez</a>
# </td><td class="number">7</td><td class="number">28</td><td class="number">9</td><td class="number">12</td>
# <td class="number">3</td> <td class="number">10</td><td class="number">1</td><td class="number">6</td>
# <td class="number">.429</td>
# <td class="number">.467</td>
# <td class="number">.893</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=24618&amp;StartDate=04%2F26%2F2025&amp;EndDate=05%2F04%2F2025">Ryan Jeffers</a>
# </td><td class="number">7</td><td class="number">27</td><td class="number">4</td><td class="number">10</td>
# <td class="number">2</td> <td class="number">8</td><td class="number">4</td><td class="number">4</td>
# <td class="number">.370</td>
# <td class="number">.452</td>
# <td class="number">.704</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=29715&amp;StartDate=04%2F28%2F2025&amp;EndDate=05%2F04%2F2025">Hunter Goodman</a>
# </td><td class="number">7</td><td class="number">27</td><td class="number">2</td><td class="number">9</td>
# <td class="number">1</td> <td class="number">6</td><td class="number">0</td><td class="number">6</td>
# <td class="number">.333</td>
# <td class="number">.333</td>
# <td class="number">.444</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=19611&amp;StartDate=04%2F27%2F2025&amp;EndDate=05%2F04%2F2025">Vladimir Guerrero Jr.</a>
# </td><td class="number">7</td><td class="number">28</td><td class="number">5</td><td class="number">8</td>
# <td class="number">2</td> <td class="number">6</td><td class="number">2</td><td class="number">8</td>
# <td class="number">.286</td>
# <td class="number">.323</td>
# <td class="number">.500</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=22664&amp;StartDate=04%2F24%2F2025&amp;EndDate=05%2F04%2F2025">Gabriel Moreno</a>
# </td><td class="number">7</td><td class="number">26</td><td class="number">6</td><td class="number">8</td>
# <td class="number">0</td> <td class="number">3</td><td class="number">2</td><td class="number">6</td>
# <td class="number">.308</td>
# <td class="number">.379</td>
# <td class="number">.385</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=17919&amp;StartDate=04%2F29%2F2025&amp;EndDate=05%2F04%2F2025">Ian Happ</a>
# </td><td class="number">6</td><td class="number">24</td><td class="number">6</td><td class="number">10</td>
# <td class="number">0</td> <td class="number">2</td><td class="number">3</td><td class="number">4</td>
# <td class="number">.417</td>
# <td class="number">.481</td>
# <td class="number">.500</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=18314&amp;StartDate=04%2F29%2F2025&amp;EndDate=05%2F04%2F2025">Dansby Swanson</a>
# </td><td class="number">6</td><td class="number">22</td><td class="number">6</td><td class="number">9</td>
# <td class="number">3</td> <td class="number">3</td><td class="number">1</td><td class="number">6</td>
# <td class="number">.409</td>
# <td class="number">.435</td>
# <td class="number">.818</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=7739&amp;StartDate=04%2F16%2F2025&amp;EndDate=05%2F03%2F2025">Travis D'Arnaud</a>
# </td><td class="number">6</td><td class="number">20</td><td class="number">2</td><td class="number">8</td>
# <td class="number">0</td> <td class="number">0</td><td class="number">2</td><td class="number">6</td>
# <td class="number">.400</td>
# <td class="number">.455</td>
# <td class="number">.600</td><td class="number">2025-05-03</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=33321&amp;StartDate=04%2F18%2F2025&amp;EndDate=04%2F25%2F2025">Luke Keaschall</a>
# </td><td class="number">6</td><td class="number">19</td><td class="number">4</td><td class="number">7</td>
# <td class="number">0</td> <td class="number">2</td><td class="number">5</td><td class="number">2</td>
# <td class="number">.368</td>
# <td class="number">.538</td>
# <td class="number">.526</td><td class="number">2025-04-25</td></tr>
# <tr class="toprow"><th class="letter">Player</th><th class="number">Games</th><th class="number">At Bats</th><th class="number">Runs</th> <th class="number">Hits</th> <th class="number">HR</th><th class="number">RBI</th><th class="number">BB</th><th class="number">K</th><th class="number">BA</th><th class="number">OBA</th><th class="number">Slug%</th><th class="number">Last Game Date</th></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=29547&amp;StartDate=04%2F02%2F2025&amp;EndDate=04%2F08%2F2025">Ryan Bliss</a>
# </td><td class="number">6</td><td class="number">20</td><td class="number">1</td><td class="number">6</td>
# <td class="number">1</td> <td class="number">3</td><td class="number">1</td><td class="number">6</td>
# <td class="number">.300</td>
# <td class="number">.333</td>
# <td class="number">.500</td><td class="number">2025-04-08</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=31595&amp;StartDate=04%2F28%2F2025&amp;EndDate=05%2F04%2F2025">Brooks Lee</a>
# </td><td class="number">6</td><td class="number">23</td><td class="number">1</td><td class="number">6</td>
# <td class="number">1</td> <td class="number">1</td><td class="number">1</td><td class="number">3</td>
# <td class="number">.261</td>
# <td class="number">.292</td>
# <td class="number">.478</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=16530&amp;StartDate=04%2F20%2F2025&amp;EndDate=05%2F04%2F2025">Mauricio Dubon</a>
# </td><td class="number">6</td><td class="number">21</td><td class="number">2</td><td class="number">6</td>
# <td class="number">0</td> <td class="number">5</td><td class="number">0</td><td class="number">0</td>
# <td class="number">.286</td>
# <td class="number">.286</td>
# <td class="number">.286</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=19997&amp;StartDate=04%2F30%2F2025&amp;EndDate=05%2F04%2F2025">Santiago Espinal</a>
# </td><td class="number">5</td><td class="number">19</td><td class="number">2</td><td class="number">10</td>
# <td class="number">0</td> <td class="number">5</td><td class="number">1</td><td class="number">4</td>
# <td class="number">.526</td>
# <td class="number">.550</td>
# <td class="number">.632</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=20308&amp;StartDate=04%2F27%2F2025&amp;EndDate=05%2F04%2F2025">Jake Meyers</a>
# </td><td class="number">5</td><td class="number">16</td><td class="number">3</td><td class="number">9</td>
# <td class="number">2</td> <td class="number">8</td><td class="number">3</td><td class="number">1</td>
# <td class="number">.562</td>
# <td class="number">.632</td>
# <td class="number">1.125</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=26365&amp;StartDate=03%2F30%2F2025&amp;EndDate=04%2F06%2F2025">Jonny Deluca</a>
# </td><td class="number">5</td><td class="number">18</td><td class="number">4</td><td class="number">9</td>
# <td class="number">0</td> <td class="number">1</td><td class="number">0</td><td class="number">3</td>
# <td class="number">.500</td>
# <td class="number">.500</td>
# <td class="number">.611</td><td class="number">2025-04-06</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=13620&amp;StartDate=04%2F25%2F2025&amp;EndDate=05%2F03%2F2025">Carson Kelly</a>
# </td><td class="number">5</td><td class="number">19</td><td class="number">3</td><td class="number">8</td>
# <td class="number">1</td> <td class="number">4</td><td class="number">3</td><td class="number">2</td>
# <td class="number">.421</td>
# <td class="number">.500</td>
# <td class="number">.632</td><td class="number">2025-05-03</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=7304&amp;StartDate=04%2F27%2F2025&amp;EndDate=05%2F04%2F2025">Salvador Perez</a>
# </td><td class="number">5</td><td class="number">20</td><td class="number">1</td><td class="number">8</td>
# <td class="number">0</td> <td class="number">2</td><td class="number">0</td><td class="number">1</td>
# <td class="number">.400</td>
# <td class="number">.400</td>
# <td class="number">.550</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=14161&amp;StartDate=04%2F30%2F2025&amp;EndDate=05%2F04%2F2025">Byron Buxton</a>
# </td><td class="number">5</td><td class="number">22</td><td class="number">1</td><td class="number">8</td>
# <td class="number">1</td> <td class="number">1</td><td class="number">1</td><td class="number">6</td>
# <td class="number">.364</td>
# <td class="number">.391</td>
# <td class="number">.500</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=11493&amp;StartDate=04%2F29%2F2025&amp;EndDate=05%2F04%2F2025">Manny Machado</a>
# </td><td class="number">5</td><td class="number">19</td><td class="number">4</td><td class="number">8</td>
# <td class="number">1</td> <td class="number">3</td><td class="number">3</td><td class="number">6</td>
# <td class="number">.421</td>
# <td class="number">.500</td>
# <td class="number">.632</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=29575&amp;StartDate=04%2F30%2F2025&amp;EndDate=05%2F04%2F2025">Trey Sweeney</a>
# </td><td class="number">5</td><td class="number">20</td><td class="number">3</td><td class="number">8</td>
# <td class="number">2</td> <td class="number">7</td><td class="number">0</td><td class="number">6</td>
# <td class="number">.400</td>
# <td class="number">.400</td>
# <td class="number">.700</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=31781&amp;StartDate=04%2F28%2F2025&amp;EndDate=05%2F04%2F2025">Jackson Holliday</a>
# </td><td class="number">5</td><td class="number">15</td><td class="number">4</td><td class="number">7</td>
# <td class="number">2</td> <td class="number">3</td><td class="number">0</td><td class="number">1</td>
# <td class="number">.467</td>
# <td class="number">.467</td>
# <td class="number">.867</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=31349&amp;StartDate=04%2F30%2F2025&amp;EndDate=05%2F04%2F2025">Victor Scott</a>
# </td><td class="number">5</td><td class="number">16</td><td class="number">3</td><td class="number">7</td>
# <td class="number">1</td> <td class="number">5</td><td class="number">3</td><td class="number">5</td>
# <td class="number">.438</td>
# <td class="number">.526</td>
# <td class="number">.688</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=26323&amp;StartDate=04%2F30%2F2025&amp;EndDate=05%2F04%2F2025">Spencer Steer</a>
# </td><td class="number">5</td><td class="number">19</td><td class="number">3</td><td class="number">7</td>
# <td class="number">1</td> <td class="number">3</td><td class="number">2</td><td class="number">4</td>
# <td class="number">.368</td>
# <td class="number">.429</td>
# <td class="number">.579</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=24679&amp;StartDate=04%2F30%2F2025&amp;EndDate=05%2F04%2F2025">Brendan Donovan</a>
# </td><td class="number">5</td><td class="number">17</td><td class="number">4</td><td class="number">6</td>
# <td class="number">0</td> <td class="number">3</td><td class="number">3</td><td class="number">1</td>
# <td class="number">.353</td>
# <td class="number">.476</td>
# <td class="number">.353</td><td class="number">2025-05-04</td></tr>
# <tr><td class="letter"><a href="https://www.baseballmusings.com/cgi-bin/PlayerInfo.py?PlayerID=20036&amp;StartDate=04%2F28%2F2025&amp;EndDate=05%2F03%2F2025">Isaac Paredes</a>
# </td><td class="number">5</td><td class="number">18</td><td class="number">3</td><td class="number">5</td>
# <td class="number">0</td> <td class="number">1</td><td class="number">4</td><td class="number">2</td>
# <td class="number">.278</td>
# <td class="number">.409</td>
# <td class="number">.389</td><td class="number">2025-05-03</td></tr>
# </table>
# <p>The information used here was obtained free of charge from and is copyrighted by Retrosheet.  Interested parties may contact <a href="https://www.retrosheet.org">Retrosheet</a> at 20 Sunset Rd., Newark, DE 19711. Newer data was purchased from <a href="https://www.baseballinfosolutions.com">Baseball Info Solutions</a>.</p>
# </td><td style="width:250px" valign="top">
# <center>
# <a href="http://www.baseballmusings.com">Baseball Musings home</a><br/>
# <a href="http://www.baseballmusings.com/cgi-bin/DayByDayDatabase.py">Day by Day Database</a><br/>
# <!-- begin ZEDO for channel:  Baseball Musings , publisher: Baseball Musings , Ad Dimension: Skyscraper - 120 x 600 -->
# <!--
# <script language="JavaScript">
# var zflag_nid="558"; var zflag_cid="414/9"; var zflag_sid="297"; var zflag_width="120"; var zflag_height="600"; var zflag_sz="8";
# </script>
# <iframe src="http://c1.zedo.com/jsc/c1/ff2.html?n=558;c=414/9;s=297;d=8;w=120;h=600" frameborder=0 marginheight=0 marginwidth=0 scrolling="no" allowTransparency="true" width=120 height=600><script language="JavaScript" src="http://c1.zedo.com/jsc/c1/ff2.js"></script><noscript>
# <a href="http://xads.zedo.com/ads2/r?n=558;c=414/9;s=297;x=2048;u=j;z=[timestamp]" target="_blank"><img border="0" width="120" height="600" src="http://xads.zedo.com/ads2/x?n=558;c=414/9;s=297;x=2048;u=j;z=[timestamp]" alt="Click here"></a>
# </noscript>
# </iframe>
# -->
# <!-- end ZEDO  for channel:  Baseball Musings , publisher: Baseball Musings , Ad Dimension: Skyscraper - 120 x 600 -->
# <br/><br/>
# <!--
# <script type="text/javascript" src="http://www.ticketnetworkdirect.com/asearch/Search.aspx?TNSearchID=1464&mainWidth=160&borderWidth=4&borderColor=%23000099&showBorder=Y&showDivider1=Y&showDivider2=Y&dividerColor=%23000099&showHeadline=Y&showSearchIntro=Y&searchIntroText=Search%20by%20Team%20or%20Event%20Name&searchBoxWidth=160&boxAndButtonSameLine=Y&popEventType=1&popEventNumber=4"></script>
# -->
# <!--
# <br><br>
# <link rel="stylesheet" type="text/css" href="http://cache.blogads.com/901196290/feed.css" />
# <script language="javascript" src="http://cache.blogads.com/901196290/feed.js"></script>
# -->
# <br/><br/><br/>
# <!-- SMG_BaseballMusings/160x600_1a/sports/baseball/mlb.general -->
# <!--
# <div id="usmg_ad_mlb.general_baseball_sports_160x600_1a">
# <script type='text/javascript'>
# googletag.defineSlot('/7103/SMG_BaseballMusings/160x600_1a/sports/baseball/mlb.general', [160,600], 'usmg_ad_mlb.general_baseball_sports_160x600_1a').addService(googletag.pubads());
# googletag.enableServices();
# googletag.display('usmg_ad_mlb.general_baseball_sports_160x600_1a');
# </script>
# </div>
# -->
# <script type="text/javascript">
# amzn_assoc_placement = "adunit0";
# amzn_assoc_enable_interest_ads = "true";
# amzn_assoc_tracking_id = "baseballmusin-20";
# amzn_assoc_ad_mode = "auto";
# amzn_assoc_ad_type = "smart";
# amzn_assoc_marketplace = "amazon";
# amzn_assoc_region = "US";
# amzn_assoc_linkid = "1a99419a77acd0cdb9a6ced0d65b9ae3";
# amzn_assoc_emphasize_categories = "16261631,1000,172282,3375251,3250697011,165793011,468642";
# amzn_assoc_fallback_mode = {"type":"search","value":"Baseball"};
# amzn_assoc_default_category = "Collectibles";
# </script>
# <script src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US"></script>
# <!--WEBBOT bot="HTMLMarkup" startspan ALT="Site Meter" -->
# <script language="JavaScript" type="text/javascript">var site="sm4statman"</script>
# <script language="JavaScript1.2" src="https://sm4.sitemeter.com/js/counter.js?site=sm4statman" type="text/javascript">
# </script>
# <noscript>
# <a href="https://sm4.sitemeter.com/stats.asp?site=sm4statman" target="_top">
# <img alt="Site Meter" border="0" src="https://sm4.sitemeter.com/meter.asp?site=sm4statman"/></a>
# </noscript>
# <!-- Copyright (c)2002 Site Meter -->
# <!--WEBBOT bot="HTMLMarkup" Endspan -->
# <br>
# <script async="" defer="" id="eXF-bmguy-2" src="https://efreecode.com/js.js"></script>
# <br>
# <form action="https://www.paypal.com/cgi-bin/webscr" method="post">
# <input name="cmd" type="hidden" value="_xclick"/>
# <input name="business" type="hidden" value="pinto@baseballmusings.com"/>
# <input name="no_note" type="hidden" value="1"/>
# <input name="currency_code" type="hidden" value="USD"/>
# <input name="tax" type="hidden" value="0"/>
# <input alt="Make payments with PayPal - it's fast, free and secure!" border="0" name="submit" src="https://www.paypal.com/images/x-click-but04.gif" type="image"/>
# </form>
# <br/><br/>
# <!--
# <A HREF="http://www.digits.com">Digits.com</A> supplies the counter.<BR>
# <IMG SRC="http://counter.digits.com/wc/-d/4/BaseballMusings" ALIGN=middle
#       WIDTH=60 HEIGHT=20 BORDER=0 HSPACE=4 VSPACE=2>
#
#
# <br />
# -->
# <script src="https://www.google-analytics.com/urchin.js" type="text/javascript">
# </script>
# <script type="text/javascript">
# _uacct = "UA-1080129-1";
# urchinTracker();
# </script>
# <br/><br/>
# <!--
# <br>
# <img src="https://t.blogreaderproject.com/t.gif?e5b912eea5c7b7d077f90856eadf676f"/>
# -->
# </br></br></center>
# </td></tr></table>

# %%
import requests
from bs4 import BeautifulSoup
import csv
import os
from datetime import datetime, timedelta

# Ensure the "text_output" folder exists
os.makedirs("text_output", exist_ok=True)

# Get yesterday's date
yesterday = (datetime.now() - timedelta(days=1)).strftime("%Y-%m-%d")

# File paths
file_name = "hitting-streak.csv"
file_path = f"text_output/{file_name}"
backup_file_path = f"text_output/hitting-streak_{yesterday}.csv"

# Check if the file already exists and rename it
if os.path.exists(file_path):
    os.rename(file_path, backup_file_path)

# URL of the webpage
url = "https://www.baseballmusings.com/cgi-bin/CurStreak.py"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the table in the HTML
    table = soup.find('table')
    
    if table:
        # Extract table rows
        rows = table.find_all('tr')
        
        # Extract table data
        table_data = []
        for row in rows:
            cells = row.find_all(['td', 'th'])  # Include both header and data cells
            table_data.append([cell.get_text(strip=True) for cell in cells])
        
        # Write the table data to a CSV file
        with open(file_path, "w", newline="", encoding="utf-8") as csv_file:
            writer = csv.writer(csv_file)
            writer.writerows(table_data)
        
        print(f"New file saved to {file_path}")
        if os.path.exists(backup_file_path):
            print(f"Existing file renamed to {backup_file_path}")
    else:
        print("No table found on the page.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# New file saved to text_output/hitting-streak.csv

# %%
# get every player and write to a txt file

import mlbstatsapi
import statsapi

mlb = mlbstatsapi.Mlb()
# params = {'season': 2025}
# type = ['season']
# groups = ['hitting', 'pitching']
#id = mlb.get_team_id('New York Mets')[0]
# you can get all major league teams with mlb.get_teams(sportid=1)
# stats = mlb.get_team_stats(team_id=id, stats=type, groups=groups, params)
yellow = mlb.get_teams(sportid=1)
green = []
for x in yellow:
    green.append(x.id)

players = []
for x in green:
    players.append(statsapi.roster(x))

for x in players:
    print(x)


# Write the players list to a CSV file
txt_file_path = "text_output/all_players.txt"
with open(txt_file_path, "w", encoding="utf-8") as txt_file:

    for y in players:
        txt_file.write(y)

print(f"Player data saved to {txt_file_path}")
# Out:
# https://statsapi.mlb.com/api/v1/teams
# #25  LF  Brent Rooker
# #13  3B  Gio Urshela
# #67  P   Grant Holman
# #53  P   Gunnar Hoglund
# #36  P   Hogan Harris
# #33  CF  JJ Bleday
# #38  P   JP Sears
# #5   SS  Jacob Wilson
# #59  P   Jeffrey Springs
# #64  C   Jhonny Pereda
# #60  P   Justin Sterner
# #4   RF  Lawrence Butler
# #40  P   Luis Severino
# #17  3B  Luis Urías
# #19  P   Mason Miller
# #12  3B  Max Schuemann
# #22  LF  Miguel Andujar
# #28  P   Mitch Spence
# #16  1B  Nick Kurtz
# #58  P   Noah Murdock
# #45  P   Osvaldo Bido
# #15  LF  Seth Brown
# #23  C   Shea Langeliers
# #48  P   T.J. McFarland
# #44  P   Tyler Ferguson
# #21  1B  Tyler Soderstrom
#
# #26  2B  Adam Frazier
# #29  RF  Alexander Canario
# #45  P   Andrew Heaney
# #22  RF  Andrew McCutchen
# #6   P   Bailey Falter
# #10  RF  Bryan Reynolds
# #64  P   Caleb Ferguson
# #50  P   Carmen Mlodzinski
# #55  P   Chase Shugart
# #35  P   Colin Holderman
# #51  P   David Bednar
# #60  P   Dennis Santana
# #48  1B  Enmanuel Valdez
# #32  C   Henry Davis
# #19  2B  Jared Triolo
# #14  C   Joey Bart
# #34  P   Joey Wentz
# #13  3B  Ke'Bryan Hayes
# #31  SS  Liover Peguero
# #62  CF  Matt Gorski
# #23  P   Mitch Keller
# #15  CF  Oneil Cruz
# #30  P   Paul Skenes
# #43  P   Ryan Borucki
# #27  P   Tanner Rainey
# #28  LF  Tommy Pham
#
# #50  P   Adrian Morejon
# #37  P   Alek Jacob
# #28  CF  Brandon Lockridge
# #84  P   Dylan Cease
# #17  C   Elias Díaz
# #23  RF  Fernando Tatis Jr.
# #30  LF  Gavin Sheets
# #40  P   Jason Adam
# #22  LF  Jason Heyward
# #56  P   Jeremiah Estrada
# #7   2B  Jose Iglesias
# #4   1B  Luis Arraez
# #12  C   Luis Campusano
# #13  3B  Manny Machado
# #15  C   Martín Maldonado
# #34  P   Michael King
# #27  P   Nick Pivetta
# #39  LF  Oscar Gonzalez
# #98  P   Randy Vásquez
# #75  P   Robert Suarez
# #38  P   Ryan Bergert
# #32  P   Stephen Kolek
# #14  CF  Tyler Wade
# #58  P   Wandy Peralta
# #2   SS  Xander Bogaerts
# #1   P   Yuki Matsui
#
# #75  P   Andrés Muñoz
# #9   3B  Ben Williamson
# #22  P   Bryan Woo
# #50  P   Bryce Miller
# #29  C   Cal Raleigh
# #54  P   Carlos Vargas
# #64  P   Casey Legumina
# #52  P   Collin Snider
# #39  1B  Donovan Solano
# #83  P   Eduard Bazardo
# #26  P   Emerson Hancock
# #55  P   Gabe Speier
# #3   SS  J.P. Crawford
# #7   3B  Jorge Polanco
# #44  CF  Julio Rodríguez
# #76  2B  Leo Rivas
# #73  P   Logan Evans
# #58  P   Luis Castillo
# #47  P   Matt Brash
# #21  3B  Miles Mastrobuoni
# #18  C   Mitch Garver
# #56  LF  Randy Arozarena
# #31  LF  Rhylan Thomas
# #23  1B  Rowdy Tellez
# #0   2B  Samad Taylor
# #46  P   Trent Thornton
#
# #0   2B  Brett Wisely
# #75  P   Camilo Doval
# #50  2B  Christian Koss
# #32  2B  David Villar
# #68  P   Erik Miller
# #60  P   Hayden Birdsong
# #17  LF  Heliot Ramos
# #12  P   Jordan Hicks
# #51  CF  Jung Hoo Lee
# #35  P   Justin Verlander
# #45  P   Kyle Harrison
# #31  1B  LaMonte Wade Jr.
# #65  P   Landen Roupp
# #62  P   Logan Webb
# #29  RF  Luis Matos
# #26  3B  Matt Chapman
# #5   RF  Mike Yastrzemski
# #14  C   Patrick Bailey
# #73  P   Randy Rodríguez
# #38  P   Robbie Ray
# #74  P   Ryan Walker
# #23  C   Sam Huff
# #76  P   Spencer Bivens
# #71  P   Tyler Rogers
# #2   SS  Willy Adames
# #41  1B  Wilmer Flores
#
# #41  1B  Alec Burleson
# #53  P   Andre Pallante
# #33  2B  Brendan Donovan
# #58  P   Chris Roycroft
# #12  P   Erick Fedde
# #59  P   JoJo Romero
# #47  P   John King
# #18  RF  Jordan Walker
# #27  SS  Jose Barrero
# #62  P   Kyle Leahy
# #21  LF  Lars Nootbaar
# #26  1B  Luken Baker
# #0   SS  Masyn Winn
# #52  P   Matthew Liberatore
# #36  P   Michael McGreevy
# #39  P   Miles Mikolas
# #28  3B  Nolan Arenado
# #16  2B  Nolan Gorman
# #43  C   Pedro Pagés
# #88  P   Phil Maton
# #56  P   Ryan Helsley
# #54  P   Sonny Gray
# #32  P   Steven Matz
# #11  CF  Victor Scott II
# #40  1B  Willson Contreras
# #63  C   Yohel Pozo
#
# #30  C   Ben Rortvedt
# #8   2B  Brandon Lowe
# #14  OF  Chandler Simpson
# #24  LF  Christopher Morel
# #25  1B  Curtis Mead
# #19  C   Danny Jansen
# #57  P   Drew Rasmussen
# #63  P   Edwin Uceta
# #17  P   Eric Orze
# #60  P   Garrett Cleavinger
# #43  P   Hunter Bigge
# #62  1B  Jonathan Aranda
# #77  RF  José Caballero
# #13  3B  Junior Caminero
# #26  CF  Kameron Misner
# #39  P   Manuel Rodríguez
# #59  P   Mason Englert
# #48  P   Mason Montgomery
# #29  P   Pete Fairbanks
# #44  P   Ryan Pepiot
# #11  P   Shane Baz
# #45  P   Taj Bradley
# #6   SS  Taylor Walls
# #20  RF  Travis Jankowski
# #2   1B  Yandy Díaz
# #52  P   Zack Littell
#
# #53  RF  Adolis García
# #13  1B  Blaine Crim
# #70  P   Caleb Boushley
# #55  P   Chris Martin
# #5   SS  Corey Seager
# #38  LF  Dustin Harris
# #41  P   Hoby Milner
# #35  P   Jack Leiter
# #67  P   Jacob Latz
# #71  P   Jacob Webb
# #48  P   Jacob deGrom
# #4   DH  Joc Pederson
# #28  C   Jonah Heim
# #6   3B  Josh Jung
# #8   3B  Josh Smith
# #1   CF  Kevin Pillar
# #3   CF  Leody Taveras
# #77  P   Luke Jackson
# #2   2B  Marcus Semien
# #17  P   Nathan Eovaldi
# #46  P   Patrick Corbin
# #62  P   Robert Garcia
# #43  P   Shawn Armstrong
# #18  C   Tucker Barnhart
# #51  P   Tyler Mahle
# #36  LF  Wyatt Langford
#
# #47  RF  Addison Barger
# #18  LF  Alan Roden
# #30  C   Alejandro Kirk
# #0   2B  Andrés Giménez
# #25  RF  Anthony Santander
# #11  SS  Bo Bichette
# #44  P   Bowden Francis
# #54  P   Brendon Little
# #57  P   Chad Green
# #40  P   Chris Bassitt
# #5   CF  Daulton Varsho
# #9   P   Dillon Tate
# #56  P   Eric Lauer
# #22  3B  Ernie Clement
# #4   RF  George Springer
# #23  P   Jeff Hoffman
# #17  P   José Berríos
# #    P   José Ureña
# #34  P   Kevin Gausman
# #68  P   Mason Fluharty
# #3   CF  Myles Straw
# #38  CF  Nathan Lukes
# #55  C   Tyler Heineman
# #27  1B  Vladimir Guerrero Jr.
# #29  P   Yariel Rodríguez
# #93  P   Yimi García
#
# #17  P   Bailey Ober
# #61  P   Brock Stewart
# #2   3B  Brooks Lee
# #25  CF  Byron Buxton
# #4   SS  Carlos Correa
# #20  P   Chris Paddack
# #8   C   Christian Vázquez
# #44  P   Cole Sands
# #21  RF  DaShawn Keirsey Jr.
# #54  P   Danny Coulombe
# #22  P   Griffin Jax
# #12  LF  Harrison Bader
# #59  P   Jhoan Duran
# #41  P   Joe Ryan
# #31  1B  Jonah Bride
# #66  P   Jorge Alcala
# #48  P   Justin Topa
# #18  2B  Kody Clemens
# #37  P   Louis Varland
# #49  P   Pablo López
# #23  3B  Royce Lewis
# #27  C   Ryan Jeffers
# #24  P   Simeon Woods Richardson
# #9   LF  Trevor Larnach
# #13  1B  Ty France
# #50  2B  Willi Castro
#
# #27  P   Aaron Nola
# #28  3B  Alec Bohm
# #16  CF  Brandon Marsh
# #3   1B  Bryce Harper
# #5   2B  Bryson Stott
# #35  P   Carlos Hernández
# #61  P   Cristopher Sánchez
# #33  SS  Edmundo Sosa
# #10  C   J.T. Realmuto
# #44  P   Jesús Luzardo
# #41  P   Joe Ross
# #23  CF  Johan Rojas
# #68  P   Jordan Romano
# #46  P   José Alvarado
# #12  LF  Kyle Schwarber
# #25  P   Matt Strahm
# #17  LF  Max Kepler
# #8   RF  Nick Castellanos
# #50  P   Orion Kerkering
# #13  C   Rafael Marchán
# #55  P   Ranger Suárez
# #99  P   Taijuan Walker
# #58  P   Tanner Banks
# #7   SS  Trea Turner
# #37  LF  Weston Wilson
# #45  P   Zack Wheeler
#
# #32  P   AJ Smith-Shawver
# #49  P   Aaron Bummer
# #8   LF  Alex Verdugo
# #27  3B  Austin Riley
# #55  P   Bryce Elder
# #51  P   Chris Sale
# #62  P   Daysbel Hernández
# #30  C   Drake Baldwin
# #52  P   Dylan Lee
# #9   OF  Eddie Rosario
# #36  LF  Eli White
# #61  P   Enyel De Los Santos
# #66  P   Grant Holmes
# #20  DH  Marcell Ozuna
# #28  1B  Matt Olson
# #23  CF  Michael Harris II
# #2   SS  Nick Allen
# #11  SS  Orlando Arcia
# #1   2B  Ozzie Albies
# #38  P   Pierce Johnson
# #48  P   Rafael Montero
# #26  P   Raisel Iglesias
# #63  P   Scott Blewett
# #12  C   Sean Murphy
# #56  P   Spencer Schwellenbach
# #17  RF  Stuart Fairchild
#
# #23  LF  Andrew Benintendi
# #25  1B  Andrew Vaughn
# #53  P   Brandon Eisert
# #27  LF  Brooks Baldwin
# #46  P   Bryse Wilson
# #68  P   Caleb Freeman
# #71  P   Cam Booser
# #10  2B  Chase Meidroth
# #65  P   Davis Martin
# #7   C   Edgar Quero
# #8   SS  Jacob Amaya
# #51  P   Jared Shuster
# #48  P   Jonathan Cannon
# #49  P   Jordan Leasure
# #5   3B  Josh Rojas
# #47  RF  Joshua Palacios
# #50  2B  Lenyn Sosa
# #88  CF  Luis Robert Jr.
# #29  C   Matt Thaiss
# #21  LF  Michael A. Taylor
# #20  3B  Miguel Vargas
# #61  P   Mike Vasil
# #59  P   Sean Burke
# #64  P   Shane Smith
# #36  P   Steven Wilson
# #40  P   Tyler Gilbert
#
# #50  C   Agustín Ramírez
# #37  P   Anthony Bender
# #59  P   Anthony Veneziano
# #47  P   Cal Quantrill
# #53  P   Calvin Faucher
# #1   3B  Connor Norby
# #54  CF  Dane Myers
# #27  P   Edward Cabrera
# #33  1B  Eric Wagaman
# #62  P   George Soriano
# #21  3B  Graham Pauley
# #46  LF  Javier Sanoja
# #7   CF  Jesús Sánchez
# #38  P   Jesus Tinoco
# #28  RF  Kyle Stowers
# #84  P   Lake Bachar
# #34  C   Liam Hicks
# #36  1B  Matt Mervis
# #23  P   Max Meyer
# #4   C   Nick Fortes
# #32  P   Ronny Henriquez
# #41  2B  Ronny Simon
# #22  P   Sandy Alcantara
# #30  P   Tyler Phillips
# #83  P   Valente Bellozo
# #9   SS  Xavier Edwards
#
# #99  RF  Aaron Judge
# #11  SS  Anthony Volpe
# #28  C   Austin Wells
# #22  1B  Ben Rice
# #59  P   Carlos Carrasco
# #55  P   Carlos Rodón
# #36  P   Clarke Schmidt
# #35  CF  Cody Bellinger
# #38  P   Devin Williams
# #63  P   Fernando Cruz
# #71  P   Ian Hamilton
# #25  C   J.C. Escarra
# #24  LF  Jasson Domínguez
# #90  2B  Jorbit Vivas
# #30  P   Luke Weaver
# #56  P   Mark Leiter Jr.
# #54  P   Max Fried
# #18  3B  Oswald Peraza
# #95  3B  Oswaldo Cabrera
# #19  3B  Pablo Reyes
# #48  1B  Paul Goldschmidt
# #33  P   Ryan Yarbrough
# #41  P   Tim Hill
# #12  CF  Trent Grisham
# #68  P   Tyler Matzek
# #98  P   Will Warren
#
# #45  P   Abner Uribe
# #2   2B  Brice Turang
# #21  2B  Caleb Durbin
# #39  P   Chad Patrick
# #22  LF  Christian Yelich
# #20  LF  Daz Cameron
# #35  P   Elvin Rodriguez
# #13  C   Eric Haase
# #51  P   Freddy Peralta
# #56  P   Grant Anderson
# #6   LF  Isaac Collins
# #11  LF  Jackson Chourio
# #9   1B  Jake Bauers
# #47  P   Jared Koenig
# #31  P   Joel Payamps
# #3   SS  Joey Ortiz
# #62  P   Jose Quintana
# #25  P   Nick Mears
# #46  P   Quinn Priester
# #12  1B  Rhys Hoskins
# #10  RF  Sal Frelick
# #36  P   Tobias Myers
# #29  P   Trevor Megill
# #33  P   Tyler Alexander
# #18  3B  Vinny Capra
# #24  C   William Contreras
#
# #46  P   Brock Burke
# #51  RF  Gustavo Campero
# #41  P   Jack Kochanowicz
# #7   CF  Jo Adell
# #12  RF  Jorge Soler
# #68  P   Jose Fermin
# #59  P   José Soriano
# #74  P   Kenley Jansen
# #10  SS  Kevin Newman
# #28  P   Kyle Hendricks
# #19  2B  Kyren Paris
# #14  C   Logan O'Hoppe
# #2   3B  Luis Rengifo
# #61  P   Michael Darrell-Hicks
# #20  OF  Niko Kavadas
# #18  1B  Nolan Schanuel
# #48  P   Reid Detmers
# #32  P   Ryan Johnson
# #56  P   Ryan Zeferjahn
# #3   LF  Taylor Ward
# #77  SS  Tim Anderson
# #55  P   Touki Toussaint
# #25  C   Travis d'Arnaud
# #31  P   Tyler Anderson
# #16  P   Yusei Kikuchi
# #9   SS  Zach Neto
#
# #5   CF  Alek Thomas
# #32  P   Brandon Pfaadt
# #39  P   Corbin Burnes
# #7   RF  Corbin Carroll
# #57  P   Eduardo Rodriguez
# #28  3B  Eugenio Suárez
# #14  C   Gabriel Moreno
# #8   2B  Garrett Hampson
# #2   SS  Geraldo Perdomo
# #68  P   Jalen Beeks
# #66  P   José Castillo
# #11  C   Jose Herrera
# #22  1B  Josh Naylor
# #67  P   Juan Morillo
# #4   2B  Ketel Marte
# #37  P   Kevin Ginkel
# #12  LF  Lourdes Gurriel Jr.
# #29  P   Merrill Kelly
# #26  1B  Pavin Smith
# #15  RF  Randal Grichuk
# #81  P   Ryan Thompson
# #19  P   Ryne Nelson
# #18  P   Shelby Miller
# #13  2B  Tim Tawa
# #47  P   Tommy Henry
# #23  P   Zac Gallen
#
# #35  C   Adley Rutschman
# #43  P   Bryan Baker
# #37  P   Cade Povich
# #31  CF  Cedric Mullins
# #50  P   Charlie Morton
# #58  P   Cionel Pérez
# #16  3B  Coby Mayo
# #64  P   Dean Kremer
# #15  LF  Dylan Carlson
# #26  3B  Emmanuel Rivera
# #74  P   Félix Bautista
# #65  P   Gregory Soto
# #2   SS  Gunnar Henderson
# #13  LF  Heston Kjerstad
# #7   2B  Jackson Holliday
# #3   SS  Jorge Mateo
# #45  P   Keegan Akin
# #48  P   Kyle Gibson
# #51  P   Matt Bowman
# #98  C   Maverick Handley
# #12  LF  Ramón Laureano
# #6   1B  Ryan Mountcastle
# #32  1B  Ryan O'Hearn
# #56  P   Seranthony Domínguez
# #19  P   Tomoyuki Sugano
# #78  P   Yennier Cano
#
# #29  3B  Abraham Toro
# #2   3B  Alex Bregman
# #44  P   Aroldis Chapman
# #66  P   Brayan Bello
# #83  P   Brennan Bernardino
# #75  C   Carlos Narváez
# #3   CF  Ceddanne Rafaela
# #12  C   Connor Wong
# #17  2B  David Hamilton
# #35  P   Garrett Crochet
# #22  P   Garrett Whitlock
# #57  P   Greg Weissert
# #73  P   Hunter Dobbins
# #16  LF  Jarren Duran
# #63  P   Justin Slaten
# #32  P   Justin Wilson
# #28  2B  Kristian Campbell
# #31  P   Liam Hendriks
# #54  P   Lucas Giolito
# #11  3B  Rafael Devers
# #30  RF  Rob Refsnyder
# #23  1B  Romy Gonzalez
# #19  P   Sean Newcomb
# #89  P   Tanner Houck
# #10  SS  Trevor Story
# #52  RF  Wilyer Abreu
#
# #32  P   Ben Brown
# #40  P   Brad Keller
# #24  P   Caleb Thielbar
# #15  C   Carson Kelly
# #58  P   Chris Flexen
# #53  P   Colin Rea
# #48  P   Daniel Palencia
# #7   SS  Dansby Swanson
# #45  P   Drew Pomeranz
# #8   LF  Ian Happ
# #50  P   Jameson Taillon
# #5   2B  Jon Berti
# #66  P   Julian Merryweather
# #3   1B  Justin Turner
# #30  RF  Kyle Tucker
# #16  P   Matthew Boyd
# #29  1B  Michael Busch
# #9   C   Miguel Amaya
# #12  SS  Nicky Lopez
# #2   2B  Nico Hoerner
# #4   CF  Pete Crow-Armstrong
# #37  P   Porter Hodge
# #55  P   Ryan Pressly
# #27  RF  Seiya Suzuki
# #18  P   Shota Imanaga
# #17  SS  Vidal Bruján
#
# #41  P   Andrew Abbott
# #38  C   Austin Wynns
# #59  LF  Blake Dunn
# #51  P   Brady Singer
# #31  P   Brent Suter
# #44  SS  Elly De La Cruz
# #15  P   Emilio Pagán
# #2   LF  Gavin Lux
# #23  P   Graham Ashcraft
# #21  P   Hunter Greene
# #27  RF  Jake Fraley
# #35  C   Jose Trevino
# #62  P   Luis Mey
# #9   2B  Matt McLain
# #40  P   Nick Lodolo
# #28  P   Nick Martinez
# #16  3B  Noelvi Marte
# #4   2B  Santiago Espinal
# #58  P   Scott Barlow
# #7   LF  Spencer Steer
# #29  CF  TJ Friedl
# #55  P   Taylor Rogers
# #64  P   Tony Santillan
# #32  2B  Tyler Callihan
# #37  C   Tyler Stephenson
# #67  P   Yosver Zulueta
#
# #1   CF  Angel Martínez
# #27  C   Austin Hedges
# #39  P   Ben Lively
# #23  C   Bo Naylor
# #4   SS  Brayan Rocchio
# #36  P   Cade Smith
# #41  1B  Carlos Santana
# #10  2B  Daniel Schneemann
# #48  P   Emmanuel Clase
# #13  2B  Gabriel Arias
# #32  P   Gavin Williams
# #33  P   Hunter Gaddis
# #16  P   Jakob Junis
# #43  RF  Jhonkensy Noel
# #54  P   Joey Cantillo
# #11  3B  José Ramírez
# #49  P   Kolby Allard
# #9   1B  Kyle Manzardo
# #26  P   Logan Allen
# #45  P   Luis L. Ortiz
# #52  P   Matt Festa
# #22  RF  Nolan Jones
# #38  LF  Steven Kwan
# #28  P   Tanner Bibee
# #29  P   Tim Herrin
# #7   SS  Will Wilson
#
# #1   2B  Adael Amador
# #31  2B  Alan Trejo
# #57  P   Angel Chivilli
# #49  P   Antonio Senzatela
# #64  P   Bradley Blalock
# #9   CF  Brenton Doyle
# #32  P   Chase Dollander
# #48  P   Germán Márquez
# #15  C   Hunter Goodman
# #25  C   Jacob Stallings
# #59  P   Jake Bird
# #44  P   Jimmy Herget
# #27  LF  Jordan Beck
# #47  P   Juan Mejia
# #6   2B  Kyle Farmer
# #21  P   Kyle Freeland
# #4   1B  Michael Toglia
# #22  CF  Mickey Moniak
# #35  RF  Nick Martini
# #11  1B  Owen Miller
# #24  3B  Ryan McMahon
# #52  P   Scott Alexander
# #12  RF  Sean Bouchard
# #54  P   Seth Halvorsen
# #40  P   Tyler Kinley
# #36  P   Zach Agnos
#
# #77  3B  Andy Ibáñez
# #4   P   Beau Brieske
# #48  P   Brant Hurter
# #75  P   Brenan Hanifee
# #12  P   Casey Mize
# #53  P   Chase Lee
# #33  2B  Colt Keith
# #13  C   Dillon Dingler
# #25  2B  Gleyber Torres
# #17  3B  Jace Jung
# #9   P   Jack Flaherty
# #21  P   Jackson Jobe
# #28  3B  Javier Báez
# #44  RF  Justyn-Henry Malloy
# #30  LF  Kerry Carpenter
# #45  P   Reese Olson
# #31  LF  Riley Greene
# #73  P   Sean Guenther
# #20  1B  Spencer Torkelson
# #29  P   Tarik Skubal
# #58  C   Tomás Nido
# #43  P   Tommy Kahnle
# #27  SS  Trey Sweeney
# #87  P   Tyler Holton
# #19  P   Will Vest
# #39  RF  Zach McKinstry
#
# #62  P   Bennett Sousa
# #1   2B  Brendan Rodgers
# #52  P   Bryan Abreu
# #74  P   Bryan King
# #11  RF  Cam Smith
# #20  CF  Chas McCormick
# #8   1B  Christian Walker
# #59  P   Framber Valdez
# #39  P   Hayden Wesneski
# #58  P   Hunter Brown
# #15  3B  Isaac Paredes
# #6   CF  Jake Meyers
# #3   SS  Jeremy Peña
# #27  LF  Jose Altuve
# #71  P   Josh Hader
# #63  P   Kaleb Ort
# #43  P   Lance McCullers Jr.
# #14  2B  Mauricio Dubón
# #56  P   Ronel Blanco
# #67  P   Ryan Gusto
# #48  P   Steven Okert
# #50  P   Tayler Scott
# #17  C   Victor Caratini
# #21  C   Yainer Diaz
# #44  LF  Yordan Alvarez
# #9   RF  Zach Dezenzo
#
# #61  P   Angel Zerpa
# #7   SS  Bobby Witt Jr.
# #53  P   Carlos Estévez
# #18  1B  Cavan Biggio
# #35  P   Chris Stratton
# #55  P   Cole Ragans
# #41  P   Daniel Lynch IV
# #8   LF  Drew Waters
# #34  C   Freddy Fermin
# #16  RF  Hunter Renfroe
# #46  P   John Schreiber
# #6   3B  Jonathan India
# #50  P   Kris Bubic
# #28  CF  Kyle Isbel
# #60  P   Lucas Erceg
# #15  C   Luke Maile
# #11  3B  Maikel Garcia
# #21  1B  Mark Canha
# #24  P   Michael Lorenzen
# #19  2B  Michael Massey
# #52  P   Michael Wacha
# #13  C   Salvador Perez
# #67  P   Seth Lugo
# #64  P   Steven Cruz
# #45  P   Taylor Clarke
# #9   1B  Vinnie Pasquantino
#
# #51  P   Alex Vesia
# #44  CF  Andy Pages
# #43  P   Anthony Banda
# #15  C   Austin Barnes
# #78  P   Ben Casparius
# #3   LF  Chris Taylor
# #85  P   Dustin May
# #8   1B  Enrique Hernández
# #59  P   Evan Phillips
# #5   1B  Freddie Freeman
# #6   2B  Hyeseong Kim
# #86  P   Jack Dreyer
# #38  P   Kirby Yates
# #57  P   Luis García
# #13  3B  Max Muncy
# #23  LF  Michael Conforto
# #72  SS  Miguel Rojas
# #50  SS  Mookie Betts
# #11  P   Roki Sasaki
# #17  TWP Shohei Ohtani
# #66  P   Tanner Scott
# #37  RF  Teoscar Hernández
# #26  P   Tony Gonsolin
# #16  C   Will Smith
# #94  P   Yoendrys Gómez
# #18  P   Yoshinobu Yamamoto
#
# #17  RF  Alex Call
# #13  3B  Amed Rosario
# #53  P   Andrew Chafin
# #61  P   Brad Lord
# #5   SS  CJ Abrams
# #99  P   Cole Henry
# #3   RF  Dylan Crews
# #62  P   Eduardo Salazar
# #79  P   Jackson Rutledge
# #30  CF  Jacob Young
# #27  P   Jake Irvin
# #29  LF  James Wood
# #21  P   Jorge López
# #47  P   Jose A. Ferrer
# #8   3B  José Tena
# #19  1B  Josh Bell
# #20  C   Keibert Ruiz
# #67  P   Kyle Finnegan
# #39  P   Lucas Sims
# #2   2B  Luis García Jr.
# #1   P   MacKenzie Gore
# #70  P   Mitchell Parker
# #26  SS  Nasim Nuñez
# #33  1B  Nathaniel Lowe
# #15  C   Riley Adams
# #32  P   Trevor Williams
#
# #9   LF  Brandon Nimmo
# #35  P   Clay Holmes
# #23  P   David Peterson
# #72  P   Dedniel Núñez
# #39  P   Edwin Díaz
# #4   C   Francisco Alvarez
# #12  SS  Francisco Lindor
# #92  P   Génesis Cabrera
# #46  P   Griffin Canning
# #43  P   Huascar Brazobán
# #1   2B  Jeff McNeil
# #3   LF  Jesse Winker
# #28  LF  José Azocar
# #70  P   José Buttó
# #22  RF  Juan Soto
# #34  P   Kodai Senga
# #13  C   Luis Torrens
# #2   2B  Luisangel Acuña
# #27  3B  Mark Vientos
# #32  P   Max Kranick
# #20  1B  Pete Alonso
# #75  P   Reed Garrett
# #55  P   Ryne Stanek
# #6   RF  Starling Marte
# #38  P   Tylor Megill
# #15  CF  Tyrone Taylor
#
# Player data saved to text_output/all_players.txt

# %%
from bs4 import BeautifulSoup
import re
from collections import Counter

# File paths
input_html_path = "docs/index.html"
output_html_path = "docs/index2.html"

# Read the HTML content
with open(input_html_path, "r") as input_file:
    html_content = input_file.read()

# Parse the HTML content
soup = BeautifulSoup(html_content, "html.parser")

# Extract all text from the HTML
text_content = soup.get_text()

# Define a regex pattern to match player names (assuming names are two words with capitalized initials)
player_name_pattern = r'\b[A-Z][a-z]+\s[A-Z][a-z]+\b'

# Find all player names in the text
player_names = re.findall(player_name_pattern, text_content)

# Count occurrences of each player name
player_counts = Counter(player_names)

# Get the top 5 players
top_players = player_counts.most_common(5)

# Create a dictionary to map players to their teams
player_teams = {}
for match in todays_matches:
    for leader in match['away_team_leaders_hr']:
        player_teams[leader['name']] = match['away_name']
    for leader in match['home_team_leaders_hr']:
        player_teams[leader['name']] = match['home_name']

# Prepare the top players list with their teams
top_players_with_teams = [
    f"{player} ({player_teams.get(player, 'Unknown Team')}) - {count} mentions"
    for player, count in top_players
]

# Create the HTML for the top players list
top_players_html = "<h2>Top Mentioned Players</h2><ul>"
for player_info in top_players_with_teams:
    top_players_html += f"<li>{player_info}</li>"
top_players_html += "</ul>"

# Prepend the top players list to the original HTML
body = soup.body
body.insert(0, BeautifulSoup(top_players_html, "html.parser"))

# Write the modified HTML to the new file
with open(output_html_path, "w") as output_file:
    output_file.write(str(soup))

print(f"Updated HTML file saved to {output_html_path}")

# %%
for match in todays_matches:

    if 'BvP_stats' in match:

        print("Batter vs Pitcher Stats:")
        for bvp in match['BvP_stats']:
            print()
            # print(f"Match: AWAY: {match['away_name']} vs HOME: {match['home_name']}")
            # print(f"Away Probable Pitcher: {match['away_probable_pitcher']}")
            # print(f"Home Probable Pitcher: {match['home_probable_pitcher']}")
            away = match['away_probable_pitcher']
            home = match['home_probable_pitcher']
            batter_name = bvp['bvp_matchup']
            if bvp['pitcher'] == away:
                print(f"Away Pitcher:  {bvp['pitcher']:<17} {match['away_name']:<25}")
                beans = 'away'
            elif bvp['pitcher'] == home:
                print(f"Home Pitcher:  {bvp['pitcher']:<17} {match['home_name']:<25}")
                beans = 'home'
            if beans == 'away':
                print(f"Home  Batter:  {bvp['batter']:<17} {match['home_name']:<25}")
            elif beans == 'home':
                print(f"Away  Batter:  {bvp['batter']:<17} {match['away_name']:<25}")
            # print(f"Pitcher: {bvp['pitcher']:>10}")
            print(f" AB: {bvp['bvp_stats'].get('atbats', 'N/A'):>7}")
            print(f"  H: {bvp['bvp_stats'].get('hits', 'N/A'):>7}")
            print(f" HR: {bvp['bvp_stats'].get('homeruns', 'N/A'):>7}")
            print(f"AVG: {bvp['bvp_stats'].get('avg', 'N/A'):>7}")
            print(f"RBI: {bvp['bvp_stats'].get('rbi', 'N/A'):>7}")
            print(f"obp: {bvp['bvp_stats'].get('obp', 'N/A'):>7}")
            print(f"ops: {bvp['bvp_stats'].get('ops', 'N/A'):>7}")
            print()

    print("\n")  # Print a newline for better readability between matches

# %%
for key, value in todays_matches[0].items():
    print(f"{key}: {value}")

# %%
"""
away_name: Chicago Cubs
home_name: Pittsburgh Pirates
away_id: 112
away_team_leaders_hr: [{'name': 'Carson Kelly', 'homeRuns': '7'}, {'name': 'Seiya Suzuki', 'homeRuns': '7'}, {'name': 'Kyle Tucker', 'homeRuns': '7'}, {'name': 'Pete Crow-Armstrong', 'homeRuns': '6'}, {'name': 'Michael Busch', 'homeRuns': '5'}, {'name': 'Dansby Swanson', 'homeRuns': '5'}, {'name': 'Miguel Amaya', 'homeRuns': '2'}, {'name': 'Ian Happ', 'homeRuns': '2'}, {'name': 'Matt Shaw', 'homeRuns': '1'}]
home_team_leaders_hr: [{'name': 'Oneil Cruz', 'homeRuns': '8'}, {'name': 'Andrew McCutchen', 'homeRuns': '3'}, {'name': 'Bryan Reynolds', 'homeRuns': '3'}, {'name': 'Enmanuel Valdez', 'homeRuns': '2'}, {'name': 'Joey Bart', 'homeRuns': '1'}, {'name': 'Alexander Canario', 'homeRuns': '1'}, {'name': 'Henry Davis', 'homeRuns': '1'}, {'name': 'Adam Frazier', 'homeRuns': '1'}, {'name': 'Nick Gonzales', 'homeRuns': '1'}, {'name': 'Matt Gorski', 'homeRuns': '1'}, {'name': "Ke'Bryan Hayes", 'homeRuns': '1'}]
home_id: 134
home_probable_pitcher: Paul Skenes
away_probable_pitcher: Colin Rea
BvP_stats: [{'bvp_stats': {'gamesplayed': 1, 'flyouts': None, 'groundouts': 1, 'airouts': 0, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 1, 'baseonballs': 1, 'intentionalwalks': 0, 'hits': 0, 'hitbypitch': 0, 'avg': '.000', 'atbats': 2, 'obp': '.333', 'slg': '.000', 'ops': '.333', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 19, 'plateappearances': 3, 'totalbases': 0, 'rbi': 0, 'leftonbase': 2, 'sacbunts': 0, 'sacflies': 0, 'babip': '.000', 'groundoutstoairouts': '1.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Colin Rea vs batter: Oneil Cruz', 'pitcher': 'Colin Rea', 'batter': 'Oneil Cruz'}, {'bvp_stats': {'gamesplayed': 4, 'flyouts': None, 'groundouts': 3, 'airouts': 2, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 2, 'baseonballs': 1, 'intentionalwalks': 0, 'hits': 2, 'hitbypitch': 0, 'avg': '.222', 'atbats': 9, 'obp': '.300', 'slg': '.222', 'ops': '.522', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 47, 'plateappearances': 10, 'totalbases': 2, 'rbi': 0, 'leftonbase': 5, 'sacbunts': 0, 'sacflies': 0, 'babip': '.286', 'groundoutstoairouts': '1.50', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Colin Rea vs batter: Andrew McCutchen', 'pitcher': 'Colin Rea', 'batter': 'Andrew McCutchen'}, {'bvp_stats': {'gamesplayed': 4, 'flyouts': None, 'groundouts': 2, 'airouts': 0, 'runs': None, 'doubles': 2, 'triples': 0, 'homeruns': 1, 'strikeouts': 3, 'baseonballs': 0, 'intentionalwalks': 0, 'hits': 7, 'hitbypitch': 0, 'avg': '.583', 'atbats': 12, 'obp': '.583', 'slg': '1.000', 'ops': '1.583', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 42, 'plateappearances': 12, 'totalbases': 12, 'rbi': 4, 'leftonbase': 3, 'sacbunts': 0, 'sacflies': 0, 'babip': '.750', 'groundoutstoairouts': '2.00', 'catchersinterference': 0, 'atbatsperhomerun': '12.00'}, 'bvp_matchup': 'pitcher: Colin Rea vs batter: Bryan Reynolds', 'pitcher': 'Colin Rea', 'batter': 'Bryan Reynolds'}, {'bvp_stats': {'gamesplayed': 3, 'flyouts': None, 'groundouts': 0, 'airouts': 2, 'runs': None, 'doubles': 1, 'triples': 0, 'homeruns': 0, 'strikeouts': 2, 'baseonballs': 0, 'intentionalwalks': 0, 'hits': 1, 'hitbypitch': 0, 'avg': '.200', 'atbats': 5, 'obp': '.200', 'slg': '.400', 'ops': '.600', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 21, 'plateappearances': 5, 'totalbases': 2, 'rbi': 1, 'leftonbase': 2, 'sacbunts': 0, 'sacflies': 0, 'babip': '.333', 'groundoutstoairouts': '0.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Colin Rea vs batter: Joey Bart', 'pitcher': 'Colin Rea', 'batter': 'Joey Bart'}, {'bvp_stats': {'gamesplayed': 1, 'flyouts': None, 'groundouts': 0, 'airouts': 0, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 1, 'strikeouts': 1, 'baseonballs': 0, 'intentionalwalks': 0, 'hits': 2, 'hitbypitch': 0, 'avg': '.667', 'atbats': 3, 'obp': '.667', 'slg': '1.667', 'ops': '2.334', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 8, 'plateappearances': 3, 'totalbases': 5, 'rbi': 2, 'leftonbase': 1, 'sacbunts': 0, 'sacflies': 0, 'babip': '1.000', 'groundoutstoairouts': '-.--', 'catchersinterference': 0, 'atbatsperhomerun': '3.00'}, 'bvp_matchup': 'pitcher: Colin Rea vs batter: Henry Davis', 'pitcher': 'Colin Rea', 'batter': 'Henry Davis'}, {'bvp_stats': {'gamesplayed': 1, 'flyouts': None, 'groundouts': 0, 'airouts': 2, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 1, 'baseonballs': 0, 'intentionalwalks': 0, 'hits': 0, 'hitbypitch': 0, 'avg': '.000', 'atbats': 3, 'obp': '.000', 'slg': '.000', 'ops': '.000', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 10, 'plateappearances': 3, 'totalbases': 0, 'rbi': 0, 'leftonbase': 2, 'sacbunts': 0, 'sacflies': 0, 'babip': '.000', 'groundoutstoairouts': '0.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Colin Rea vs batter: Adam Frazier', 'pitcher': 'Colin Rea', 'batter': 'Adam Frazier'}, {'bvp_stats': {'gamesplayed': 3, 'flyouts': None, 'groundouts': 1, 'airouts': 3, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 1, 'strikeouts': 0, 'baseonballs': 1, 'intentionalwalks': 0, 'hits': 4, 'hitbypitch': 0, 'avg': '.500', 'atbats': 8, 'obp': '.556', 'slg': '.875', 'ops': '1.431', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 28, 'plateappearances': 9, 'totalbases': 7, 'rbi': 3, 'leftonbase': 1, 'sacbunts': 0, 'sacflies': 0, 'babip': '.429', 'groundoutstoairouts': '0.33', 'catchersinterference': 0, 'atbatsperhomerun': '8.00'}, 'bvp_matchup': 'pitcher: Colin Rea vs batter: Nick Gonzales', 'pitcher': 'Colin Rea', 'batter': 'Nick Gonzales'}, {'bvp_stats': {'gamesplayed': 1, 'flyouts': None, 'groundouts': 0, 'airouts': 1, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 1, 'baseonballs': 0, 'intentionalwalks': 0, 'hits': 1, 'hitbypitch': 0, 'avg': '.333', 'atbats': 3, 'obp': '.333', 'slg': '.333', 'ops': '.666', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 14, 'plateappearances': 3, 'totalbases': 1, 'rbi': 0, 'leftonbase': 1, 'sacbunts': 0, 'sacflies': 0, 'babip': '.500', 'groundoutstoairouts': '0.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': "pitcher: Colin Rea vs batter: Ke'Bryan Hayes", 'pitcher': 'Colin Rea', 'batter': "Ke'Bryan Hayes"}, {'bvp_stats': {'gamesplayed': 1, 'flyouts': None, 'groundouts': 0, 'airouts': 1, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 0, 'baseonballs': 0, 'intentionalwalks': 0, 'hits': 1, 'hitbypitch': 0, 'avg': '.500', 'atbats': 2, 'obp': '.500', 'slg': '.500', 'ops': '1.000', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 6, 'plateappearances': 2, 'totalbases': 1, 'rbi': 0, 'leftonbase': 0, 'sacbunts': 0, 'sacflies': 0, 'babip': '.500', 'groundoutstoairouts': '0.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Paul Skenes vs batter: Carson Kelly', 'pitcher': 'Paul Skenes', 'batter': 'Carson Kelly'}, {'bvp_stats': {'gamesplayed': 3, 'flyouts': None, 'groundouts': 2, 'airouts': 1, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 4, 'baseonballs': 0, 'intentionalwalks': 0, 'hits': 2, 'hitbypitch': 0, 'avg': '.222', 'atbats': 9, 'obp': '.222', 'slg': '.222', 'ops': '.444', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 37, 'plateappearances': 9, 'totalbases': 2, 'rbi': 0, 'leftonbase': 6, 'sacbunts': 0, 'sacflies': 0, 'babip': '.400', 'groundoutstoairouts': '2.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Paul Skenes vs batter: Seiya Suzuki', 'pitcher': 'Paul Skenes', 'batter': 'Seiya Suzuki'}, {'bvp_stats': {'gamesplayed': 3, 'flyouts': None, 'groundouts': 2, 'airouts': 0, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 2, 'baseonballs': 0, 'intentionalwalks': 0, 'hits': 2, 'hitbypitch': 0, 'avg': '.333', 'atbats': 6, 'obp': '.333', 'slg': '.333', 'ops': '.666', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 21, 'plateappearances': 6, 'totalbases': 2, 'rbi': 1, 'leftonbase': 3, 'sacbunts': 0, 'sacflies': 0, 'babip': '.500', 'groundoutstoairouts': '2.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Paul Skenes vs batter: Pete Crow-Armstrong', 'pitcher': 'Paul Skenes', 'batter': 'Pete Crow-Armstrong'}, {'bvp_stats': {'gamesplayed': 4, 'flyouts': None, 'groundouts': 2, 'airouts': 0, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 5, 'baseonballs': 3, 'intentionalwalks': 0, 'hits': 0, 'hitbypitch': 0, 'avg': '.000', 'atbats': 7, 'obp': '.300', 'slg': '.000', 'ops': '.300', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 53, 'plateappearances': 10, 'totalbases': 0, 'rbi': 0, 'leftonbase': 3, 'sacbunts': 0, 'sacflies': 0, 'babip': '.000', 'groundoutstoairouts': '2.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Paul Skenes vs batter: Michael Busch', 'pitcher': 'Paul Skenes', 'batter': 'Michael Busch'}, {'bvp_stats': {'gamesplayed': 2, 'flyouts': None, 'groundouts': 0, 'airouts': 0, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 2, 'baseonballs': 1, 'intentionalwalks': 0, 'hits': 1, 'hitbypitch': 0, 'avg': '.333', 'atbats': 3, 'obp': '.500', 'slg': '.333', 'ops': '.833', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 18, 'plateappearances': 4, 'totalbases': 1, 'rbi': 0, 'leftonbase': 1, 'sacbunts': 0, 'sacflies': 0, 'babip': '1.000', 'groundoutstoairouts': '-.--', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Paul Skenes vs batter: Dansby Swanson', 'pitcher': 'Paul Skenes', 'batter': 'Dansby Swanson'}, {'bvp_stats': {'gamesplayed': 1, 'flyouts': None, 'groundouts': 2, 'airouts': 0, 'runs': None, 'doubles': 0, 'triples': 0, 'homeruns': 0, 'strikeouts': 0, 'baseonballs': 0, 'intentionalwalks': 0, 'hits': 0, 'hitbypitch': 0, 'avg': '.000', 'atbats': 2, 'obp': '.000', 'slg': '.000', 'ops': '.000', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 12, 'plateappearances': 2, 'totalbases': 0, 'rbi': 0, 'leftonbase': 0, 'sacbunts': 0, 'sacflies': 0, 'babip': '.000', 'groundoutstoairouts': '2.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Paul Skenes vs batter: Miguel Amaya', 'pitcher': 'Paul Skenes', 'batter': 'Miguel Amaya'}, {'bvp_stats': {'gamesplayed': 4, 'flyouts': None, 'groundouts': 2, 'airouts': 1, 'runs': None, 'doubles': 1, 'triples': 0, 'homeruns': 0, 'strikeouts': 5, 'baseonballs': 1, 'intentionalwalks': 0, 'hits': 1, 'hitbypitch': 0, 'avg': '.111', 'atbats': 9, 'obp': '.200', 'slg': '.222', 'ops': '.422', 'caughtstealing': None, 'stolenbases': None, 'stolenbasepercentage': None, 'groundintodoubleplay': 0, 'groundintotripleplay': 0, 'numberofpitches': 45, 'plateappearances': 10, 'totalbases': 2, 'rbi': 0, 'leftonbase': 2, 'sacbunts': 0, 'sacflies': 0, 'babip': '.250', 'groundoutstoairouts': '2.00', 'catchersinterference': 0, 'atbatsperhomerun': '-.--'}, 'bvp_matchup': 'pitcher: Paul Skenes vs batter: Ian Happ', 'pitcher': 'Paul Skenes', 'batter': 'Ian Happ'}]
"""
# import statsapi
# for y in todays_matches:
#     print(f"Match: AWAY: {y['away_name']} vs HOME: {y['home_name']}")
#     print()
#     print(f"Away Probable Pitcher: {y['away_probable_pitcher']}")
#     # get the stats for the away probable pitcher
#     beans = statsapi.player_stat_data(next(x['id'] for x in statsapi.get('sports_players',{'season':2025,'gameType':'W'})['people'] if x['fullName']==y.get('away_probable_pitcher')), 'pitching', 'career')
#     # Query the ERA stat
#     era1 = beans['stats'][0]['stats']['era']
#     print(f"    ERA: {era1}")
#     strikeouts1 = beans['stats'][0]['stats']['strikeoutsPer9Inn']
#     print(f"    Strikeouts per 9 Innings: {strikeouts1}")
#     print()
#     print(f"Home Probable Pitcher: {y['home_probable_pitcher']}")
#     # get the stats for the home probable pitcher
#     beans2 = statsapi.player_stat_data(next(x['id'] for x in statsapi.get('sports_players',{'season':2025,'gameType':'W'})['people'] if x['fullName']==y.get('home_probable_pitcher')), 'pitching', 'career')
#     era2 = beans2['stats'][0]['stats']['era']
#     print(f"    ERA: {era2}")
#     strikeouts2 = beans2['stats'][0]['stats']['strikeoutsPer9Inn']
#     print(f"    Strikeouts per 9 Innings: {strikeouts2}")
#     print()
#     # print(f"Away Team: {y['away_name']} (ID: {x['away_id']})")
#     print("Away Team Home Run Leaders:")
#     for leader in y['away_team_leaders_hr']:
#         print(f"  - {leader['name']}: {leader['homeRuns']} HR")

#     print()
#     # print(f"Home Team: {y['home_name']} (ID: {x['home_id']})")
#     print("Home Team Home Run Leaders:")
#     for leader in y['home_team_leaders_hr']:
#         print(f"  - {leader['name']}: {leader['homeRuns']} HR")
#     print()

#
