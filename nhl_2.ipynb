# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_matchups_to_json(url):
    """
    Scrapes the team matchups section from the given URL and converts it to JSON format.

    Args:
        url (str): The URL of the webpage to scrape.

    Returns:
        dict: A dictionary containing the scraped matchups data.
    """
    # Send a GET request to the webpage
    response = requests.get(url)
    response.raise_for_status()  # Raise an exception for HTTP errors

    # Parse the webpage content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the matchups section
    matchups = []
    matchup_divs = soup.find_all('div', class_='matchup')  # Adjust class name based on the webpage structure

    for div in matchup_divs:
        # Extract team names, winning chances, and other details
        teams = div.find_all('img', alt=True)
        team1 = teams[0]['alt']
        team2 = teams[1]['alt']

        winning_chances = div.find_all('div', class_='winning-chance')  # Adjust class name
        chance1 = winning_chances[0].text.strip()
        chance2 = winning_chances[1].text.strip()

        starters = div.find_all('div', class_='starter')  # Adjust class name
        starter1 = starters[0].text.strip()
        starter2 = starters[1].text.strip()

        sources = div.find_all('div', class_='source')  # Adjust class name
        source1 = sources[0].text.strip()
        source2 = sources[1].text.strip()

        matchups.append({
            "team1": team1,
            "team2": team2,
            "chance1": chance1,
            "chance2": chance2,
            "starter1": starter1,
            "starter2": starter2,
            "source1": source1,
            "source2": source2
        })

    # Convert the matchups data to JSON format
    matchups_json = json.dumps(matchups, indent=4)
    return matchups_json


# Example usage
url = "https://moneypuck.com/"
matchups_json = scrape_matchups_to_json(url)
print(matchups_json)
# Out:
# []

# %%
from requests_html import HTMLSession

def scrape_matchups_with_requests_html(url):
    """
    Scrapes the team matchups section from the given URL using requests-html.

    Args:
        url (str): The URL of the webpage to scrape.

    Returns:
        dict: A dictionary containing the scraped matchups data.
    """
    session = HTMLSession()
    response = session.get(url)
    response.html.render()  # Render JavaScript

    # Parse the rendered HTML
    matchups = []
    matchup_divs = response.html.find('.matchup')  # Adjust selector based on the webpage structure

    for div in matchup_divs:
        team1 = div.find('.team1', first=True).text
        team2 = div.find('.team2', first=True).text
        chance1 = div.find('.chance1', first=True).text
        chance2 = div.find('.chance2', first=True).text
        starter1 = div.find('.starter1', first=True).text
        starter2 = div.find('.starter2', first=True).text
        source1 = div.find('.source1', first=True).text
        source2 = div.find('.source2', first=True).text

        matchups.append({
            "team1": team1,
            "team2": team2,
            "chance1": chance1,
            "chance2": chance2,
            "starter1": starter1,
            "starter2": starter2,
            "source1": source1,
            "source2": source2
        })

    return matchups


# Example usage
url = "https://moneypuck.com/"
matchups = scrape_matchups_with_requests_html(url)
print(matchups)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 47
#      45 # Example usage
#      46 url = "https://moneypuck.com/"
# ---> 47 matchups = scrape_matchups_with_requests_html(url)
#      48 print(matchups)
#
# Cell In[3], line 15, in scrape_matchups_with_requests_html(url)
#      13 session = HTMLSession()
#      14 response = session.get(url)
# ---> 15 response.html.render()  # Render JavaScript
#      17 # Parse the rendered HTML
#      18 matchups = []
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/requests_html.py:586, in HTML.render(self, retries, script, wait, scrolldown, sleep, reload, timeout, keep_page)
#     541 def render(self, retries: int = 8, script: str = None, wait: float = 0.2, scrolldown=False, sleep: int = 0, reload: bool = True, timeout: Union[float, int] = 8.0, keep_page: bool = False):
#     542     """Reloads the response in Chromium, and replaces HTML content
#     543     with an updated version, with JavaScript executed.
#     544
#    (...)    583     Chromium into your home directory (``~/.pyppeteer``).
#     584     """
# --> 586     self.browser = self.session.browser  # Automatically create a event loop and browser
#     587     content = None
#     589     # Automatically set Reload to False, if example URL is being used.
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/requests_html.py:729, in HTMLSession.browser(self)
#     727     self.loop = asyncio.get_event_loop()
#     728     if self.loop.is_running():
# --> 729         raise RuntimeError("Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.")
#     730     self._browser = self.loop.run_until_complete(super().browser)
#     731 return self._browser
#
# RuntimeError: Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.

# %%
from requests_html import HTMLSession

def scrape_matchups_with_requests_html(url):
    """
    Scrapes the team matchups section from the given URL using requests-html.

    Args:
        url (str): The URL of the webpage to scrape.

    Returns:
        dict: A dictionary containing the scraped matchups data.
    """
    session = HTMLSession()
    response = session.get(url)

    try:
        response.html.render(timeout=30)  # Render JavaScript with a timeout
    except Exception as e:
        print(f"Error rendering JavaScript: {e}")
        return []

    # Parse the rendered HTML
    matchups = []
    matchup_divs = response.html.find('.matchup')  # Adjust selector based on the webpage structure

    for div in matchup_divs:
        try:
            team1 = div.find('.team1', first=True).text
            team2 = div.find('.team2', first=True).text
            chance1 = div.find('.chance1', first=True).text
            chance2 = div.find('.chance2', first=True).text
            starter1 = div.find('.starter1', first=True).text
            starter2 = div.find('.starter2', first=True).text
            source1 = div.find('.source1', first=True).text
            source2 = div.find('.source2', first=True).text

            matchups.append({
                "team1": team1,
                "team2": team2,
                "chance1": chance1,
                "chance2": chance2,
                "starter1": starter1,
                "starter2": starter2,
                "source1": source1,
                "source2": source2
            })
        except AttributeError:
            print("Error parsing matchup data. Skipping...")
            continue

    return matchups


# Example usage
url = "https://moneypuck.com/"
matchups = scrape_matchups_with_requests_html(url)
print(matchups)
# Out:
# Error rendering JavaScript: Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.
# []
