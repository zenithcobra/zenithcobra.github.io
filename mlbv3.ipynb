# %%
import statsapi
import mlbstatsapi

mlb = mlbstatsapi.Mlb()
batter_id = mlb.get_people_id('Pete Alonso')[0]
pitcher_id = mlb.get_people_id('Griffin Canning')[0]

stats = ['vsPlayer']
group = ['hitting']
params = {'opposingPlayerId': pitcher_id, 'season': 2025}

stats = mlb.get_player_stats(batter_id, stats=stats, groups=group, **params)
vs_player_total = stats['hitting']['vsplayertotal']
for split in vs_player_total.splits:
    for k, v in split.stat.__dict__.items():
            print(k, v)
# Out:
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/624413/stats
# gamesplayed 2
# flyouts None
# groundouts 2
# airouts 1
# runs None
# doubles 0
# triples 0
# homeruns 0
# strikeouts 2
# baseonballs 0
# intentionalwalks 0
# hits 1
# hitbypitch 0
# avg .167
# atbats 6
# obp .167
# slg .167
# ops .334
# caughtstealing None
# stolenbases None
# stolenbasepercentage None
# groundintodoubleplay 1
# groundintotripleplay 0
# numberofpitches 20
# plateappearances 6
# totalbases 1
# rbi 0
# leftonbase 6
# sacbunts 0
# sacflies 0
# babip .250
# groundoutstoairouts 2.00
# catchersinterference 0
# atbatsperhomerun -.--

# %%
import statsapi
import mlbstatsapi
from datetime import datetime

# Get today's schedule
matches_today = []

# get the proper formatted date
mlb_date = datetime.now().strftime("%m/%d/%Y")

# get the schedule as a dictionary for today
schedule = statsapi.schedule(start_date=mlb_date, end_date=mlb_date)

# iterate through each game of the schedule
for x in schedule:

    # initialize game data dictionary
    game_data = {}
    
    # away_name
    game_data.update({'away_name': x.get('away_name')}) 
    
    # home_name
    game_data.update({'home_name': x.get('home_name')})
    
    # away_id
    game_data.update({'away_id': x.get('away_id')})

    away_team_leaders_hr = []
    # add top away team guys here
    away_leaders = statsapi.team_leader_data(x.get('away_id'), 'homeRuns', season=2025, leaderGameTypes="R", limit=10)
    for z in away_leaders:
        away_team_leaders_hr.append({'name': z[1],'homeRuns': z[2]})

    game_data.update({'away_team_leaders_hr': away_team_leaders_hr})

    home_team_leaders_hr = []
    # add top away team guys here
    home_leaders = statsapi.team_leader_data(x.get('home_id'), 'homeRuns', season=2025, leaderGameTypes="R", limit=10)
    for z in home_leaders:
        home_team_leaders_hr.append({'name': z[1],'homeRuns': z[2]})

    game_data.update({'home_team_leaders_hr': home_team_leaders_hr})

    # home_id
    game_data.update({'home_id': x.get('home_id')})
    # home_probable_pitcher
    game_data.update({'home_probable_pitcher': x.get('home_probable_pitcher')})
    # away_probable_pitcher
    game_data.update({'away_probable_pitcher': x.get('away_probable_pitcher')})

    matches_today.append(game_data)




mlb = mlbstatsapi.Mlb()

for x in matches_today:
    pitcher_id = mlb.get_people_id(x.get('away_probable_pitcher'))[0]
    
    BvP = []
    for y in x.get('home_team_leaders_hr'):
        batter_id = mlb.get_people_id(y.get('name'))[0]

        stats = ['vsPlayer']
        group = ['hitting']
        params = {'opposingPlayerId': pitcher_id, 'season': 2025}

        # stats = mlb.get_player_stats(batter_id, stats=stats, groups=group, **params)
        # vs_player_total = stats['hitting']['vsplayertotal']
        # for split in vs_player_total.splits:
        #     for k, v in split.stat.__dict__.items():
        #             print(k, v)
        try:
            stats = mlb.get_player_stats(batter_id, stats=stats, groups=group, **params)
            # Attempt to access 'hitting' key
            vs_player_total = stats['hitting']['vsplayertotal']
            for split in vs_player_total.splits:
                # for k, v in split.stat.__dict__.items():
                #     print(k, v)
                # print(split)
                # print(split.stat.__dict__.items())
                p_id = mlb.get_person(pitcher_id)
                b_id = mlb.get_person(batter_id)
                
                # add this info to the dictionary for matches to print a formatted copy later
                bvp_matchup = f'pitcher: {p_id.__dict__.get('fullname')} vs batter: {b_id.__dict__.get('fullname')}'
                dict2 = {'bvp_stats': split.stat.__dict__}
                dict2.update({'bvp_matchup': bvp_matchup})
                BvP.append(dict2)


        except KeyError as e:
            # Handle missing 'hitting' key or other KeyErrors
            #print(f"KeyError: {e}. Skipping this player. Stats: {stats}")
            yellow = 1
        except Exception as e:
            # Handle any other unexpected errors
            #print(f"Unexpected error: {e}. Skipping this player.")
            yellow = 2
    # add the BvP stats to the matches_today dictionary
    x.update({'BvP_stats': BvP})
# Out:
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/695578/stats
# https://statsapi.mlb.com/api/v1/people/656288
# https://statsapi.mlb.com/api/v1/people/695578
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/682928/stats
# https://statsapi.mlb.com/api/v1/people/656288
# https://statsapi.mlb.com/api/v1/people/682928
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/605137/stats
# https://statsapi.mlb.com/api/v1/people/656288
# https://statsapi.mlb.com/api/v1/people/605137
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/686611/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/663993/stats
# https://statsapi.mlb.com/api/v1/people/656288
# https://statsapi.mlb.com/api/v1/people/663993
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/660688/stats
# https://statsapi.mlb.com/api/v1/people/656288
# https://statsapi.mlb.com/api/v1/people/660688
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/656180/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/671277/stats
# https://statsapi.mlb.com/api/v1/people/656288
# https://statsapi.mlb.com/api/v1/people/671277
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/642708/stats
# https://statsapi.mlb.com/api/v1/people/656288
# https://statsapi.mlb.com/api/v1/people/642708
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/700932/stats
# https://statsapi.mlb.com/api/v1/people/641927
# https://statsapi.mlb.com/api/v1/people/700932
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/608070/stats
# https://statsapi.mlb.com/api/v1/people/641927
# https://statsapi.mlb.com/api/v1/people/608070
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/672356/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/680757/stats
# https://statsapi.mlb.com/api/v1/people/641927
# https://statsapi.mlb.com/api/v1/people/680757
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/595978/stats
# https://statsapi.mlb.com/api/v1/people/641927
# https://statsapi.mlb.com/api/v1/people/595978
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/666310/stats
# https://statsapi.mlb.com/api/v1/people/641927
# https://statsapi.mlb.com/api/v1/people/666310
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/467793/stats
# https://statsapi.mlb.com/api/v1/people/641927
# https://statsapi.mlb.com/api/v1/people/467793
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/682177/stats
# https://statsapi.mlb.com/api/v1/people/641927
# https://statsapi.mlb.com/api/v1/people/682177
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/666134/stats
# https://statsapi.mlb.com/api/v1/people/641927
# https://statsapi.mlb.com/api/v1/people/666134
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/678877/stats
# https://statsapi.mlb.com/api/v1/people/641927
# https://statsapi.mlb.com/api/v1/people/678877
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/656775/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/656811/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/668939/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/676059/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/677008/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/657656/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/683002/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/702616/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/641933/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/681297/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/663624/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/602104/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/682829/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/682829
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/669720/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/669720
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/680574/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/680574
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/682622/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/682622
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/642851/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/642851
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/600869/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/600869
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/687952/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/687952
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/641584/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/641584
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/668715/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/668715
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/694362/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/670770/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/670770
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/666158/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/666158
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/624431/stats
# https://statsapi.mlb.com/api/v1/people/669467
# https://statsapi.mlb.com/api/v1/people/624431
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/694671/stats
# https://statsapi.mlb.com/api/v1/people/676664
# https://statsapi.mlb.com/api/v1/people/694671
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/666969/stats
# https://statsapi.mlb.com/api/v1/people/676664
# https://statsapi.mlb.com/api/v1/people/666969
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/641680/stats
# https://statsapi.mlb.com/api/v1/people/676664
# https://statsapi.mlb.com/api/v1/people/641680
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/608369/stats
# https://statsapi.mlb.com/api/v1/people/676664
# https://statsapi.mlb.com/api/v1/people/608369
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/669394/stats
# https://statsapi.mlb.com/api/v1/people/676664
# https://statsapi.mlb.com/api/v1/people/669394
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/673962/stats
# https://statsapi.mlb.com/api/v1/people/676664
# https://statsapi.mlb.com/api/v1/people/673962
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/543760/stats
# https://statsapi.mlb.com/api/v1/people/676664
# https://statsapi.mlb.com/api/v1/people/543760
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/669701/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/687957/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/543309/stats
# https://statsapi.mlb.com/api/v1/people/676664
# https://statsapi.mlb.com/api/v1/people/543309
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/665750/stats
# https://statsapi.mlb.com/api/v1/people/676664
# https://statsapi.mlb.com/api/v1/people/665750
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/670623/stats
# https://statsapi.mlb.com/api/v1/people/656427
# https://statsapi.mlb.com/api/v1/people/670623
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/514888/stats
# https://statsapi.mlb.com/api/v1/people/656427
# https://statsapi.mlb.com/api/v1/people/514888
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/670541/stats
# https://statsapi.mlb.com/api/v1/people/656427
# https://statsapi.mlb.com/api/v1/people/670541
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/665161/stats
# https://statsapi.mlb.com/api/v1/people/656427
# https://statsapi.mlb.com/api/v1/people/665161
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/701358/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/572233/stats
# https://statsapi.mlb.com/api/v1/people/656427
# https://statsapi.mlb.com/api/v1/people/572233
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/673237/stats
# https://statsapi.mlb.com/api/v1/people/656427
# https://statsapi.mlb.com/api/v1/people/673237
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/687597/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/696100/stats
# https://statsapi.mlb.com/api/v1/people/693821
# https://statsapi.mlb.com/api/v1/people/696100
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/686668/stats
# https://statsapi.mlb.com/api/v1/people/693821
# https://statsapi.mlb.com/api/v1/people/686668
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/666160/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/641857/stats
# https://statsapi.mlb.com/api/v1/people/693821
# https://statsapi.mlb.com/api/v1/people/641857
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/669911/stats
# https://statsapi.mlb.com/api/v1/people/693821
# https://statsapi.mlb.com/api/v1/people/669911
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/691182/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/656248/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/690924/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/691728/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/669242/stats
# https://statsapi.mlb.com/api/v1/people/665795
# https://statsapi.mlb.com/api/v1/people/669242
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/606192/stats
# https://statsapi.mlb.com/api/v1/people/665795
# https://statsapi.mlb.com/api/v1/people/606192
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/660271/stats
# https://statsapi.mlb.com/api/v1/people/665795
# https://statsapi.mlb.com/api/v1/people/660271
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/571771/stats
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/681624/stats
# https://statsapi.mlb.com/api/v1/people/665795
# https://statsapi.mlb.com/api/v1/people/681624
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/605141/stats
# https://statsapi.mlb.com/api/v1/people/665795
# https://statsapi.mlb.com/api/v1/people/605141
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/518692/stats
# https://statsapi.mlb.com/api/v1/people/665795
# https://statsapi.mlb.com/api/v1/people/518692
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/669257/stats
# https://statsapi.mlb.com/api/v1/people/665795
# https://statsapi.mlb.com/api/v1/people/669257
# https://statsapi.mlb.com/api/v1/sports/1/players
# https://statsapi.mlb.com/api/v1/people/624424/stats
# https://statsapi.mlb.com/api/v1/people/665795
# https://statsapi.mlb.com/api/v1/people/624424

# %%
# for x in matches_today:
#     print(x)
# for x in matches_today:
#     for k, v in x.items():
#         print(f'key: {k} value: {v}')

# Print a readable output of each item in the dictionary of the list matches_today
for match in matches_today:
    print(f"Match: {match['away_name']} vs {match['home_name']}")
    print(f"Away Team ID: {match['away_id']}, Home Team ID: {match['home_id']}")
    print(f"Away Probable Pitcher: {match['away_probable_pitcher']}")
    print(f"Home Probable Pitcher: {match['home_probable_pitcher']}")
    
    print("Away Team Leaders in Home Runs:")
    for leader in match['away_team_leaders_hr']:
        print(f"  {leader['name']}: {leader['homeRuns']} HR")
    
    print("Home Team Leaders in Home Runs:")
    for leader in match['home_team_leaders_hr']:
        print(f"  {leader['name']}: {leader['homeRuns']} HR")
    
    if 'BvP_stats' in match:
        print("Batter vs Pitcher Stats:")
        for bvp in match['BvP_stats']:
            print(f"  Matchup: {bvp['bvp_matchup']}")
            for stat, value in bvp['bvp_stats'].items():
                print(f"    {stat}: {value}")
    
    print("\n")  # Print a newline for better readability between matches
# Out:
# Match: New York Mets vs Washington Nationals
# Away Team ID: 121, Home Team ID: 120
# Away Probable Pitcher: Griffin Canning
# Home Probable Pitcher: Trevor Williams
# Away Team Leaders in Home Runs:
#   Pete Alonso: 6 HR
#   Francisco Lindor: 5 HR
#   Brandon Nimmo: 4 HR
#   Juan Soto: 3 HR
#   Mark Vientos: 2 HR
#   Francisco Alvarez: 1 HR
#   Brett Baty: 1 HR
#   Starling Marte: 1 HR
#   Luis Torrens: 1 HR
#   Jesse Winker: 1 HR
# Home Team Leaders in Home Runs:
#   James Wood: 8 HR
#   CJ Abrams: 4 HR
#   Josh Bell: 4 HR
#   Dylan Crews: 4 HR
#   Nathaniel Lowe: 4 HR
#   Keibert Ruiz: 2 HR
#   Riley Adams: 1 HR
#   Luis García Jr.: 1 HR
#   Amed Rosario: 1 HR
# Batter vs Pitcher Stats:
#   Matchup: pitcher: Griffin Canning vs batter: James Wood
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 1
#     runs: None
#     doubles: 1
#     triples: 0
#     homeruns: 1
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .667
#     atbats: 3
#     obp: .667
#     slg: 2.000
#     ops: 2.667
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 12
#     plateappearances: 3
#     totalbases: 6
#     rbi: 2
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: .500
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: 3.00
#   Matchup: pitcher: Griffin Canning vs batter: CJ Abrams
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 1
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 2
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 7
#     plateappearances: 2
#     totalbases: 0
#     rbi: 0
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Griffin Canning vs batter: Josh Bell
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: 1.000
#     atbats: 1
#     obp: 1.000
#     slg: 1.000
#     ops: 2.000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 8
#     plateappearances: 2
#     totalbases: 1
#     rbi: 1
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: 1.000
#     groundoutstoairouts: -.--
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Griffin Canning vs batter: Nathaniel Lowe
#     gamesplayed: 6
#     flyouts: None
#     groundouts: 4
#     airouts: 2
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 2
#     strikeouts: 4
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 3
#     hitbypitch: 0
#     avg: .231
#     atbats: 13
#     obp: .231
#     slg: .692
#     ops: .923
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 1
#     groundintotripleplay: 0
#     numberofpitches: 52
#     plateappearances: 13
#     totalbases: 9
#     rbi: 3
#     leftonbase: 7
#     sacbunts: 0
#     sacflies: 0
#     babip: .143
#     groundoutstoairouts: 2.00
#     catchersinterference: 0
#     atbatsperhomerun: 6.50
#   Matchup: pitcher: Griffin Canning vs batter: Keibert Ruiz
#     gamesplayed: 2
#     flyouts: None
#     groundouts: 1
#     airouts: 2
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .400
#     atbats: 5
#     obp: .400
#     slg: .400
#     ops: .800
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 16
#     plateappearances: 5
#     totalbases: 2
#     rbi: 0
#     leftonbase: 1
#     sacbunts: 0
#     sacflies: 0
#     babip: .400
#     groundoutstoairouts: 0.50
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Griffin Canning vs batter: Luis García Jr.
#     gamesplayed: 2
#     flyouts: None
#     groundouts: 5
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 5
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 2
#     groundintotripleplay: 0
#     numberofpitches: 13
#     plateappearances: 5
#     totalbases: 0
#     rbi: 1
#     leftonbase: 5
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 5.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Griffin Canning vs batter: Amed Rosario
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 1
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .667
#     atbats: 3
#     obp: .667
#     slg: 1.333
#     ops: 2.000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 10
#     plateappearances: 3
#     totalbases: 4
#     rbi: 1
#     leftonbase: 1
#     sacbunts: 0
#     sacflies: 0
#     babip: .667
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#
#
# Match: Minnesota Twins vs Cleveland Guardians
# Away Team ID: 142, Home Team ID: 114
# Away Probable Pitcher: Bailey Ober
# Home Probable Pitcher: Gavin Williams
# Away Team Leaders in Home Runs:
#   Byron Buxton: 6 HR
#   Trevor Larnach: 4 HR
#   Harrison Bader: 3 HR
#   Ty France: 2 HR
#   Willi Castro: 1 HR
#   Carlos Correa: 1 HR
#   Edouard Julien: 1 HR
#   Brooks Lee: 1 HR
#   Jose Miranda: 1 HR
#   Matt Wallner: 1 HR
# Home Team Leaders in Home Runs:
#   Kyle Manzardo: 7 HR
#   José Ramírez: 5 HR
#   Gabriel Arias: 4 HR
#   Steven Kwan: 4 HR
#   Austin Hedges: 2 HR
#   Bo Naylor: 2 HR
#   Carlos Santana: 2 HR
#   Daniel Schneemann: 2 HR
#   Nolan Jones: 1 HR
#   Jhonkensy Noel: 1 HR
# Batter vs Pitcher Stats:
#   Matchup: pitcher: Bailey Ober vs batter: Kyle Manzardo
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 2
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 2
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 8
#     plateappearances: 2
#     totalbases: 0
#     rbi: 0
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Bailey Ober vs batter: José Ramírez
#     gamesplayed: 8
#     flyouts: None
#     groundouts: 4
#     airouts: 7
#     runs: None
#     doubles: 2
#     triples: 0
#     homeruns: 1
#     strikeouts: 2
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 6
#     hitbypitch: 1
#     avg: .316
#     atbats: 19
#     obp: .381
#     slg: .579
#     ops: .960
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 1
#     groundintotripleplay: 0
#     numberofpitches: 72
#     plateappearances: 21
#     totalbases: 11
#     rbi: 3
#     leftonbase: 4
#     sacbunts: 0
#     sacflies: 0
#     babip: .313
#     groundoutstoairouts: 0.57
#     catchersinterference: 0
#     atbatsperhomerun: 19.00
#   Matchup: pitcher: Bailey Ober vs batter: Steven Kwan
#     gamesplayed: 4
#     flyouts: None
#     groundouts: 3
#     airouts: 9
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 12
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 46
#     plateappearances: 12
#     totalbases: 0
#     rbi: 0
#     leftonbase: 7
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 0.33
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Bailey Ober vs batter: Austin Hedges
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 1
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 1
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 2
#     plateappearances: 1
#     totalbases: 0
#     rbi: 0
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Bailey Ober vs batter: Bo Naylor
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 1
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 4
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 6
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 28
#     plateappearances: 6
#     totalbases: 0
#     rbi: 0
#     leftonbase: 3
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Bailey Ober vs batter: Carlos Santana
#     gamesplayed: 5
#     flyouts: None
#     groundouts: 2
#     airouts: 6
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 2
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 10
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 1
#     groundintotripleplay: 0
#     numberofpitches: 40
#     plateappearances: 10
#     totalbases: 0
#     rbi: 0
#     leftonbase: 7
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 0.33
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Bailey Ober vs batter: Daniel Schneemann
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 2
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 2
#     obp: .333
#     slg: .000
#     ops: .333
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 14
#     plateappearances: 3
#     totalbases: 0
#     rbi: 0
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: .---
#     groundoutstoairouts: -.--
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Bailey Ober vs batter: Nolan Jones
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 1
#     strikeouts: 2
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: .333
#     atbats: 3
#     obp: .333
#     slg: 1.333
#     ops: 1.666
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 19
#     plateappearances: 3
#     totalbases: 4
#     rbi: 1
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: .---
#     groundoutstoairouts: -.--
#     catchersinterference: 0
#     atbatsperhomerun: 3.00
#   Matchup: pitcher: Bailey Ober vs batter: Jhonkensy Noel
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 2
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 3
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 12
#     plateappearances: 3
#     totalbases: 0
#     rbi: 0
#     leftonbase: 1
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#
#
# Match: New York Yankees vs Baltimore Orioles
# Away Team ID: 147, Home Team ID: 110
# Away Probable Pitcher: Will Warren
# Home Probable Pitcher: Tomoyuki Sugano
# Away Team Leaders in Home Runs:
#   Aaron Judge: 8 HR
#   Jazz Chisholm Jr.: 7 HR
#   Trent Grisham: 7 HR
#   Ben Rice: 6 HR
#   Anthony Volpe: 5 HR
#   Austin Wells: 4 HR
#   Cody Bellinger: 2 HR
#   Jasson Domínguez: 2 HR
#   Oswaldo Cabrera: 1 HR
#   J.C. Escarra: 1 HR
#   Paul Goldschmidt: 1 HR
#   Oswald Peraza: 1 HR
# Home Team Leaders in Home Runs:
#   Cedric Mullins: 6 HR
#   Ryan O'Hearn: 4 HR
#   Adley Rutschman: 4 HR
#   Jordan Westburg: 4 HR
#   Heston Kjerstad: 3 HR
#   Ramón Laureano: 3 HR
#   Gunnar Henderson: 2 HR
#   Jackson Holliday: 2 HR
#   Tyler O'Neill: 2 HR
#   Colton Cowser: 1 HR
#   Ryan Mountcastle: 1 HR
#   Ramón Urías: 1 HR
# Batter vs Pitcher Stats:
#
#
# Match: St. Louis Cardinals vs Cincinnati Reds
# Away Team ID: 138, Home Team ID: 113
# Away Probable Pitcher: Andre Pallante
# Home Probable Pitcher: Nick Martinez
# Away Team Leaders in Home Runs:
#   Iván Herrera: 4 HR
#   Lars Nootbaar: 4 HR
#   Nolan Arenado: 3 HR
#   Brendan Donovan: 3 HR
#   Willson Contreras: 2 HR
#   Jordan Walker: 2 HR
#   Nolan Gorman: 1 HR
#   Pedro Pagés: 1 HR
#   Yohel Pozo: 1 HR
#   Thomas Saggese: 1 HR
#   Victor Scott II: 1 HR
#   Masyn Winn: 1 HR
# Home Team Leaders in Home Runs:
#   Elly De La Cruz: 5 HR
#   Austin Hays: 5 HR
#   Matt McLain: 4 HR
#   Noelvi Marte: 3 HR
#   Austin Wynns: 3 HR
#   Jeimer Candelario: 2 HR
#   Christian Encarnacion-Strand: 2 HR
#   Jake Fraley: 2 HR
#   Spencer Steer: 2 HR
#   Blake Dunn: 1 HR
#   TJ Friedl: 1 HR
#   Gavin Lux: 1 HR
#   Jose Trevino: 1 HR
# Batter vs Pitcher Stats:
#   Matchup: pitcher: Andre Pallante vs batter: Elly De La Cruz
#     gamesplayed: 5
#     flyouts: None
#     groundouts: 5
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 2
#     baseonballs: 2
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .222
#     atbats: 9
#     obp: .364
#     slg: .222
#     ops: .586
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 43
#     plateappearances: 11
#     totalbases: 2
#     rbi: 0
#     leftonbase: 8
#     sacbunts: 0
#     sacflies: 0
#     babip: .286
#     groundoutstoairouts: 5.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Austin Hays
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 1
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 1
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 2
#     plateappearances: 1
#     totalbases: 0
#     rbi: 0
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Matt McLain
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 1
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 2
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 9
#     plateappearances: 2
#     totalbases: 0
#     rbi: 0
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Noelvi Marte
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 2
#     airouts: 2
#     runs: None
#     doubles: 1
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: .200
#     atbats: 5
#     obp: .200
#     slg: .400
#     ops: .600
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 14
#     plateappearances: 5
#     totalbases: 2
#     rbi: 2
#     leftonbase: 4
#     sacbunts: 0
#     sacflies: 0
#     babip: .200
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Austin Wynns
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 1
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 1
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 1
#     groundintotripleplay: 0
#     numberofpitches: 3
#     plateappearances: 1
#     totalbases: 0
#     rbi: 0
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Jeimer Candelario
#     gamesplayed: 2
#     flyouts: None
#     groundouts: 1
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 3
#     obp: .250
#     slg: .000
#     ops: .250
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 18
#     plateappearances: 4
#     totalbases: 0
#     rbi: 1
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Christian Encarnacion-Strand
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: 1.000
#     atbats: 1
#     obp: 1.000
#     slg: 1.000
#     ops: 2.000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 2
#     plateappearances: 1
#     totalbases: 1
#     rbi: 0
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: 1.000
#     groundoutstoairouts: -.--
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Jake Fraley
#     gamesplayed: 5
#     flyouts: None
#     groundouts: 3
#     airouts: 3
#     runs: None
#     doubles: 1
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 3
#     hitbypitch: 0
#     avg: .333
#     atbats: 9
#     obp: .400
#     slg: .444
#     ops: .844
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 1
#     groundintotripleplay: 0
#     numberofpitches: 33
#     plateappearances: 10
#     totalbases: 4
#     rbi: 1
#     leftonbase: 9
#     sacbunts: 0
#     sacflies: 0
#     babip: .333
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Spencer Steer
#     gamesplayed: 4
#     flyouts: None
#     groundouts: 0
#     airouts: 2
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 3
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 1
#     avg: .286
#     atbats: 7
#     obp: .444
#     slg: .286
#     ops: .730
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 34
#     plateappearances: 9
#     totalbases: 2
#     rbi: 0
#     leftonbase: 1
#     sacbunts: 0
#     sacflies: 0
#     babip: .500
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: TJ Friedl
#     gamesplayed: 8
#     flyouts: None
#     groundouts: 7
#     airouts: 2
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 3
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .143
#     atbats: 14
#     obp: .200
#     slg: .143
#     ops: .343
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 44
#     plateappearances: 15
#     totalbases: 2
#     rbi: 2
#     leftonbase: 9
#     sacbunts: 0
#     sacflies: 0
#     babip: .182
#     groundoutstoairouts: 3.50
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Gavin Lux
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 3
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 2
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 5
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 15
#     plateappearances: 5
#     totalbases: 0
#     rbi: 0
#     leftonbase: 3
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 3.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Andre Pallante vs batter: Jose Trevino
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 1
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: .500
#     atbats: 2
#     obp: .500
#     slg: .500
#     ops: 1.000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 10
#     plateappearances: 2
#     totalbases: 1
#     rbi: 0
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 0
#     babip: .500
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#
#
# Match: Athletics vs Texas Rangers
# Away Team ID: 133, Home Team ID: 140
# Away Probable Pitcher: JP Sears
# Home Probable Pitcher: Patrick Corbin
# Away Team Leaders in Home Runs:
#   Tyler Soderstrom: 9 HR
#   Brent Rooker: 7 HR
#   Shea Langeliers: 5 HR
#   Lawrence Butler: 4 HR
#   Luis Urías: 4 HR
#   Jacob Wilson: 3 HR
#   Miguel Andujar: 2 HR
#   JJ Bleday: 2 HR
#   Seth Brown: 1 HR
#   Max Muncy: 1 HR
# Home Team Leaders in Home Runs:
#   Wyatt Langford: 6 HR
#   Adolis García: 4 HR
#   Jonah Heim: 4 HR
#   Corey Seager: 4 HR
#   Jake Burger: 3 HR
#   Josh Jung: 2 HR
#   Marcus Semien: 2 HR
#   Josh Smith: 2 HR
#   Dustin Harris: 1 HR
#   Kyle Higashioka: 1 HR
#   Leody Taveras: 1 HR
# Batter vs Pitcher Stats:
#   Matchup: pitcher: JP Sears vs batter: Wyatt Langford
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 3
#     airouts: 3
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 1
#     strikeouts: 1
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: .125
#     atbats: 8
#     obp: .222
#     slg: .500
#     ops: .722
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 31
#     plateappearances: 9
#     totalbases: 4
#     rbi: 1
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: 8.00
#   Matchup: pitcher: JP Sears vs batter: Adolis García
#     gamesplayed: 9
#     flyouts: None
#     groundouts: 4
#     airouts: 9
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 7
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 4
#     hitbypitch: 0
#     avg: .167
#     atbats: 24
#     obp: .167
#     slg: .167
#     ops: .334
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 81
#     plateappearances: 24
#     totalbases: 4
#     rbi: 2
#     leftonbase: 14
#     sacbunts: 0
#     sacflies: 0
#     babip: .235
#     groundoutstoairouts: 0.44
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: JP Sears vs batter: Jonah Heim
#     gamesplayed: 7
#     flyouts: None
#     groundouts: 3
#     airouts: 7
#     runs: None
#     doubles: 2
#     triples: 0
#     homeruns: 1
#     strikeouts: 2
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 4
#     hitbypitch: 0
#     avg: .267
#     atbats: 15
#     obp: .294
#     slg: .600
#     ops: .894
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 68
#     plateappearances: 17
#     totalbases: 9
#     rbi: 4
#     leftonbase: 5
#     sacbunts: 0
#     sacflies: 1
#     babip: .231
#     groundoutstoairouts: 0.43
#     catchersinterference: 0
#     atbatsperhomerun: 15.00
#   Matchup: pitcher: JP Sears vs batter: Corey Seager
#     gamesplayed: 5
#     flyouts: None
#     groundouts: 3
#     airouts: 3
#     runs: None
#     doubles: 1
#     triples: 0
#     homeruns: 0
#     strikeouts: 5
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .154
#     atbats: 13
#     obp: .214
#     slg: .231
#     ops: .445
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 47
#     plateappearances: 14
#     totalbases: 3
#     rbi: 1
#     leftonbase: 5
#     sacbunts: 0
#     sacflies: 0
#     babip: .250
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: JP Sears vs batter: Jake Burger
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 2
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 6
#     plateappearances: 2
#     totalbases: 0
#     rbi: 0
#     leftonbase: 1
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: JP Sears vs batter: Josh Jung
#     gamesplayed: 5
#     flyouts: None
#     groundouts: 3
#     airouts: 3
#     runs: None
#     doubles: 1
#     triples: 0
#     homeruns: 0
#     strikeouts: 3
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 4
#     hitbypitch: 0
#     avg: .308
#     atbats: 13
#     obp: .308
#     slg: .385
#     ops: .693
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 58
#     plateappearances: 13
#     totalbases: 5
#     rbi: 0
#     leftonbase: 6
#     sacbunts: 0
#     sacflies: 0
#     babip: .400
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: JP Sears vs batter: Marcus Semien
#     gamesplayed: 9
#     flyouts: None
#     groundouts: 6
#     airouts: 8
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 2
#     strikeouts: 4
#     baseonballs: 2
#     intentionalwalks: 0
#     hits: 6
#     hitbypitch: 1
#     avg: .250
#     atbats: 24
#     obp: .333
#     slg: .500
#     ops: .833
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 98
#     plateappearances: 27
#     totalbases: 12
#     rbi: 5
#     leftonbase: 8
#     sacbunts: 0
#     sacflies: 0
#     babip: .222
#     groundoutstoairouts: 0.75
#     catchersinterference: 0
#     atbatsperhomerun: 12.00
#   Matchup: pitcher: JP Sears vs batter: Kyle Higashioka
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 0
#     airouts: 2
#     runs: None
#     doubles: 1
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .400
#     atbats: 5
#     obp: .500
#     slg: .600
#     ops: 1.100
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 27
#     plateappearances: 6
#     totalbases: 3
#     rbi: 1
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 0
#     babip: .500
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: JP Sears vs batter: Leody Taveras
#     gamesplayed: 8
#     flyouts: None
#     groundouts: 4
#     airouts: 3
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 1
#     strikeouts: 6
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 1
#     avg: .133
#     atbats: 15
#     obp: .235
#     slg: .333
#     ops: .568
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 64
#     plateappearances: 17
#     totalbases: 5
#     rbi: 2
#     leftonbase: 11
#     sacbunts: 0
#     sacflies: 0
#     babip: .125
#     groundoutstoairouts: 1.33
#     catchersinterference: 0
#     atbatsperhomerun: 15.00
#
#
# Match: Detroit Tigers vs Houston Astros
# Away Team ID: 116, Home Team ID: 117
# Away Probable Pitcher: Jack Flaherty
# Home Probable Pitcher: Ronel Blanco
# Away Team Leaders in Home Runs:
#   Spencer Torkelson: 8 HR
#   Kerry Carpenter: 5 HR
#   Riley Greene: 4 HR
#   Dillon Dingler: 3 HR
#   Andy Ibáñez: 2 HR
#   Gleyber Torres: 2 HR
#   Justyn-Henry Malloy: 1 HR
#   Zach McKinstry: 1 HR
#   Trey Sweeney: 1 HR
# Home Team Leaders in Home Runs:
#   Isaac Paredes: 4 HR
#   Jose Altuve: 3 HR
#   Yordan Alvarez: 3 HR
#   Jeremy Peña: 3 HR
#   Cam Smith: 3 HR
#   Christian Walker: 3 HR
#   Yainer Diaz: 2 HR
# Batter vs Pitcher Stats:
#   Matchup: pitcher: Jack Flaherty vs batter: Isaac Paredes
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 1
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .400
#     atbats: 5
#     obp: .500
#     slg: .400
#     ops: .900
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 28
#     plateappearances: 6
#     totalbases: 2
#     rbi: 0
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: .500
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Jack Flaherty vs batter: Jose Altuve
#     gamesplayed: 4
#     flyouts: None
#     groundouts: 1
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 5
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 3
#     hitbypitch: 0
#     avg: .300
#     atbats: 10
#     obp: .300
#     slg: .300
#     ops: .600
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 43
#     plateappearances: 10
#     totalbases: 3
#     rbi: 1
#     leftonbase: 4
#     sacbunts: 0
#     sacflies: 0
#     babip: .600
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Jack Flaherty vs batter: Yordan Alvarez
#     gamesplayed: 4
#     flyouts: None
#     groundouts: 3
#     airouts: 2
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 2
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 1
#     avg: .125
#     atbats: 8
#     obp: .222
#     slg: .125
#     ops: .347
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 37
#     plateappearances: 9
#     totalbases: 1
#     rbi: 0
#     leftonbase: 6
#     sacbunts: 0
#     sacflies: 0
#     babip: .167
#     groundoutstoairouts: 1.50
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Jack Flaherty vs batter: Jeremy Peña
#     gamesplayed: 4
#     flyouts: None
#     groundouts: 1
#     airouts: 4
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 3
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: .111
#     atbats: 9
#     obp: .111
#     slg: .111
#     ops: .222
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 32
#     plateappearances: 9
#     totalbases: 1
#     rbi: 0
#     leftonbase: 4
#     sacbunts: 0
#     sacflies: 0
#     babip: .167
#     groundoutstoairouts: 0.25
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Jack Flaherty vs batter: Christian Walker
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 2
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 3
#     baseonballs: 2
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: .167
#     atbats: 6
#     obp: .333
#     slg: .167
#     ops: .500
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 39
#     plateappearances: 9
#     totalbases: 1
#     rbi: 1
#     leftonbase: 3
#     sacbunts: 0
#     sacflies: 1
#     babip: .250
#     groundoutstoairouts: 2.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Jack Flaherty vs batter: Yainer Diaz
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 4
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 5
#     obp: .167
#     slg: .000
#     ops: .167
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 2
#     groundintotripleplay: 0
#     numberofpitches: 21
#     plateappearances: 6
#     totalbases: 0
#     rbi: 0
#     leftonbase: 4
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 4.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#
#
# Match: Atlanta Braves vs Colorado Rockies
# Away Team ID: 144, Home Team ID: 115
# Away Probable Pitcher: Bryce Elder
# Home Probable Pitcher: Ryan Feltner
# Away Team Leaders in Home Runs:
#   Sean Murphy: 7 HR
#   Austin Riley: 6 HR
#   Marcell Ozuna: 5 HR
#   Ozzie Albies: 4 HR
#   Matt Olson: 4 HR
#   Michael Harris II: 3 HR
#   Drake Baldwin: 2 HR
#   Jarred Kelenic: 2 HR
#   Eli White: 2 HR
# Home Team Leaders in Home Runs:
#   Jordan Beck: 5 HR
#   Hunter Goodman: 4 HR
#   Brenton Doyle: 3 HR
#   Mickey Moniak: 3 HR
#   Ryan McMahon: 2 HR
#   Michael Toglia: 2 HR
#   Adael Amador: 1 HR
#   Sean Bouchard: 1 HR
#   Braxton Fulford: 1 HR
#   Zac Veen: 1 HR
# Batter vs Pitcher Stats:
#   Matchup: pitcher: Bryce Elder vs batter: Hunter Goodman
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 0
#     runs: None
#     doubles: 1
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .667
#     atbats: 3
#     obp: .667
#     slg: 1.000
#     ops: 1.667
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 10
#     plateappearances: 3
#     totalbases: 3
#     rbi: 1
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: 1.000
#     groundoutstoairouts: -.--
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Bryce Elder vs batter: Brenton Doyle
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 1
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 2
#     obp: .000
#     slg: .000
#     ops: .000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 8
#     plateappearances: 2
#     totalbases: 0
#     rbi: 0
#     leftonbase: 1
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Bryce Elder vs batter: Ryan McMahon
#     gamesplayed: 2
#     flyouts: None
#     groundouts: 0
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 1
#     strikeouts: 2
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .500
#     atbats: 4
#     obp: .500
#     slg: 1.250
#     ops: 1.750
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 32
#     plateappearances: 6
#     totalbases: 5
#     rbi: 2
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 1
#     babip: .500
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: 4.00
#   Matchup: pitcher: Bryce Elder vs batter: Michael Toglia
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 2
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: .333
#     atbats: 3
#     obp: .333
#     slg: .333
#     ops: .666
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 8
#     plateappearances: 3
#     totalbases: 1
#     rbi: 0
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 0
#     babip: .333
#     groundoutstoairouts: 2.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#
#
# Match: Miami Marlins vs Los Angeles Dodgers
# Away Team ID: 146, Home Team ID: 119
# Away Probable Pitcher: Edward Cabrera
# Home Probable Pitcher: Dustin May
# Away Team Leaders in Home Runs:
#   Matt Mervis: 7 HR
#   Agustín Ramírez: 3 HR
#   Eric Wagaman: 3 HR
#   Otto Lopez: 2 HR
#   Kyle Stowers: 2 HR
#   Griffin Conine: 1 HR
#   Liam Hicks: 1 HR
#   Derek Hill: 1 HR
#   Dane Myers: 1 HR
#   Connor Norby: 1 HR
#   Javier Sanoja: 1 HR
#   Jesús Sánchez: 1 HR
# Home Team Leaders in Home Runs:
#   Tommy Edman: 8 HR
#   Teoscar Hernández: 8 HR
#   Shohei Ohtani: 6 HR
#   Enrique Hernández: 5 HR
#   Andy Pages: 5 HR
#   Mookie Betts: 4 HR
#   Freddie Freeman: 4 HR
#   Will Smith: 3 HR
#   Michael Conforto: 2 HR
# Batter vs Pitcher Stats:
#   Matchup: pitcher: Edward Cabrera vs batter: Tommy Edman
#     gamesplayed: 1
#     flyouts: None
#     groundouts: 0
#     airouts: 0
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: .500
#     atbats: 2
#     obp: .500
#     slg: .500
#     ops: 1.000
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 12
#     plateappearances: 2
#     totalbases: 1
#     rbi: 0
#     leftonbase: 1
#     sacbunts: 0
#     sacflies: 0
#     babip: 1.000
#     groundoutstoairouts: -.--
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Edward Cabrera vs batter: Teoscar Hernández
#     gamesplayed: 2
#     flyouts: None
#     groundouts: 0
#     airouts: 2
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 2
#     obp: .333
#     slg: .000
#     ops: .333
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 9
#     plateappearances: 3
#     totalbases: 0
#     rbi: 0
#     leftonbase: 0
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Edward Cabrera vs batter: Shohei Ohtani
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 2
#     airouts: 1
#     runs: None
#     doubles: 1
#     triples: 0
#     homeruns: 0
#     strikeouts: 0
#     baseonballs: 2
#     intentionalwalks: 0
#     hits: 2
#     hitbypitch: 0
#     avg: .400
#     atbats: 5
#     obp: .571
#     slg: .600
#     ops: 1.171
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 1
#     groundintotripleplay: 0
#     numberofpitches: 25
#     plateappearances: 7
#     totalbases: 3
#     rbi: 1
#     leftonbase: 3
#     sacbunts: 0
#     sacflies: 0
#     babip: .400
#     groundoutstoairouts: 2.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Edward Cabrera vs batter: Andy Pages
#     gamesplayed: 2
#     flyouts: None
#     groundouts: 0
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 0
#     avg: .000
#     atbats: 2
#     obp: .333
#     slg: .000
#     ops: .333
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 12
#     plateappearances: 3
#     totalbases: 0
#     rbi: 1
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Edward Cabrera vs batter: Mookie Betts
#     gamesplayed: 4
#     flyouts: None
#     groundouts: 1
#     airouts: 3
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 1
#     strikeouts: 2
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 1
#     hitbypitch: 0
#     avg: .143
#     atbats: 7
#     obp: .250
#     slg: .571
#     ops: .821
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 33
#     plateappearances: 8
#     totalbases: 4
#     rbi: 1
#     leftonbase: 4
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 0.33
#     catchersinterference: 0
#     atbatsperhomerun: 7.00
#   Matchup: pitcher: Edward Cabrera vs batter: Freddie Freeman
#     gamesplayed: 5
#     flyouts: None
#     groundouts: 1
#     airouts: 4
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 2
#     baseonballs: 2
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 1
#     avg: .000
#     atbats: 7
#     obp: .300
#     slg: .000
#     ops: .300
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 50
#     plateappearances: 10
#     totalbases: 0
#     rbi: 0
#     leftonbase: 6
#     sacbunts: 0
#     sacflies: 0
#     babip: .000
#     groundoutstoairouts: 0.25
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Edward Cabrera vs batter: Will Smith
#     gamesplayed: 3
#     flyouts: None
#     groundouts: 1
#     airouts: 1
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 0
#     strikeouts: 1
#     baseonballs: 1
#     intentionalwalks: 0
#     hits: 0
#     hitbypitch: 1
#     avg: .000
#     atbats: 2
#     obp: .400
#     slg: .000
#     ops: .400
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 24
#     plateappearances: 5
#     totalbases: 0
#     rbi: 1
#     leftonbase: 2
#     sacbunts: 0
#     sacflies: 1
#     babip: .000
#     groundoutstoairouts: 1.00
#     catchersinterference: 0
#     atbatsperhomerun: -.--
#   Matchup: pitcher: Edward Cabrera vs batter: Michael Conforto
#     gamesplayed: 5
#     flyouts: None
#     groundouts: 0
#     airouts: 4
#     runs: None
#     doubles: 0
#     triples: 0
#     homeruns: 1
#     strikeouts: 2
#     baseonballs: 0
#     intentionalwalks: 0
#     hits: 4
#     hitbypitch: 2
#     avg: .400
#     atbats: 10
#     obp: .500
#     slg: .700
#     ops: 1.200
#     caughtstealing: None
#     stolenbases: None
#     stolenbasepercentage: None
#     groundintodoubleplay: 0
#     groundintotripleplay: 0
#     numberofpitches: 47
#     plateappearances: 12
#     totalbases: 7
#     rbi: 5
#     leftonbase: 4
#     sacbunts: 0
#     sacflies: 0
#     babip: .429
#     groundoutstoairouts: 0.00
#     catchersinterference: 0
#     atbatsperhomerun: 10.00

# %%
for x in matches_today:
    print(f"Game: {x['away_name']} at {x['home_name']}")
    print(f"Away Team ID: {x['away_id']}, Home Team ID: {x['home_id']}")
    print(f"Away Probable Pitcher ID: {x['away_probable_pitcher']}, Home Probable Pitcher ID: {x['home_probable_pitcher']}")
    
    print("Away Team Leaders in Home Runs:")
    for leader in x['away_team_leaders_hr']:
        print(f"  {leader['name']}: {leader['homeRuns']} HR")
    
    print("Home Team Leaders in Home Runs:")
    for leader in x['home_team_leaders_hr']:
        print(f"  {leader['name']}: {leader['homeRuns']} HR")
    
    print("\n")  # Print a newline for better readability between games
# Out:
# Game: New York Mets at Washington Nationals
# Away Team ID: 121, Home Team ID: 120
# Away Probable Pitcher ID: Griffin Canning, Home Probable Pitcher ID: Trevor Williams
# Away Team Leaders in Home Runs:
#   Pete Alonso: 6 HR
#   Francisco Lindor: 5 HR
#   Brandon Nimmo: 4 HR
#   Juan Soto: 3 HR
#   Mark Vientos: 2 HR
#   Francisco Alvarez: 1 HR
#   Brett Baty: 1 HR
#   Starling Marte: 1 HR
#   Luis Torrens: 1 HR
#   Jesse Winker: 1 HR
# Home Team Leaders in Home Runs:
#   James Wood: 8 HR
#   CJ Abrams: 4 HR
#   Josh Bell: 4 HR
#   Dylan Crews: 4 HR
#   Nathaniel Lowe: 4 HR
#   Keibert Ruiz: 2 HR
#   Riley Adams: 1 HR
#   Luis García Jr.: 1 HR
#   Amed Rosario: 1 HR
#
#
# Game: Minnesota Twins at Cleveland Guardians
# Away Team ID: 142, Home Team ID: 114
# Away Probable Pitcher ID: Bailey Ober, Home Probable Pitcher ID: Gavin Williams
# Away Team Leaders in Home Runs:
#   Byron Buxton: 6 HR
#   Trevor Larnach: 4 HR
#   Harrison Bader: 3 HR
#   Ty France: 2 HR
#   Willi Castro: 1 HR
#   Carlos Correa: 1 HR
#   Edouard Julien: 1 HR
#   Brooks Lee: 1 HR
#   Jose Miranda: 1 HR
#   Matt Wallner: 1 HR
# Home Team Leaders in Home Runs:
#   Kyle Manzardo: 7 HR
#   José Ramírez: 5 HR
#   Gabriel Arias: 4 HR
#   Steven Kwan: 4 HR
#   Austin Hedges: 2 HR
#   Bo Naylor: 2 HR
#   Carlos Santana: 2 HR
#   Daniel Schneemann: 2 HR
#   Nolan Jones: 1 HR
#   Jhonkensy Noel: 1 HR
#
#
# Game: New York Yankees at Baltimore Orioles
# Away Team ID: 147, Home Team ID: 110
# Away Probable Pitcher ID: Will Warren, Home Probable Pitcher ID: Tomoyuki Sugano
# Away Team Leaders in Home Runs:
#   Aaron Judge: 8 HR
#   Jazz Chisholm Jr.: 7 HR
#   Trent Grisham: 7 HR
#   Ben Rice: 6 HR
#   Anthony Volpe: 5 HR
#   Austin Wells: 4 HR
#   Cody Bellinger: 2 HR
#   Jasson Domínguez: 2 HR
#   Oswaldo Cabrera: 1 HR
#   J.C. Escarra: 1 HR
#   Paul Goldschmidt: 1 HR
#   Oswald Peraza: 1 HR
# Home Team Leaders in Home Runs:
#   Cedric Mullins: 6 HR
#   Ryan O'Hearn: 4 HR
#   Adley Rutschman: 4 HR
#   Jordan Westburg: 4 HR
#   Heston Kjerstad: 3 HR
#   Ramón Laureano: 3 HR
#   Gunnar Henderson: 2 HR
#   Jackson Holliday: 2 HR
#   Tyler O'Neill: 2 HR
#   Colton Cowser: 1 HR
#   Ryan Mountcastle: 1 HR
#   Ramón Urías: 1 HR
#
#
# Game: St. Louis Cardinals at Cincinnati Reds
# Away Team ID: 138, Home Team ID: 113
# Away Probable Pitcher ID: Andre Pallante, Home Probable Pitcher ID: Nick Martinez
# Away Team Leaders in Home Runs:
#   Iván Herrera: 4 HR
#   Lars Nootbaar: 4 HR
#   Nolan Arenado: 3 HR
#   Brendan Donovan: 3 HR
#   Willson Contreras: 2 HR
#   Jordan Walker: 2 HR
#   Nolan Gorman: 1 HR
#   Pedro Pagés: 1 HR
#   Yohel Pozo: 1 HR
#   Thomas Saggese: 1 HR
#   Victor Scott II: 1 HR
#   Masyn Winn: 1 HR
# Home Team Leaders in Home Runs:
#   Elly De La Cruz: 5 HR
#   Austin Hays: 5 HR
#   Matt McLain: 4 HR
#   Noelvi Marte: 3 HR
#   Austin Wynns: 3 HR
#   Jeimer Candelario: 2 HR
#   Christian Encarnacion-Strand: 2 HR
#   Jake Fraley: 2 HR
#   Spencer Steer: 2 HR
#   Blake Dunn: 1 HR
#   TJ Friedl: 1 HR
#   Gavin Lux: 1 HR
#   Jose Trevino: 1 HR
#
#
# Game: Athletics at Texas Rangers
# Away Team ID: 133, Home Team ID: 140
# Away Probable Pitcher ID: JP Sears, Home Probable Pitcher ID: Patrick Corbin
# Away Team Leaders in Home Runs:
#   Tyler Soderstrom: 9 HR
#   Brent Rooker: 7 HR
#   Shea Langeliers: 5 HR
#   Lawrence Butler: 4 HR
#   Luis Urías: 4 HR
#   Jacob Wilson: 3 HR
#   Miguel Andujar: 2 HR
#   JJ Bleday: 2 HR
#   Seth Brown: 1 HR
#   Max Muncy: 1 HR
# Home Team Leaders in Home Runs:
#   Wyatt Langford: 6 HR
#   Adolis García: 4 HR
#   Jonah Heim: 4 HR
#   Corey Seager: 4 HR
#   Jake Burger: 3 HR
#   Josh Jung: 2 HR
#   Marcus Semien: 2 HR
#   Josh Smith: 2 HR
#   Dustin Harris: 1 HR
#   Kyle Higashioka: 1 HR
#   Leody Taveras: 1 HR
#
#
# Game: Detroit Tigers at Houston Astros
# Away Team ID: 116, Home Team ID: 117
# Away Probable Pitcher ID: Jack Flaherty, Home Probable Pitcher ID: Ronel Blanco
# Away Team Leaders in Home Runs:
#   Spencer Torkelson: 8 HR
#   Kerry Carpenter: 5 HR
#   Riley Greene: 4 HR
#   Dillon Dingler: 3 HR
#   Andy Ibáñez: 2 HR
#   Gleyber Torres: 2 HR
#   Justyn-Henry Malloy: 1 HR
#   Zach McKinstry: 1 HR
#   Trey Sweeney: 1 HR
# Home Team Leaders in Home Runs:
#   Isaac Paredes: 4 HR
#   Jose Altuve: 3 HR
#   Yordan Alvarez: 3 HR
#   Jeremy Peña: 3 HR
#   Cam Smith: 3 HR
#   Christian Walker: 3 HR
#   Yainer Diaz: 2 HR
#
#
# Game: Atlanta Braves at Colorado Rockies
# Away Team ID: 144, Home Team ID: 115
# Away Probable Pitcher ID: Bryce Elder, Home Probable Pitcher ID: Ryan Feltner
# Away Team Leaders in Home Runs:
#   Sean Murphy: 7 HR
#   Austin Riley: 6 HR
#   Marcell Ozuna: 5 HR
#   Ozzie Albies: 4 HR
#   Matt Olson: 4 HR
#   Michael Harris II: 3 HR
#   Drake Baldwin: 2 HR
#   Jarred Kelenic: 2 HR
#   Eli White: 2 HR
# Home Team Leaders in Home Runs:
#   Jordan Beck: 5 HR
#   Hunter Goodman: 4 HR
#   Brenton Doyle: 3 HR
#   Mickey Moniak: 3 HR
#   Ryan McMahon: 2 HR
#   Michael Toglia: 2 HR
#   Adael Amador: 1 HR
#   Sean Bouchard: 1 HR
#   Braxton Fulford: 1 HR
#   Zac Veen: 1 HR
#
#
# Game: Miami Marlins at Los Angeles Dodgers
# Away Team ID: 146, Home Team ID: 119
# Away Probable Pitcher ID: Edward Cabrera, Home Probable Pitcher ID: Dustin May
# Away Team Leaders in Home Runs:
#   Matt Mervis: 7 HR
#   Agustín Ramírez: 3 HR
#   Eric Wagaman: 3 HR
#   Otto Lopez: 2 HR
#   Kyle Stowers: 2 HR
#   Griffin Conine: 1 HR
#   Liam Hicks: 1 HR
#   Derek Hill: 1 HR
#   Dane Myers: 1 HR
#   Connor Norby: 1 HR
#   Javier Sanoja: 1 HR
#   Jesús Sánchez: 1 HR
# Home Team Leaders in Home Runs:
#   Tommy Edman: 8 HR
#   Teoscar Hernández: 8 HR
#   Shohei Ohtani: 6 HR
#   Enrique Hernández: 5 HR
#   Andy Pages: 5 HR
#   Mookie Betts: 4 HR
#   Freddie Freeman: 4 HR
#   Will Smith: 3 HR
#   Michael Conforto: 2 HR

# %% [markdown]
# # Games today
#
# ## YESTERDAY RESULTS
# [link to GAME_REPORT]
#
# ## STANDINGS
#
# ## TODAYS SCHEDULE
#
# ## TOP 7 LEAGUE_LEADERS
#
# ## Game #X
#
# HOME [name] vs AWAY [name]
#
# HOME [team leaders ['homeRuns']
# AWAY [team leaders ['homeRuns']
#
# HOME [probable pitcher]
# GET top 7 AWAY leaders and compare stats against pitcher
#
# AWAY [probable pitcher]
# GET top 7 HOME leaders and compare stats against pitcher
