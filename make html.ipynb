# %%
import importlib
import script

# Reload the script after making changes
importlib.reload(script)
print('make index')
index_html = script.make_index()
# save_to_text(index_html, 'raw_index')

# index_html = make_index()
processed_html = script.process_html(index_html)
# print(processed_html)
script.save_to_html(processed_html,'index')
# Out:
# make index
# Archived file already exists: data/archived_data/all_team_data_2025-08-27.json
# Today's data saved to data/all_team_data.json
# Archived file already exists: data/archived_data/teams_table.html_2025-08-27.txt
# Today's data saved to data/teams_table.html.txt
# Today's data saved to data/schedule_view.txt.txt
# Archived file already exists: data/archived_data/styled_schedule_view.html_2025-08-27.txt
# Today's data saved to data/styled_schedule_view.html.txt
# Archived file already exists: docs/archived_data/index_2025-08-27.html
# Today's data saved to docs/index.html

# %%
import importlib
import script

# Reload the script after making changes
importlib.reload(script)
# script.make_index()

# team_data_path = "data/team_data.json"
# team_data = script.read_json_file(team_data_path)
# ballpark_data_path = "data/ballpark_data.json"
# ballpark_data = script.read_json_file(ballpark_data_path)
# schedule_data_path = 'data/schedule_data.json'
# schedule_data = script.read_json_file(schedule_data_path)
# print(schedule_data)
# team_data_table = script.generate_team_html_table(team_data, ballpark_data, schedule_data)
# save_to_text(team_data_table,'team_data_table')
# print(team_data_table)
# team_table_data = script.parse_html_table(team_data_table)


import importlib
import script
import statsapi

# Reload the script after making changes
importlib.reload(script)

# RUNNING THE SCRIPT 

print('script getting date')
# DATES
# date = script.get_date()
# print(date)

# print('script getting yesterdays report')
# # YESTERDAYS REPORT
# yesterdays_report = script.get_yesterdays_report()
# script.save_list_to_text(yesterdays_report,'yesterdays_report_text')


# print('script getting schedule')
# # SCHEDULE INFO
date = '07/14/2025'
schedule = statsapi.schedule(start_date='07/13/2025', end_date='07/13/2025')
# schedule = script.get_schedule_by_date(date)
print(schedule)
# processed_schedule = script.process_the_schedule(schedule)
# schedule_text = script.get_schedule_text()
# script.save_to_json(schedule,'schedule_data')
# script.save_to_text(schedule_text, 'schedule_text')


# print('script getting standings')
# # STANDINGS
# standings_text = script.get_standings_text()
# script.save_to_text(standings_text, "standings_text")


# print('script getting team info')
# # TEAMS PLAYING TODAY and History and Records
# teams_today = script.get_teams_playing_today_from_processed_schedule(processed_schedule)
# team_history = script.get_team_history(teams_today)
# team_wins = script.get_team_records(team_history)
# ballparks = script.scrape_ballparks_table_to_json()
# script.save_to_json(teams_today, 'teams_playing_today_data')
# script.save_to_json(team_wins, 'team_data')
# script.save_to_json(ballparks, 'ballpark_data')


# print('script  getting pitchers')
# # PITCHERS
# pitchers_today = script.process_pitchers_from_processed_schedule(processed_schedule)
# processed_pitchers = script.add_stats_to_pitchers(pitchers_today)
# script.save_to_json(processed_pitchers,"pitcher_data")


# print('script getting batters')
# # BATTERS
# rooster = script.process_players_from_roster_into_list(processed_schedule)
# batters = script.add_stats_to_batters(rooster)
# batters_with_streaks = script.process_batters(batters,team_history)
# batter_vs_pitcher = script.old_batter_vs_pitchers_get()
# batter_vs_pitcher_with_streaks = script.get_streaks_for_bvp(batter_vs_pitcher,batters_with_streaks)
# todays_dh_batters = script.find_dh_batters_add_stats_streaks(schedule, batters_with_streaks)
# yesterdays_home_runs = script.get_yesterdays_homers(batters_with_streaks)
# script.save_to_json(batters_with_streaks, "batter_data")
# script.save_to_json(batter_vs_pitcher_with_streaks,'batter_vs_pitcher_data')
# script.save_to_json(todays_dh_batters, 'dh_batter_data')
# script.save_to_json(yesterdays_home_runs,'yesterday_home_run_data')


# print('script getting league leaders')
# # LEAGUE LEADERS
# eras_leaders = script.league_leaders_era()
# so9_leaders = script.league_leaders_strikeouts_per_9_innings()
# hr_leaders = script.league_leaders_hrs()
# script.save_to_json(eras_leaders, 'ERA_leader_data')
# script.save_to_json(so9_leaders, 'SO9_leader_data')
# script.save_to_json(hr_leaders, 'HR_leader_data')


# print('make index')
# index_html = script.make_index()
# script.save_to_text(index_html, 'raw_index')

# # index_html = make_index()
# processed_html = script.process_html(index_html)
# # print(processed_html)
# script.save_to_html(processed_html,'index')
# Out:
# script getting date
# [{'game_id': 777130, 'game_datetime': '2025-07-13T17:35:00Z', 'game_date': '2025-07-13', 'game_type': 'R', 'status': 'Final', 'away_name': 'Tampa Bay Rays', 'home_name': 'Boston Red Sox', 'away_id': 139, 'home_id': 111, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Brayan Bello', 'away_probable_pitcher': 'Ryan Pepiot', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': 1, 'home_score': 4, 'current_inning': 9, 'inning_state': 'Top', 'venue_id': 3, 'venue_name': 'Fenway Park', 'national_broadcasts': ['MLBN (out-of-market only)'], 'series_status': 'BOS wins 4-0', 'winning_team': 'Boston Red Sox', 'losing_team': 'Tampa Bay Rays', 'winning_pitcher': 'Brayan Bello', 'losing_pitcher': 'Ryan Pepiot', 'save_pitcher': 'Aroldis Chapman', 'summary': '2025-07-13 - Tampa Bay Rays (1) @ Boston Red Sox (4) (Final)'}, {'game_id': 777129, 'game_datetime': '2025-07-13T17:35:00Z', 'game_date': '2025-07-13', 'game_type': 'R', 'status': 'Final', 'away_name': 'Miami Marlins', 'home_name': 'Baltimore Orioles', 'away_id': 146, 'home_id': 110, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Brandon Young', 'away_probable_pitcher': 'Eury Pérez', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': 11, 'home_score': 1, 'current_inning': 9, 'inning_state': 'Bottom', 'venue_id': 2, 'venue_name': 'Oriole Park at Camden Yards', 'national_broadcasts': [], 'series_status': 'MIA wins 2-1', 'winning_team': 'Miami Marlins', 'losing_team': 'Baltimore Orioles', 'winning_pitcher': 'Eury Pérez', 'losing_pitcher': 'Brandon Young', 'save_pitcher': None, 'summary': '2025-07-13 - Miami Marlins (11) @ Baltimore Orioles (1) (Final)'}, {'game_id': 777122, 'game_datetime': '2025-07-13T17:35:00Z', 'game_date': '2025-07-13', 'game_type': 'R', 'status': 'Final', 'away_name': 'Chicago Cubs', 'home_name': 'New York Yankees', 'away_id': 112, 'home_id': 147, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Will Warren', 'away_probable_pitcher': 'Shota Imanaga', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': 4, 'home_score': 1, 'current_inning': 9, 'inning_state': 'Bottom', 'venue_id': 3313, 'venue_name': 'Yankee Stadium', 'national_broadcasts': ['MLBN (out-of-market only)'], 'series_status': 'CHC wins 2-1', 'winning_team': 'Chicago Cubs', 'losing_team': 'New York Yankees', 'winning_pitcher': 'Shota Imanaga', 'losing_pitcher': 'Will Warren', 'save_pitcher': 'Daniel Palencia', 'summary': '2025-07-13 - Chicago Cubs (4) @ New York Yankees (1) (Final)'}, {'game_id': 777128, 'game_datetime': '2025-07-13T17:40:00Z', 'game_date': '2025-07-13', 'game_type': 'R', 'status': 'Final', 'away_name': 'Colorado Rockies', 'home_name': 'Cincinnati Reds', 'away_id': 115, 'home_id': 113, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Nick Martinez', 'away_probable_pitcher': 'Austin Gomber', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': 2, 'home_score': 4, 'current_inning': 9, 'inning_state': 'Top', 'venue_id': 2602, 'venue_name': 'Great American Ball Park', 'national_broadcasts': [], 'series_status': 'CIN wins 2-1', 'winning_team': 'Cincinnati Reds', 'losing_team': 'Colorado Rockies', 'winning_pitcher': 'Nick Martinez', 'losing_pitcher': 'Austin Gomber', 'save_pitcher': 'Emilio Pagán', 'summary': '2025-07-13 - Colorado Rockies (2) @ Cincinnati Reds (4) (Final)'}, {'game_id': 777121, 'game_datetime': '2025-07-13T17:40:00Z', 'game_date': '2025-07-13', 'game_type': 'R', 'status': 'Final', 'away_name': 'Seattle Mariners', 'home_name': 'Detroit Tigers', 'away_id': 136, 'home_id': 116, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Jack Flaherty', 'away_probable_pitcher': 'Logan Gilbert', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': 8, 'home_score': 4, 'current_inning': 9, 'inning_state': 'Bottom', 'venue_id': 2394, 'venue_name': 'Comerica Park', 'national_broadcasts': [], 'series_status': 'SEA wins 3-0', 'winning_team': 'Seattle Mariners', 'losing_team': 'Det ...
