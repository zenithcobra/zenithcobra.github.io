# %%
import importlib
import script

# Reload the script after making changes
importlib.reload(script)

# DATES
date = script.get_date()


schedule = script.get_schedule_by_date(date)
print(schedule)

schedule_text = script.get_schedule_text()
print(schedule_text)
# Out:
# [{'game_id': 777211, 'game_datetime': '2025-07-07T22:40:00Z', 'game_date': '2025-07-07', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Tampa Bay Rays', 'home_name': 'Detroit Tigers', 'away_id': 139, 'home_id': 116, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': '', 'away_probable_pitcher': 'Shane Baz', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 2394, 'venue_name': 'Comerica Park', 'national_broadcasts': ['FS1'], 'series_status': None, 'summary': '2025-07-07 - Tampa Bay Rays @ Detroit Tigers (Scheduled)'}, {'game_id': 777209, 'game_datetime': '2025-07-07T23:10:00Z', 'game_date': '2025-07-07', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Colorado Rockies', 'home_name': 'Boston Red Sox', 'away_id': 115, 'home_id': 111, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Richard Fitts', 'away_probable_pitcher': 'Austin Gomber', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 3, 'venue_name': 'Fenway Park', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-07-07 - Colorado Rockies @ Boston Red Sox (Scheduled)'}, {'game_id': 777208, 'game_datetime': '2025-07-07T23:10:00Z', 'game_date': '2025-07-07', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Miami Marlins', 'home_name': 'Cincinnati Reds', 'away_id': 146, 'home_id': 113, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Brady Singer', 'away_probable_pitcher': 'Janson Junk', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 2602, 'venue_name': 'Great American Ball Park', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-07-07 - Miami Marlins @ Cincinnati Reds (Scheduled)'}, {'game_id': 777204, 'game_datetime': '2025-07-07T23:40:00Z', 'game_date': '2025-07-07', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Pittsburgh Pirates', 'home_name': 'Kansas City Royals', 'away_id': 134, 'home_id': 118, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Noah Cameron', 'away_probable_pitcher': 'Andrew Heaney', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 7, 'venue_name': 'Kauffman Stadium', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-07-07 - Pittsburgh Pirates @ Kansas City Royals (Scheduled)'}, {'game_id': 777212, 'game_datetime': '2025-07-07T23:40:00Z', 'game_date': '2025-07-07', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Toronto Blue Jays', 'home_name': 'Chicago White Sox', 'away_id': 141, 'home_id': 145, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Sean Burke', 'away_probable_pitcher': 'José Berríos', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 4, 'venue_name': 'Rate Field', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-07-07 - Toronto Blue Jays @ Chicago White Sox (Scheduled)'}, {'game_id': 777201, 'game_datetime': '2025-07-07T23:40:00Z', 'game_date': '2025-07-07', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Los Angeles Dodgers', 'home_name': 'Milwaukee Brewers', 'away_id': 119, 'home_id': 158, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Freddy Peralta', 'away_probable_pitcher': 'Yoshinobu Yamamoto', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 32, 'venue_name': 'American Family Field', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-07-07 - Los Angeles Dodgers @ Milwaukee Brewers (Scheduled)'}, {'game_id': 777202, 'game_datetime': '2025-07-08T00:10:00Z', 'game_date': '2025-07-07', 'game_t ...
# Today's Schedule:
# 2025-07-07 06:40 PM EDT - Tampa Bay Rays @ Detroit Tigers (Scheduled)
# 2025-07-07 07:10 PM EDT - Colorado Rockies @ Boston Red Sox (Scheduled)
# 2025-07-07 07:10 PM EDT - Miami Marlins @ Cincinnati Reds (Scheduled)
# 2025-07-07 07:40 PM EDT - Pittsburgh Pirates @ Kansas City Royals (Scheduled)
# 2025-07-07 07:40 PM EDT - Toronto Blue Jays @ Chicago White Sox (Scheduled)
# 2025-07-07 07:40 PM EDT - Los Angeles Dodgers @ Milwaukee Brewers (Scheduled)
# 2025-07-07 08:10 PM EDT - Cleveland Guardians @ Houston Astros (Scheduled)
# 2025-07-07 09:38 PM EDT - Texas Rangers @ Los Angeles Angels (Scheduled)
# 2025-07-07 09:40 PM EDT - Arizona Diamondbacks @ San Diego Padres (Scheduled)
# 2025-07-07 09:45 PM EDT - Philadelphia Phillies @ San Francisco Giants (Scheduled)
