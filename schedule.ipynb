# %%
import importlib
import script

# Reload the script after making changes
importlib.reload(script)

# DATES
date = script.get_date()
schedule = script.get_schedule_by_date(date)
list_of_matches = []
for x in schedule:
    match_dict = {"away": x.get('away_name'), "home": x.get('home_name')}
    list_of_matches.append(match_dict)

print(list_of_matches)
# schedule_text = script.get_schedule_text()
# print(schedule_text)
# Out:
# [{'away': 'New York Mets', 'home': 'Baltimore Orioles'}, {'away': 'Tampa Bay Rays', 'home': 'Detroit Tigers'}, {'away': 'Seattle Mariners', 'home': 'New York Yankees'}, {'away': 'Colorado Rockies', 'home': 'Boston Red Sox'}, {'away': 'Miami Marlins', 'home': 'Cincinnati Reds'}, {'away': 'Pittsburgh Pirates', 'home': 'Kansas City Royals'}, {'away': 'Chicago Cubs', 'home': 'Minnesota Twins'}, {'away': 'Toronto Blue Jays', 'home': 'Chicago White Sox'}, {'away': 'Los Angeles Dodgers', 'home': 'Milwaukee Brewers'}, {'away': 'Washington Nationals', 'home': 'St. Louis Cardinals'}, {'away': 'Cleveland Guardians', 'home': 'Houston Astros'}, {'away': 'Texas Rangers', 'home': 'Los Angeles Angels'}, {'away': 'Arizona Diamondbacks', 'home': 'San Diego Padres'}, {'away': 'Philadelphia Phillies', 'home': 'San Francisco Giants'}, {'away': 'Atlanta Braves', 'home': 'Athletics'}]

# %%
import statsapi

result = statsapi.schedule(game_id=777464)
for key,value in result[0].items():
    print(f"{key}: {value}")
# print(result[0])
# Out:
# game_id: 777464
# game_datetime: 2025-06-18T22:40:00Z
# game_date: 2025-06-18
# game_type: R
# status: Postponed
# away_name: Pittsburgh Pirates
# home_name: Detroit Tigers
# away_id: 134
# home_id: 116
# doubleheader: N
# game_num: 1
# home_probable_pitcher: Tarik Skubal
# away_probable_pitcher: Andrew Heaney
# home_pitcher_note:
# away_pitcher_note:
# away_score: 0
# home_score: 0
# current_inning:
# inning_state:
# venue_id: 2394
# venue_name: Comerica Park
# national_broadcasts: []
# series_status: DET wins 2-1
# summary: 2025-06-18 - Pittsburgh Pirates @ Detroit Tigers (Postponed)

# %%
import statsapi
# Boxscore
boxscore = statsapi.boxscore_data(776763, timecode=None)
for key, value in boxscore.items():
    # print(f"{key}: {value}")
    print(f"{key}")

print('--------------------------------------------')
game_id = boxscore['gameId']
print(f"Game ID: {game_id}")
team_info = boxscore['teamInfo']
for key, value in team_info.items():
    print(f"{key}: {value}")
# player_info = boxscore['playerInfo']
# for key, value in player_info.items():
#     print(f"{key}: {value}")
away = boxscore['away']['players']
for a in away:
    # for key, value in away[a].items():
    #     print(key,value)
    name = away[a]['person']['fullName']
    player_id = away[a]['person']['id']
    print(name, player_id)
    position = away[a]['position']['abbreviation']
    print(position)
    stats = away[a]['stats']
    for key, value in stats.items():
        print(f"{key}: {value}")
# home = boxscore['home']
# for key, value in home.items():
#     print(f"{key}: {value}")
# away_batters = boxscore['awayBatters']
# for a in away_batters:
#     print('==========================')
#     for key, value in a.items():
#         print(f"{key}: {value}")
# home_batters = boxscore['homeBatters']
# for b in home_batters:
#     for key, value in b.items():
#         print(f"{key}: {value}")
# away_batter_notes = boxscore['gameBoxInfo']
# for s in away_batter_notes:
#     # for key, value in away_batter_notes.items():
#     #     print(f"{key}: {value}")
#     print(s)
# Out:
# gameId
# teamInfo
# playerInfo
# away
# home
# awayBatters
# homeBatters
# awayBattingTotals
# homeBattingTotals
# awayBattingNotes
# homeBattingNotes
# awayPitchers
# homePitchers
# awayPitchingTotals
# homePitchingTotals
# gameBoxInfo
# --------------------------------------------
# Game ID: 2025/08/12/lanmlb-anamlb-1
# away: {'id': 119, 'abbreviation': 'LAD', 'teamName': 'Dodgers', 'shortName': 'LA Dodgers'}
# home: {'id': 108, 'abbreviation': 'LAA', 'teamName': 'Angels', 'shortName': 'LA Angels'}
# Ben Casparius 676508
# P
# batting: {}
# pitching: {'note': '(L, 7-5)', 'runs': 1, 'doubles': 0, 'triples': 0, 'homeRuns': 0, 'strikeOuts': 1, 'baseOnBalls': 0, 'hits': 2, 'atBats': 3, 'stolenBases': 0, 'numberOfPitches': 15, 'inningsPitched': '0.1', 'wins': 0, 'losses': 1, 'holds': 0, 'blownSaves': 0, 'earnedRuns': 0, 'pitchesThrown': 15, 'strikes': 9, 'rbi': 1}
# Will Smith 669257
# C
# ...

# %%
hr_record = ''
        hits_record = ''
        rbi_record = ''
        for game in last_games_list:
            boxscore = statsapi.boxscore_data(game, timecode=None)
            for x in boxscore.get('awayBatters'):
                if player_id == x.get('personId'):
                    hr_record = hr_record + x.get('hr') + '-'
                    hits_record = hits_record + x.get('h') + '-'
                    rbi_record = rbi_record + x.get('rbi') + '-'
            for x in boxscore.get('homeBatters'):
                if player_id == x.get('personId'):
                    hr_record = hr_record + x.get('hr') + '-'
                    hits_record = hits_record + x.get('h') + '-'
                    rbi_record = rbi_record + x.get('rbi') + '-'
        q.update({'HR_record': hr_record, 'H_record': hits_record, 'RBI_record': rbi_record})
