# %%
# Roster and processing logic

import statsapi

roster_string = statsapi.roster(143)
roster_list_unprocessed = roster_string.split('\n')
roster_list = []
for x in roster_list_unprocessed:
    roster_line = ''
    for y in x.split(' ')[4:]:
        roster_line = roster_line + y + ' '
    roster_list.append(roster_line.lstrip())

for a in roster_list:
    print(a)
# Out:
# Alec Bohm
# Brandon Marsh
# Bryce Harper
# Bryson Stott
# Carlos Hernández
# Cristopher Sánchez
# Edmundo Sosa
# J.T. Realmuto
# Jesús Luzardo
# Joe Ross
# Johan Rojas
# Jordan Romano
# Kyle Schwarber
# Matt Strahm
# Max Kepler
# Max Lazar
# Mick Abel
# Nick Castellanos
# Orion Kerkering
# Rafael Marchán
# Ranger Suárez
# Seth Johnson
# Taijuan Walker
# Tanner Banks
# Trea Turner
# Weston Wilson

# %%
#  import statsapi

#  homerun_leaders_by_team = []
#  home_leaders_data = statsapi.team_leader_data(143, 'homeRuns', season=2025, leaderGameTypes="R", limit=10)
#         for z in home_leaders_data:
#             homerun_leaders_by_team.append({'name': z[1],'homeRuns': z[2]})
import statsapi

def get_homerun_leaders_by_team(team_id, season=2025, leaderGameTypes="R", limit=10):
    """
    Returns a list of home run leaders for a given team ID.

    Args:
        team_id (int): The ID of the team to fetch home run leaders for.
        season (int): The MLB season year (default is 2025).
        leaderGameTypes (str): The type of games to consider (default is "R" for regular season).
        limit (int): The maximum number of leaders to fetch (default is 10).

    Returns:
        list: A list of dictionaries containing player names and their home run counts.
    """
    homerun_leaders_by_team = []
    home_leaders_data = statsapi.team_leader_data(team_id, 'homeRuns', season=season, leaderGameTypes=leaderGameTypes, limit=limit)
    
    for z in home_leaders_data:
        homerun_leaders_by_team.append({'name': z[1], 'homeRuns': z[2]})
    
    return homerun_leaders_by_team

# Example usage
team_id = 143  # Replace with the desired team ID
leaders = get_homerun_leaders_by_team(team_id)
print(leaders)

# %%
import statsapi
print(statsapi.meta('gameTypes'))
# Out:
# [{'id': 'S', 'description': 'Spring Training'}, {'id': 'R', 'description': 'Regular Season'}, {'id': 'F', 'description': 'Wild Card'}, {'id': 'D', 'description': 'Division Series'}, {'id': 'L', 'description': 'League Championship Series'}, {'id': 'W', 'description': 'World Series'}, {'id': 'C', 'description': 'Championship'}, {'id': 'N', 'description': 'Nineteenth Century Series'}, {'id': 'P', 'description': 'Playoffs'}, {'id': 'A', 'description': 'All-Star Game'}, {'id': 'I', 'description': 'Intrasquad'}, {'id': 'E', 'description': 'Exhibition'}]

# %%
from datetime import datetime, timedelta
# get date
def get_date():
    """
    Gets the current date in the format required by 'statsapi'.
    Returns:
        str: The current date formatted as 'MM/DD/YYYY'.
    """
    return datetime.now().strftime("%m/%d/%Y")

# schedule
import statsapi
def get_schedule_by_date(date):
    """
    Gets the statsapi schedule based on the date provided and returns the schedule.
    Args:
        date (str): The date formatted as 'MM/DD/YYYY'.
    Returns:
        list: A list of dictionaries representing the schedule for the given date.
        keys being
            
    """
    # Get the schedule as a dictionary for the provided date
    schedule = statsapi.schedule(start_date=date, end_date=date)
    return schedule
for x in get_schedule_by_date(get_date()):
    for y,z in x.items():
        print(y)
# Out:
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary
# game_id
# game_datetime
# game_date
# game_type
# status
# away_name
# home_name
# away_id
# home_id
# doubleheader
# game_num
# home_probable_pitcher
# away_probable_pitcher
# home_pitcher_note
# away_pitcher_note
# away_score
# home_score
# current_inning
# inning_state
# venue_id
# venue_name
# national_broadcasts
# series_status
# summary

# %%
def extract_probable_pitchers_from_processed_schedule(processed_schedule):
    """
    Extracts probable pitchers from the processed schedule and returns a list of dictionaries.

    Args:
        processed_schedule (list): A list of dictionaries representing the processed schedule.

    Returns:
        list: A list of dictionaries, each containing details about a probable pitcher.
              Example format:
              [
                  {"pitcher": probable_pitcher_name, "pitchers_team": team_name, "pitchers_team_id": team_id, "home_or_away": "home"},
                  {"pitcher": probable_pitcher_name, "pitchers_team": team_name, "pitchers_team_id": team_id, "home_or_away": "away"}
              ]
    """
    pitchers_today = []

    for game in processed_schedule:
        # Extract home probable pitcher
        home_pitcher = game.get("home_probable_pitcher")
        if home_pitcher:  # Ensure the pitcher exists
            home_pitcher_dict = {
                "pitcher": home_pitcher,
                "pitchers_team": game.get("home_name"),
                "pitchers_team_id": game.get("home_id"),
                "home_or_away": "home"
            }
            pitchers_today.append(home_pitcher_dict)

        # Extract away probable pitcher
        away_pitcher = game.get("away_probable_pitcher")
        if away_pitcher:  # Ensure the pitcher exists
            away_pitcher_dict = {
                "pitcher": away_pitcher,
                "pitchers_team": game.get("away_name"),
                "pitchers_team_id": game.get("away_id"),
                "home_or_away": "away"
            }
            pitchers_today.append(away_pitcher_dict)

    return pitchers_today

# Example usage
schedule = [
    {
        "date": "06/05/2025",
        "venue": "Yankee Stadium",
        "away_name": "Los Angeles Angels",
        "away_id": 108,
        "away_probable_pitcher": "Shohei Ohtani",
        "away_team_roster": ["Player A", "Player B"],
        "away_team_leaders_hr": [{"name": "Shohei Ohtani", "homeRuns": 44}],
        "home_name": "New York Yankees",
        "home_id": 147,
        "home_probable_pitcher": "Gerrit Cole",
        "home_team_roster": ["Player X", "Player Y"],
        "home_team_leaders_hr": [{"name": "Aaron Judge", "homeRuns": 52}]
    }
]

processed_schedule = process_the_schedule(schedule)  # Process the schedule
pitchers_today = extract_probable_pitchers_from_processed_schedule(processed_schedule)

# Print the extracted probable pitchers
print(pitchers_today)

# %%
import mlbstatsapi

def get_id_for_player(player_name):
    """
    Returns a player's ID based on their name.

    Args:
        player_name (str): The name of the player.

    Returns:
        int: The player's ID if found, otherwise None.
    """
    mlb = mlbstatsapi.Mlb()
    player_id = mlb.get_people_id(player_name)
    
    # Validate pitcher_ids
    if not player_id:
        print(f"Warning: No player ID found for {player_id}")
        return None
    
    # Safely access the first element
    return player_id[0]


def get_bvp_stats(batter_id, pitcher_id):
    """
    Retrieves batter vs pitcher (BvP) stats for the given batter and pitcher IDs.

    Args:
        batter_id (int): The ID of the batter.
        pitcher_id (int): The ID of the pitcher.

    Returns:
        list: A list of dictionaries containing BvP stats, matchup details, and player names.
    """
    mlb = mlbstatsapi.Mlb()
    BvP = []  # Initialize an empty list to store BvP stats

    # variables for the api call
    stats = ['vsPlayer']
    group = ['hitting']
    params = {'opposingPlayerId': pitcher_id, 'season': 2025}

    try:
        # Fetch player stats
        stats = mlb.get_player_stats(batter_id, stats=stats, groups=group, **params)
        vs_player_total = stats['hitting']['vsplayertotal']

        # Process splits in the stats
        for split in vs_player_total.splits:
            p_id = mlb.get_person(pitcher_id)
            b_id = mlb.get_person(batter_id)

            # Create a matchup string
            bvp_matchup = f"pitcher: {p_id.__dict__.get('fullname')} vs batter: {b_id.__dict__.get('fullname')}"

            # Create a dictionary for the BvP stats
            dict2 = {'bvp_stats': split.stat.__dict__}  # Dict of stats from the BvP stats
            dict2.update({'bvp_matchup': bvp_matchup})
            dict2.update({'pitcher': p_id.__dict__.get('fullname')})
            dict2.update({'batter': b_id.__dict__.get('fullname')})
            BvP.append(dict2)

    except KeyError as e:
        print(f"KeyError: {e}. Skipping this player. Stats: {stats}")
    except Exception as e:
        print(f"Unexpected error: {e}. Skipping this player.")

    return BvP

batter = 'Oneil Cruz'
batter_id = get_id_for_player(batter)
print(batter_id)
pitcher = 'Joe Ross'
pitcher_id = get_id_for_player(pitcher)
print(pitcher_id)
bvp_stats = get_bvp_stats(batter_id, pitcher_id)
# print(bvp_stats)
for k,v in bvp_stats[0].get('bvp_stats').items():
    print(k,v)
# Out:
# https://statsapi.mlb.com/api/v1/sports/1/players
# 665833
# https://statsapi.mlb.com/api/v1/sports/1/players
# 605452
# https://statsapi.mlb.com/api/v1/people/665833/stats
# https://statsapi.mlb.com/api/v1/people/605452
# https://statsapi.mlb.com/api/v1/people/665833
# gamesplayed 2
# flyouts None
# groundouts 0
# airouts 0
# runs None
# doubles 2
# triples 0
# homeruns 0
# strikeouts 1
# baseonballs 0
# intentionalwalks 0
# hits 3
# hitbypitch 0
# avg .750
# atbats 4
# obp .750
# slg 1.250
# ops 2.000
# caughtstealing None
# stolenbases None
# stolenbasepercentage None
# groundintodoubleplay 0
# groundintotripleplay 0
# numberofpitches 13
# plateappearances 4
# totalbases 5
# rbi 0
# leftonbase 1
# sacbunts 0
# sacflies 0
# babip 1.000
# groundoutstoairouts -.--
# catchersinterference 0
# atbatsperhomerun -.--

# %%
# yo
