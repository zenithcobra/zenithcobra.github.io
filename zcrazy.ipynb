# %%
from collections import defaultdict

# File path
file_path = "LEAGUE LEADERS.txt"

# Data structure to store player stats
player_stats = defaultdict(lambda: defaultdict(list))

# Read the file and parse the data
with open(file_path, "r") as file:
    for line in file:
        parts = line.strip().split()
        if len(parts) < 6:
            continue  # Skip invalid lines
        
        # Extract data
        name = " ".join(parts[:2])  # First and last name
        team = " ".join(parts[2:-3])  # Team name
        stat_type = parts[-3]  # Statistic type (e.g., AVG, HR)
        year = parts[-2]  # Year
        value = parts[-1]  # Statistic value
        
        # Store the data
        player_stats[name][stat_type].append((year, value))

# Function to calculate a player's performance score (example: based on AVG and OBPS)
def calculate_score(stats):
    avg = max(float(v[1]) for v in stats.get("AVG", [("0", "0")]))
    obps = max(float(v[1]) for v in stats.get("OBPS", [("0", "0")]))
    return avg + obps  # Example scoring formula

# Rank players based on their performance score
ranked_players = sorted(player_stats.items(), key=lambda x: calculate_score(x[1]), reverse=True)

# Display the top 5 players
print("Top 5 Players:")
for i, (player, stats) in enumerate(ranked_players[:5], start=1):
    print(f"{i}. {player}")
    for stat_type, values in stats.items():
        print(f"   {stat_type}: {', '.join([f'{v[0]}: {v[1]}' for v in values])}")
# Out:
# Top 5 Players:
# 1. Aaron Judge
#    AVG: 2024: .322, 2025: .357, 2025: .357
#    HITS: 2024: 180, 2025: 20
#    HR: 2024: 58, 2025: 6
#    OBPS: 2024: 1.159, 2025: 1.228
#    SO: 2024: 171
#    aGP: 2024: 158, 2025: 15
# 2. Jung Hoo
#    AVG: 2025: .352, 2025: .352
#    HITS: 2025: 19
#    HR: 2025: 3
#    OBPS: 2025: 1.130
# 3. George Springer
#    AVG: 2025: .375, 2025: .375
#    HITS: 2025: 18
#    OBPS: 2025: 1.040
#    aGP: 2025: 16
# 4. Kyle Tucker
#    AVG: 2025: .324, 2025: .324
#    HITS: 2025: 23
#    HR: 2025: 5, 2024: 23
#    OBPS: 2025: 1.090
#    aGP: 2025: 18
# 5. Pete Alonso
#    AVG: 2025: .321, 2025: .321
#    HITS: 2024: 146, 2025: 17
#    HR: 2024: 34, 2025: 4
#    OBPS: 2024: .788, 2025: 1.091
#    SO: 2024: 172
#    aGP: 2024: 162, 2025: 15

# %%
# File path
file_path = "BLUE JAYS HISTORY.txt"

# Data structure to store key points
highlights = []

# Read the file and parse the data
with open(file_path, "r") as file:
    lines = file.readlines()
    i = 0
    while i < len(lines):
        line = lines[i].strip()
        if line.endswith(")"):  # Likely a highlight title with duration
            highlight = {"title": line}
            i += 1
            if i < len(lines) and not lines[i].startswith("http"):  # Description
                highlight["description"] = lines[i].strip()
                i += 1
            if i < len(lines) and lines[i].startswith("http"):  # Video link
                highlight["video_link"] = lines[i].strip()
                i += 1
            highlights.append(highlight)
        else:
            i += 1

# Display the summary
print("Blue Jays Highlights Summary:")
for idx, highlight in enumerate(highlights, start=1):
    print(f"{idx}. {highlight['title']}")
    if "description" in highlight:
        print(f"   Description: {highlight['description']}")
    if "video_link" in highlight:
        print(f"   Video Link: {highlight['video_link']}")
    print()
# Out:
# Blue Jays Highlights Summary:
# 1. Probable pitchers for Braves at Blue Jays - April 14, 2025 (00:00:06)
#    Description:
#    Video Link: https://darkroom-clips.mlb.com/825c452b-88bc-42f3-9213-bc217da7685b.mp4
#
# 2. Probable pitchers for Braves at Blue Jays - April 14, 2025 (00:00:06)
#    Description:
#    Video Link: https://darkroom-clips.mlb.com/bc4f4e17-42fc-4039-bed9-563be83ac81d.mp4
#
# 3. Grant Holmes against the Blue Jays (00:00:08)
#    Description:
#    Video Link: https://darkroom-clips.mlb.com/09a31dcb-3ee5-4e3c-ae9f-34687d423a34.mp4
#
# 4. Bullpen availability for Toronto, April 14 vs Braves (00:00:08)
#    Description:
#    Video Link: https://darkroom-clips.mlb.com/4198fb56-d704-44a0-91b5-405ad6e56203.mp4
#
# 5. Bullpen availability for Atlanta, April 14 vs Blue Jays (00:00:08)
#    Description:
#    Video Link: https://darkroom-clips.mlb.com/f0568fc2-1105-484e-bd92-aadfa52bfc98.mp4
#
# 6. summary                   -> 2025-04-13 - Toronto Blue Jays (7) @ Baltimore Orioles (6) (Final)
#    Description:
#
# 7. Alejandro Kirk's first homer of the season (00:00:28)
#    Description: Alejandro Kirk drills a solo home run to left field for his first of the year and evens the score at 1 in the 2nd inning
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/0590512a-653bd297-14286c0a-csvm-diamondgcp-asset_1280x720_59_4000K.mp4
#
# 8. Ryan Mountcastle's solo home run (1) (00:00:24)
#    Description: Ryan Mountcastle belts a line-drive to left field for his first homer of the season, giving the Orioles a 2-1 lead in the 2nd inning
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/8e46446f-3921ff88-df7e4f90-csvm-diamondgcp-asset_1280x720_59_4000K.mp4
#
# 9. Vladimir Guerrero Jr.'s RBI single (00:00:15)
#    Description: Vladimir Guerrero Jr. laces a single to right-center field that plates Davis Schneider and ties the game at 2 in the 3rd inning
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/7f6935fc-447fec4b-5b767321-csvm-diamondgcp-asset-4000K.mp4
#
# 10. Tyler O'Neill's solo home run (2) (00:00:22)
#    Description: Tyler O'Neill crushes a solo home run to left-center field and increases the Orioles' lead to 4-2 in the 4th inning
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/f5fcd237-da2645a0-7d9c0460-csvm-diamondgcp-asset_1280x720_59_4000K.mp4
#
# 11. Orioles plate two runs on an error (00:00:30)
#    Description: Jackson Holliday reaches on an error by Vladimir Guerrero Jr., scoring Heston Kjerstad and Ryan Mountcastle to extend the lead to 6-3 in the 6th inning
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/33a0c3db-286292ac-1938a593-csvm-diamondgcp-asset_1280x720_59_4000K.mp4
#
# 12. Alejandro Kirk's RBI double (00:00:24)
#    Description: Alejandro Kirk drives a double to left field that brings home Andrés Giménez and shrinks the Orioles' lead to 6-4 in the 8th inning
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/964447de-9cd09955-3d01e678-csvm-diamondgcp-asset_1280x720_59_4000K.mp4
#
# 13. Bo Bichette's game-tying RBI single (00:00:21)
#    Description: Bo Bichette laces a single to left field that scores Ernie Clement and ties the game at 6 in the 8th inning
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/f3d3f93f-33a5dbf6-d92ca76d-csvm-diamondgcp-asset_1280x720_59_4000K.mp4
#
# 14. Myles Straw's go-ahead RBI infield single (00:00:23)
#    Description: Myles Straw hustles out a ground ball to third base for an infield single and scores Andrés Giménez to give the Blue Jays a 7-6 lead in the 10th inning
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/0f41e3d9-0fe1d23e-a44efa29-csvm-diamondgcp-asset_1280x720_59_4000K.mp4
#
# 15. Blue Jays vs. Orioles Highlights (00:03:15)
#    Description: Myles Straw and the Blue Jays take on Gunnar Henderson and the Orioles on April 13, 2025
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/84430243-8a9ebce6-22191fd7-csvm-diamondgcp-asset_1280x720_59_4000K.mp4
#
# 16. Condensed Game: TOR@BAL - 4/13/25 (00:10:20)
#    Description: Condensed Game: Myles Straw and the Blue Jays take on Gunnar Henderson and the Orioles on April 13, 2025
#    Video Link: https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-04/13/578d669b-9475a42f-67542421-csvm-diamondgcp-asset_1280x720_59_4000K.mp4

# %%
import os

# List of text files to convert
text_files = ["LEAGUE LEADERS.txt", "BLUE JAYS HISTORY.txt","GAME REPORTS.txt", "TOP LEAGUE LEADERS.txt", "MLB STANDINGS AND SCHEDULE.txt"]

# Directory to store the generated HTML files
output_dir = "html_output"
os.makedirs(output_dir, exist_ok=True)

# Flexbox CSS for stretchable text
flexbox_css = """
<style>
    
</style>
"""

# Generate HTML files for each text file
html_files = []
for text_file in text_files:
    if not os.path.exists(text_file):
        print(f"File {text_file} not found, skipping.")
        continue

    # Read the content of the text file
    with open(text_file, "r") as file:
        content = file.read()

    # Create an HTML file
    html_filename = os.path.splitext(text_file)[0] + ".html"
    html_filepath = os.path.join(output_dir, html_filename)
    html_files.append(html_filename)

    # Write the HTML content
    with open(html_filepath, "w") as html_file:
        html_file.write(f"<!DOCTYPE html>\n<html>\n<head>\n<title>{text_file}</title>\n{flexbox_css}</head>\n<body>\n")
        html_file.write(f"<div class='content'>\n<pre>{content}</pre>\n</div>\n")
        html_file.write(f"<a href='index.html'>Back to Index</a>\n</body>\n</html>")

# Generate the index.html file
index_filepath = os.path.join(output_dir, "index.html")
with open(index_filepath, "w") as index_file:
    index_file.write(f"<!DOCTYPE html>\n<html>\n<head>\n<title>Index</title>\n{flexbox_css}</head>\n<body>\n")
    index_file.write("<div class='content'>\n<h1>Index</h1>\n<ul>\n")
    for html_file in html_files:
        index_file.write(f"<li><a href='{html_file}'>{html_file}</a></li>\n")
    index_file.write("</ul>\n</div>\n</body>\n</html>")

print(f"HTML files have been generated in the '{output_dir}' directory.")
# Out:
# HTML files have been generated in the 'html_output' directory.

# %% [markdown]
# body {
#         display: flex;
#         flex-direction: column;
#         align-items: center;
#         justify-content: center;
#         margin: 0;
#         padding: 20px;
#         font-family: Arial, sans-serif;
#         background-color: #f4f4f4;
#     }
#     .content {
#         display: flex;
#         flex-direction: column;
#         width: 99%;
#         max-width: 1200px;
#         background: white;
#         padding: 20px;
#         border-radius: 8px;
#         box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#         overflow-wrap: break-word;
#     }
#     a {
#         text-decoration: none;
#         color: #007BFF;
#     }
#     a:hover {
#         text-decoration: underline;
#     }

# %%
import nest_asyncio; nest_asyncio.apply()  # This is needed to use sync API in repl
from playwright.sync_api import sync_playwright

pw = sync_playwright().start()
chrome = pw.chromium.launch(headless=False)
page = chrome.new_page()
page.goto("https://twitch.tv")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[3], line 4
#       1 import nest_asyncio; nest_asyncio.apply()  # This is needed to use sync API in repl
#       2 from playwright.sync_api import sync_playwright
# ----> 4 pw = sync_playwright().start()
#       5 chrome = pw.chromium.launch(headless=False)
#       6 page = chrome.new_page()
#
# File ~/.python/current/lib/python3.12/site-packages/playwright/sync_api/_context_manager.py:84, in PlaywrightContextManager.start(self)
#      83 def start(self) -> SyncPlaywright:
# ---> 84     return self.__enter__()
#
# File ~/.python/current/lib/python3.12/site-packages/playwright/sync_api/_context_manager.py:47, in PlaywrightContextManager.__enter__(self)
#      45             self._own_loop = True
#      46         if self._loop.is_running():
# ---> 47             raise Error(
#      48                 """It looks like you are using Playwright Sync API inside the asyncio loop.
#      49 Please use the Async API instead."""
#      50             )
#      52         # Create a new fiber for the protocol dispatcher. It will be pumping events
#      53         # until the end of times. We will pass control to that fiber every time we
#      54         # block while waiting for a response.
#      55         def greenlet_main() -> None:
#
# Error: It looks like you are using Playwright Sync API inside the asyncio loop.
# Please use the Async API instead.

# %%
import statsapi

from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# Get today's date
todays_date = datetime.now()

# Get the date one month prior
one_month_from_todays_date = todays_date - relativedelta(months=1)

# Format the dates as mm/dd/yyyy
todays_date = todays_date.strftime('%m/%d/%Y')
one_month_from_todays_date = one_month_from_todays_date.strftime('%m/%d/%Y')


sched = statsapi.schedule(start_date=one_month_from_todays_date,end_date=todays_date,team=141)

newlist = sorted(sched, key = lambda k: k["game_date"], reverse=True)

for game in newlist[0:5]:
    print(game.get('game_id'))
# Out:
# 778258
# 778273
# 778297
# 778311
# 778322

# %%
print( statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2008,'gameType':'W'})['people'] if x['fullName']=='Chase Utley'), 'hitting', 'career') )
# Out:
# Chase "Silver Fox" Utley, 2B (2003-2018)
#
# Career Hitting
# gamesPlayed: 1937
# groundOuts: 1734
# airOuts: 2123
# runs: 1103
# doubles: 411
# triples: 58
# homeRuns: 259
# strikeOuts: 1193
# baseOnBalls: 724
# intentionalWalks: 62
# hits: 1885
# hitByPitch: 204
# avg: .275
# atBats: 6857
# obp: .358
# slg: .465
# ops: .823
# caughtStealing: 22
# stolenBases: 154
# stolenBasePercentage: .875
# groundIntoDoublePlay: 93
# numberOfPitches: 30993
# plateAppearances: 7863
# totalBases: 3189
# rbi: 1025
# leftOnBase: 2790
# sacBunts: 6
# sacFlies: 72
# babip: .297
# groundOutsToAirouts: 0.82
# catchersInterference: 0
# atBatsPerHomeRun: 26.48
