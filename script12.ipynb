# %%
import statsapi

import json

# Read the JSON file
with open("text_output/teams_playing_today.json", "r", encoding="utf-8") as file:
    data = json.load(file)

# Ensure the data is a list
if isinstance(data, list):
    teams_list = data
else:
    raise ValueError("The JSON file does not contain a list.")

# Print the list to verify
# print(teams_list)

import statsapi
from datetime import datetime, timedelta
import os


# Get today's date
mlb_date = datetime.now().strftime("%m/%d/%Y")
schedule = statsapi.schedule(start_date=mlb_date, end_date=mlb_date)

# statsapi.get("game", {"gamePk": 633611})
# json_string = statsapi.get("game", {"gamePk": 777815})
# print(json_string.get('livedata'))


import json
import statsapi

# Fetch the JSON string
json_string = statsapi.get("game", {"gamePk": 777815})
livedata = json_string.get('liveData').get('boxscore').get('teams')
for x in livedata.get('away'):
    print(x)

# print(type(json_string))
# for key, value in json_string.items():
#     print(f"{key}")
# # Parse the JSON string into a Python dictionary
# if json_string:
#     json_data = json.loads(json_string)  # Convert JSON string to dictionary

#     # Access the 'livedata' key
#     livedata = json_data.get('liveData')
#     print(livedata)
# else:
#     print("No data returned from statsapi.get()")

# -----------------------------------
# for x in schedule:
#     game_json = statsapi.get("game", {"gamePk": x['game_id']})
#     print(game_json.get('boxscore').get('boxscore').get('teams'))
# #{livedata{boxscore{teams{
# Out:
# team
# teamStats
# players
# batters
# pitchers
# bench
# bullpen
# battingOrder
# info
# note

# %%
# Out:
# {'game_id': 777815, 'game_datetime': '2025-05-23T17:35:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Pre-Game', 'away_name': 'Baltimore Orioles', 'home_name': 'Boston Red Sox', 'away_id': 110, 'home_id': 111, 'doubleheader': 'S', 'game_num': 1, 'home_probable_pitcher': 'Brayan Bello', 'away_probable_pitcher': 'Cade Povich', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': 0, 'home_score': 0, 'current_inning': 1, 'inning_state': 'Top', 'venue_id': 3, 'venue_name': 'Fenway Park', 'national_broadcasts': ['MLBN'], 'series_status': None, 'summary': '2025-05-23 - Baltimore Orioles @ Boston Red Sox (Pre-Game)'}
# {'game_id': 777809, 'game_datetime': '2025-05-23T23:10:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Baltimore Orioles', 'home_name': 'Boston Red Sox', 'away_id': 110, 'home_id': 111, 'doubleheader': 'S', 'game_num': 2, 'home_probable_pitcher': 'Lucas Giolito', 'away_probable_pitcher': '', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 3, 'venue_name': 'Fenway Park', 'national_broadcasts': ['MLBN (out-of-market only)'], 'series_status': None, 'summary': '2025-05-23 - Baltimore Orioles @ Boston Red Sox (Scheduled)'}
# {'game_id': 777811, 'game_datetime': '2025-05-23T22:40:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Chicago Cubs', 'home_name': 'Cincinnati Reds', 'away_id': 112, 'home_id': 113, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Hunter Greene', 'away_probable_pitcher': 'Matthew Boyd', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 2602, 'venue_name': 'Great American Ball Park', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - Chicago Cubs @ Cincinnati Reds (Scheduled)'}
# {'game_id': 777806, 'game_datetime': '2025-05-23T22:40:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Milwaukee Brewers', 'home_name': 'Pittsburgh Pirates', 'away_id': 158, 'home_id': 134, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Paul Skenes', 'away_probable_pitcher': 'Freddy Peralta', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 31, 'venue_name': 'PNC Park', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - Milwaukee Brewers @ Pittsburgh Pirates (Scheduled)'}
# {'game_id': 777801, 'game_datetime': '2025-05-23T22:45:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'San Francisco Giants', 'home_name': 'Washington Nationals', 'away_id': 137, 'home_id': 120, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'MacKenzie Gore', 'away_probable_pitcher': 'Landen Roupp', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 3309, 'venue_name': 'Nationals Park', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - San Francisco Giants @ Washington Nationals (Scheduled)'}
# {'game_id': 777810, 'game_datetime': '2025-05-23T23:05:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Toronto Blue Jays', 'home_name': 'Tampa Bay Rays', 'away_id': 141, 'home_id': 139, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Drew Rasmussen', 'away_probable_pitcher': 'Eric Lauer', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 2523, 'venue_name': 'George M. Steinbrenner Field', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - Toronto Blue Jays @ Tampa Bay Rays (Scheduled)'}
# {'game_id': 777807, 'game_datetime': '2025-05-23T23:10:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Cleveland Guardians', 'home_name': 'Detroit Tigers', 'away_id': 114, 'home_id': 116, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Jackson Jobe', 'away_probable_pitcher': 'Slade Cecconi', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 2394, 'venue_name': 'Comerica Park', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - Cleveland Guardians @ Detroit Tigers (Scheduled)'}
# {'game_id': 777808, 'game_datetime': '2025-05-23T23:10:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Los Angeles Dodgers', 'home_name': 'New York Mets', 'away_id': 119, 'home_id': 121, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Griffin Canning', 'away_probable_pitcher': 'Clayton Kershaw', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 3289, 'venue_name': 'Citi Field', 'national_broadcasts': ['Apple TV+'], 'series_status': None, 'summary': '2025-05-23 - Los Angeles Dodgers @ New York Mets (Scheduled)'}
# {'game_id': 777813, 'game_datetime': '2025-05-23T23:15:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'San Diego Padres', 'home_name': 'Atlanta Braves', 'away_id': 135, 'home_id': 144, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Chris Sale', 'away_probable_pitcher': 'Nick Pivetta', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 4705, 'venue_name': 'Truist Park', 'national_broadcasts': ['MLBN (out-of-market only)'], 'series_status': None, 'summary': '2025-05-23 - San Diego Padres @ Atlanta Braves (Scheduled)'}
# {'game_id': 777805, 'game_datetime': '2025-05-23T23:40:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Texas Rangers', 'home_name': 'Chicago White Sox', 'away_id': 140, 'home_id': 145, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Sean Burke', 'away_probable_pitcher': 'Tyler Mahle', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 4, 'venue_name': 'Rate Field', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - Texas Rangers @ Chicago White Sox (Scheduled)'}
# {'game_id': 777800, 'game_datetime': '2025-05-24T00:10:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Seattle Mariners', 'home_name': 'Houston Astros', 'away_id': 136, 'home_id': 117, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Ryan Gusto', 'away_probable_pitcher': 'Emerson Hancock', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 2392, 'venue_name': 'Daikin Park', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - Seattle Mariners @ Houston Astros (Scheduled)'}
# {'game_id': 777799, 'game_datetime': '2025-05-24T00:10:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Kansas City Royals', 'home_name': 'Minnesota Twins', 'away_id': 118, 'home_id': 142, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Pablo López', 'away_probable_pitcher': 'Noah Cameron', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 3312, 'venue_name': 'Target Field', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - Kansas City Royals @ Minnesota Twins (Scheduled)'}
# {'game_id': 777797, 'game_datetime': '2025-05-24T00:15:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Arizona Diamondbacks', 'home_name': 'St. Louis Cardinals', 'away_id': 109, 'home_id': 138, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Miles Mikolas', 'away_probable_pitcher': 'Zac Gallen', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 2889, 'venue_name': 'Busch Stadium', 'national_broadcasts': ['Apple TV+'], 'series_status': None, 'summary': '2025-05-23 - Arizona Diamondbacks @ St. Louis Cardinals (Scheduled)'}
# {'game_id': 777802, 'game_datetime': '2025-05-24T00:40:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'New York Yankees', 'home_name': 'Colorado Rockies', 'away_id': 147, 'home_id': 115, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': '', 'away_probable_pitcher': 'Clarke Schmidt', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 19, 'venue_name': 'Coors Field', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - New York Yankees @ Colorado Rockies (Scheduled)'}
# {'game_id': 777798, 'game_datetime': '2025-05-24T01:38:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Miami Marlins', 'home_name': 'Los Angeles Angels', 'away_id': 146, 'home_id': 108, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': 'Yusei Kikuchi', 'away_probable_pitcher': 'Sandy Alcantara', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 1, 'venue_name': 'Angel Stadium', 'national_broadcasts': [], 'series_status': None, 'summary': '2025-05-23 - Miami Marlins @ Los Angeles Angels (Scheduled)'}
# {'game_id': 777804, 'game_datetime': '2025-05-24T02:05:00Z', 'game_date': '2025-05-23', 'game_type': 'R', 'status': 'Scheduled', 'away_name': 'Philadelphia Phillies', 'home_name': 'Athletics', 'away_id': 143, 'home_id': 133, 'doubleheader': 'N', 'game_num': 1, 'home_probable_pitcher': '', 'away_probable_pitcher': 'Zack Wheeler', 'home_pitcher_note': '', 'away_pitcher_note': '', 'away_score': '0', 'home_score': '0', 'current_inning': '', 'inning_state': '', 'venue_id': 2529, 'venue_name': 'Sutter Health Park', 'national_broadcasts': ['MLBN (out-of-market only)'], 'series_status': None, 'summary': '2025-05-23 - Philadelphia Phillies @ Athletics (Scheduled)'}
# {'copyright': 'Copyright 2025 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt', 'gamePk': 777815, 'link': '/api/v1.1/game/777815/feed/live', 'metaData': {'wait': 10, 'timeStamp': '20250523_142657', 'gameEvents': ['game_advisory'], 'logicalEvents': []}, 'gameData': {'game': {'pk': 777815, 'type': 'R', 'doubleHeader': 'S', 'id': '2025/05/23/balmlb-bosmlb-1', 'gamedayType': 'P', 'tiebreaker': 'N', 'gameNumber': 1, 'calendarEventID': '14-777815-2025-05-23', 'season': '2025', 'seasonDisplay': '2025'}, 'datetime': {'dateTime': '2025-05-23T17:35:00Z', 'originalDate': '2025-05-23', 'officialDate': '2025-05-23', 'dayNight': 'day', 'time': '1:35', 'ampm': 'PM'}, 'status': {'abstractGameState': 'Preview', 'codedGameState': 'P', 'detailedState': 'Pre-Game', 'statusCode': 'P', 'startTimeTBD': False, 'abstractGameCode': 'P'}, 'teams': {'away': {'springLeague': {'id': 115, 'name': 'Grapefruit League', 'link': '/api/v1/league/115', 'abbreviation': 'GL'}, 'allStarStatus': 'N', 'id': 110, 'name': 'Baltimore Orioles', 'link': '/api/v1/teams/110', 'season': 2025, 'venue': {'id': 2, 'name': 'Oriole Park at Camden Yards', 'link': '/api/v1/venues/2'}, 'springVenue': {'id': 2508, 'link': '/api/v1/venues/2508'}, 'teamCode': 'bal', 'fileCode': 'bal', 'abbreviation': 'BAL', 'teamName': 'Orioles', 'locationName': 'Baltimore', 'firstYearOfPlay': '1901', 'league': {'id': 103, 'name': 'American League', 'link': '/api/v1/league/103'}, 'division': {'id': 201, 'name': 'American League East', 'link': '/api/v1/divisions/201'}, 'sport': {'id': 1, 'link': '/api/v1/sports/1', 'name': 'Major League Baseball'}, 'shortName': 'Baltimore', 'record': {'gamesPlayed': 48, 'wildCardGamesBack': '-', 'leagueGamesBack': '-', 'springLeagueGamesBack': '-', 'sportGamesBack': '-', 'divisionGamesBack': '-', 'conferenceGamesBack': '-', 'leagueRecord': {'wins': 16, 'losses': 32, 'ties': 0, 'pct': '.333'}, 'records': {}, 'divisionLeader': False, 'wins': 16, 'losses': 32, 'winningPercentage': '.333'}, 'franchiseName': 'Baltimore', 'clubName': 'Orioles', 'active': True}, 'home': {'springLeague': {'id': 115, 'name': 'Grapefruit League', 'link': '/api/v1/league/115', 'abbreviation': 'GL'}, 'allStarStatus': 'N', 'id': 111, 'name': 'Boston Red Sox', 'link': '/api/v1/teams/111', 'season': 2025, 'venue': {'id': 3, 'name': 'Fenway Park', 'link': '/api/v1/venues/3'}, 'springVenue': {'id': 4309, 'link': '/api/v1/venues/4309'}, 'teamCode': 'bos', 'fileCode': 'bos', 'abbreviation': 'BOS', 'teamName': 'Red Sox', 'locationName': 'Boston', 'firstYearOfPlay': '1901', 'league': {'id': 103, 'name': 'American League', 'link': '/api/v1/league/103'}, 'division': {'id': 201, 'name': 'American League East', 'link': '/api/v1/divisions/201'}, 'sport': {'id': 1, 'link': '/api/v1/sports/1', 'name': 'Major League Baseball'}, 'shortName': 'Boston', 'record': {'gamesPlayed': 51, 'wildCardGamesBack': '-', 'leagueGamesBack': '-', 'springLeagueGamesBack': '-', 'sportGamesBack': '-', 'divisionGamesBack': '-', 'conferenceGamesBack': '-', 'leagueRecord': {'wins': 25, 'losses': 26, 'ties': 0, 'pct': '.490'}, 'records': {}, 'divisionLeader': False, 'wins': 25, 'losses': 26, 'winningPercentage': '.490'}, 'franchiseName': 'Boston', 'clubName': 'Red Sox', 'active': True}}, 'players': {'ID669211': {'id': 669211, 'fullName': 'Keegan Akin', 'link': '/api/v1/people/669211', 'firstName': 'Keegan', 'lastName': 'Akin', 'primaryNumber': '45', 'birthDate': '1995-04-01', 'currentAge': 30, 'birthCity': 'Alma', 'birthStateProvince': 'MI', 'birthCountry': 'USA', 'height': '6\' 0"', 'weight': 240, 'active': True, 'primaryPosition': {'code': '1', 'name': 'Pitcher', 'type': 'Pitcher', 'abbreviation': 'P'}, 'useName': 'Keegan', 'useLastName': 'Akin', 'middleName': 'Lee', 'boxscoreName': 'Akin', 'gender': 'M', 'isPlayer': True, 'isVerified': False, 'draftYear': 2016, 'pronunciation': 'A-kin', 'mlbDebutDate': '2020-08-14', 'batSide': {'code': ' ...

# %%
import json
import statsapi

# Fetch the JSON string
json_string = statsapi.get("game", {"gamePk": 777815})

# Pretty-print the JSON
pretty_json = json.dumps(json_string, indent=4)
print(pretty_json)
# Out:
# {
#     "copyright": "Copyright 2025 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt",
#     "gamePk": 777815,
#     "link": "/api/v1.1/game/777815/feed/live",
#     "metaData": {
#         "wait": 10,
#         "timeStamp": "20250523_142657",
#         "gameEvents": [
#             "game_advisory"
#         ],
#         "logicalEvents": []
#     },
#     "gameData": {
#         "game": {
#             "pk": 777815,
#             "type": "R",
#             "doubleHeader": "S",
#             "id": "2025/05/23/balmlb-bosmlb-1",
#             "gamedayType": "P",
#             "tiebreaker": "N",
#             "gameNumber": 1,
#             "calendarEventID": "14-777815-2025-05-23",
#             "season": "2025",
#             "seasonDisplay": "2025"
#         },
#         "datetime": {
#             "dateTime": "2025-05-23T17:35:00Z",
#             "originalDate": "2025-05-23",
#             "officialDate": "2025-05-23",
#             "dayNight": "day",
#             "time": "1:35",
#             "ampm": "PM"
#         },
#         "status": {
#             "abstractGameState": "Preview",
#             "codedGameState": "P",
#             "detailedState": "Pre-Game",
#             "statusCode": "P",
#             "startTimeTBD": false,
#             "abstractGameCode": "P"
#         },
#         "teams": {
#             "away": {
#                 "springLeague": {
#                     "id": 115,
#                     "name": "Grapefruit League",
#                     "link": "/api/v1/league/115",
#                     "abbreviation": "GL"
#                 },
#                 "allStarStatus": "N",
#                 "id": 110,
#                 "name": "Baltimore Orioles",
#                 "link": "/api/v1/teams/110",
#                 "season": 2025,
#                 "venue": {
#                     "id": 2,
#                     "name": "Oriole Park at Camden Yards",
#                     "link": "/api/v1/venues/2"
#                 },
#                 "springVenue": {
#                     "id": 2508,
#                     "link": "/api/v1/venues/2508"
#                 },
#                 "teamCode": "bal",
#                 "fileCode": "bal",
#                 "abbreviation": "BAL",
#                 "teamName": "Orioles",
#                 "locationName": "Baltimore",
#                 "firstYearOfPlay": "1901",
#                 "league": {
#                     "id": 103,
#                     "name": "American League",
#                     "link": "/api/v1/league/103"
#                 },
#                 "division": {
#                     "id": 201,
#                     "name": "American League East",
#                     "link": "/api/v1/divisions/201"
#                 },
#                 "sport": {
#                     "id": 1,
#                     "link": "/api/v1/sports/1",
#                     "name": "Major League Baseball"
#                 },
#                 "shortName": "Baltimore",
#                 "record": {
#                     "gamesPlayed": 48,
#                     "wildCardGamesBack": "-",
#                     "leagueGamesBack": "-",
#                     "springLeagueGamesBack": "-",
#                     "sportGamesBack": "-",
#                     "divisionGamesBack": "-",
#                     "conferenceGamesBack": "-",
#                     "leagueRecord": {
#                         "wins": 16,
#                         "losses": 32,
#                         "ties": 0,
#                         "pct": ".333"
#                     },
#                     "records": {},
#                     "divisionLeader": false,
#                     "wins": 16,
#                     "losses": 32,
#                     "winningPercentage": ".333"
#                 },
#                 "franchiseName": "Baltimore",
#                 "clubName": "Orioles",
#                 "active": true
#             },
#             "home": {
#                 "springLeague": {
#                     "id": 115,
#                     "name": "Grapefruit League",
#                     "link": "/api/v1/league/115",
#                     "abbreviation": "GL"
#                 },
#                 "allStarStatus": "N",
#                 "id": 111,
#                 "name": "Boston Red Sox",
#                 "link": "/api/v1/teams/111",
#                 "season": 2025,
#                 "venue": {
#                     "id": 3,
#                     "name": "Fenway Park",
#                     "link": "/api/v1/venues/3"
#                 },
#                 "springVenue": {
#                     "id": 4309,
#                     "link": "/api/v1/venues/4309"
#                 },
#                 "teamCode": "bos",
#                 "fileCode": "bos",
#                 "abbreviation": "BOS",
#                 "teamName": "Red Sox",
#                 "locationName": "Boston",
#                 "firstYearOfPlay": "1901",
#                 "league": {
#                     "id": 103,
#                     "name": "American League",
#                     "link": "/api/v1/league/103"
#                 },
#                 "division": {
#                     "id": 201,
#                     "name": "American League East",
#                     "link": "/api/v1/divisions/201"
#                 },
#                 "sport": {
#                     "id": 1,
#                     "link": "/api/v1/sports/1",
#                     "name": "Major League Baseball"
#                 },
#                 "shortName": "Boston",
#                 "record": {
#                     "gamesPlayed": 51,
#                     "wildCardGamesBack": "-",
#                     "leagueGamesBack": "-",
#                     "springLeagueGamesBack": "-",
#                     "sportGamesBack": "-",
#                     "divisionGamesBack": "-",
#                     "conferenceGamesBack": "-",
#                     "leagueRecord": {
#                         "wins": 25,
#                         "losses": 26,
#                         "ties": 0,
#                         "pct": ".490"
#                     },
#                     "records": {},
#                     "divisionLeader": false,
#                     "wins": 25,
#                     "losses": 26,
#                     "winningPercentage": ".490"
#                 },
#                 "franchiseName": "Boston",
#                 "clubName": "Red Sox",
#                 "active": true
#             }
#         },
#         "players": {
#             "ID669211": {
#                 "id": 669211,
#                 "fullName": "Keegan Akin",
#                 "link": "/api/v1/people/669211",
#                 "firstName": "Keegan",
#                 "lastName": "Akin",
#                 "primaryNumber": "45",
#                 "birthDate": "1995-04-01",
#                 "currentAge": 30,
#                 "birthCity": "Alma",
#                 "birthStateProvince": "MI",
#                 "birthCountry": "USA",
#                 "height": "6' 0\"",
#                 "weight": 240,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "1",
#                     "name": "Pitcher",
#                     "type": "Pitcher",
#                     "abbreviation": "P"
#                 },
#                 "useName": "Keegan",
#                 "useLastName": "Akin",
#                 "middleName": "Lee",
#                 "boxscoreName": "Akin",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": false,
#                 "draftYear": 2016,
#                 "pronunciation": "A-kin",
#                 "mlbDebutDate": "2020-08-14",
#                 "batSide": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "pitchHand": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "nameFirstLast": "Keegan Akin",
#                 "nameSlug": "keegan-akin-669211",
#                 "firstLastName": "Keegan Akin",
#                 "lastFirstName": "Akin, Keegan",
#                 "lastInitName": "Akin, K",
#                 "initLastName": "K Akin",
#                 "fullFMLName": "Keegan Lee Akin",
#                 "fullLFMName": "Akin, Keegan Lee",
#                 "strikeZoneTop": 3.371,
#                 "strikeZoneBottom": 1.535
#             },
#             "ID666185": {
#                 "id": 666185,
#                 "fullName": "Dylan Carlson",
#                 "link": "/api/v1/people/666185",
#                 "firstName": "Dylan",
#                 "lastName": "Carlson",
#                 "primaryNumber": "15",
#                 "birthDate": "1998-10-23",
#                 "currentAge": 26,
#                 "birthCity": "Elk Grove",
#                 "birthStateProvince": "CA",
#                 "birthCountry": "USA",
#                 "height": "6' 2\"",
#                 "weight": 200,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "7",
#                     "name": "Outfielder",
#                     "type": "Outfielder",
#                     "abbreviation": "LF"
#                 },
#                 "useName": "Dylan",
#                 "useLastName": "Carlson",
#                 "middleName": "James",
#                 "boxscoreName": "Carlson",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": false,
#                 "draftYear": 2016,
#                 "mlbDebutDate": "2020-08-15",
#                 "batSide": {
#                     "code": "S",
#                     "description": "Switch"
#                 },
#                 "pitchHand": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "nameFirstLast": "Dylan Carlson",
#                 "nameSlug": "dylan-carlson-666185",
#                 "firstLastName": "Dylan Carlson",
#                 "lastFirstName": "Carlson, Dylan",
#                 "lastInitName": "Carlson, D",
#                 "initLastName": "D Carlson",
#                 "fullFMLName": "Dylan James Carlson",
#                 "fullLFMName": "Carlson, Dylan James",
#                 "strikeZoneTop": 3.56,
#                 "strikeZoneBottom": 1.64
#             },
#             "ID622761": {
#                 "id": 622761,
#                 "fullName": "Jorge Mateo",
#                 "link": "/api/v1/people/622761",
#                 "firstName": "Jorge",
#                 "lastName": "Mateo",
#                 "primaryNumber": "3",
#                 "birthDate": "1995-06-23",
#                 "currentAge": 29,
#                 "birthCity": "Santo Domingo Oeste",
#                 "birthCountry": "Dominican Republic",
#                 "height": "6' 1\"",
#                 "weight": 200,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "6",
#                     "name": "Shortstop",
#                     "type": "Infielder",
#                     "abbreviation": "SS"
#                 },
#                 "useName": "Jorge",
#                 "useLastName": "Mateo",
#                 "middleName": "Luis",
#                 "boxscoreName": "Mateo",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": false,
#                 "pronunciation": "mah-TAY-oh",
#                 "mlbDebutDate": "2020-08-13",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Jorge Mateo",
#                 "nameSlug": "jorge-mateo-622761",
#                 "firstLastName": "Jorge Mateo",
#                 "lastFirstName": "Mateo, Jorge",
#                 "lastInitName": "Mateo, J",
#                 "initLastName": "J Mateo",
#                 "fullFMLName": "Jorge Luis Mateo",
#                 "fullLFMName": "Mateo, Jorge Luis",
#                 "strikeZoneTop": 3.48,
#                 "strikeZoneBottom": 1.64
#             },
#             "ID683002": {
#                 "id": 683002,
#                 "fullName": "Gunnar Henderson",
#                 "link": "/api/v1/people/683002",
#                 "firstName": "Gunnar",
#                 "lastName": "Henderson",
#                 "primaryNumber": "2",
#                 "birthDate": "2001-06-29",
#                 "currentAge": 23,
#                 "birthCity": "Montgomery",
#                 "birthStateProvince": "AL",
#                 "birthCountry": "USA",
#                 "height": "6' 3\"",
#                 "weight": 220,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "6",
#                     "name": "Shortstop",
#                     "type": "Infielder",
#                     "abbreviation": "SS"
#                 },
#                 "useName": "Gunnar",
#                 "useLastName": "Henderson",
#                 "middleName": "Randal",
#                 "boxscoreName": "Henderson",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2019,
#                 "mlbDebutDate": "2022-08-31",
#                 "batSide": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Gunnar Henderson",
#                 "nameSlug": "gunnar-henderson-683002",
#                 "firstLastName": "Gunnar Henderson",
#                 "lastFirstName": "Henderson, Gunnar",
#                 "lastInitName": "Henderson, G",
#                 "initLastName": "G Henderson",
#                 "fullFMLName": "Gunnar Randal Henderson",
#                 "fullLFMName": "Henderson, Gunnar Randal",
#                 "strikeZoneTop": 3.73,
#                 "strikeZoneBottom": 1.75
#             },
#             "ID621111": {
#                 "id": 621111,
#                 "fullName": "Walker Buehler",
#                 "link": "/api/v1/people/621111",
#                 "firstName": "Walker",
#                 "lastName": "Buehler",
#                 "primaryNumber": "0",
#                 "birthDate": "1994-07-28",
#                 "currentAge": 30,
#                 "birthCity": "Lexington",
#                 "birthStateProvince": "KY",
#                 "birthCountry": "USA",
#                 "height": "6' 2\"",
#                 "weight": 185,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "1",
#                     "name": "Pitcher",
#                     "type": "Pitcher",
#                     "abbreviation": "P"
#                 },
#                 "useName": "Walker",
#                 "useLastName": "Buehler",
#                 "middleName": "Anthony",
#                 "boxscoreName": "Buehler",
#                 "nickName": "Buetane",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2015,
#                 "pronunciation": "BYOO-ler",
#                 "mlbDebutDate": "2017-09-07",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Walker Buehler",
#                 "nameSlug": "walker-buehler-621111",
#                 "firstLastName": "Walker Buehler",
#                 "lastFirstName": "Buehler, Walker",
#                 "lastInitName": "Buehler, W",
#                 "initLastName": "W Buehler",
#                 "fullFMLName": "Walker Anthony Buehler",
#                 "fullLFMName": "Buehler, Walker Anthony",
#                 "strikeZoneTop": 3.29,
#                 "strikeZoneBottom": 1.6
#             },
#             "ID521230": {
#                 "id": 521230,
#                 "fullName": "Liam Hendriks",
#                 "link": "/api/v1/people/521230",
#                 "firstName": "Liam",
#                 "lastName": "Hendriks",
#                 "primaryNumber": "31",
#                 "birthDate": "1989-02-10",
#                 "currentAge": 36,
#                 "birthCity": "Perth",
#                 "birthStateProvince": "Western Australia",
#                 "birthCountry": "Australia",
#                 "height": "6' 0\"",
#                 "weight": 235,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "1",
#                     "name": "Pitcher",
#                     "type": "Pitcher",
#                     "abbreviation": "P"
#                 },
#                 "useName": "Liam",
#                 "useLastName": "Hendriks",
#                 "middleName": "Johnson",
#                 "boxscoreName": "Hendriks",
#                 "nickName": "Slydah",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "mlbDebutDate": "2011-09-06",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Liam Hendriks",
#                 "nameSlug": "liam-hendriks-521230",
#                 "firstLastName": "Liam Hendriks",
#                 "lastFirstName": "Hendriks, Liam",
#                 "lastInitName": "Hendriks, L",
#                 "initLastName": "L Hendriks",
#                 "fullFMLName": "Liam Johnson Hendriks",
#                 "fullLFMName": "Hendriks, Liam Johnson",
#                 "strikeZoneTop": 3.371,
#                 "strikeZoneBottom": 1.535
#             },
#             "ID690928": {
#                 "id": 690928,
#                 "fullName": "Hunter Dobbins",
#                 "link": "/api/v1/people/690928",
#                 "firstName": "Hunter",
#                 "lastName": "Dobbins",
#                 "primaryNumber": "73",
#                 "birthDate": "1999-08-30",
#                 "currentAge": 25,
#                 "birthCity": "Bryan",
#                 "birthStateProvince": "TX",
#                 "birthCountry": "USA",
#                 "height": "6' 2\"",
#                 "weight": 185,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "1",
#                     "name": "Pitcher",
#                     "type": "Pitcher",
#                     "abbreviation": "P"
#                 },
#                 "useName": "Hunter",
#                 "useLastName": "Dobbins",
#                 "boxscoreName": "Dobbins",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2021,
#                 "mlbDebutDate": "2025-04-06",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Hunter Dobbins",
#                 "nameSlug": "hunter-dobbins-690928",
#                 "firstLastName": "Hunter Dobbins",
#                 "lastFirstName": "Dobbins, Hunter",
#                 "lastInitName": "Dobbins, H",
#                 "initLastName": "H Dobbins",
#                 "fullFMLName": "Hunter  Dobbins",
#                 "fullLFMName": "Dobbins, Hunter ",
#                 "strikeZoneTop": 3.467,
#                 "strikeZoneBottom": 1.589
#             },
#             "ID663624": {
#                 "id": 663624,
#                 "fullName": "Ryan Mountcastle",
#                 "link": "/api/v1/people/663624",
#                 "firstName": "Ryan",
#                 "lastName": "Mountcastle",
#                 "primaryNumber": "6",
#                 "birthDate": "1997-02-18",
#                 "currentAge": 28,
#                 "birthCity": "Winter Springs",
#                 "birthStateProvince": "FL",
#                 "birthCountry": "USA",
#                 "height": "6' 3\"",
#                 "weight": 220,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "3",
#                     "name": "First Base",
#                     "type": "Infielder",
#                     "abbreviation": "1B"
#                 },
#                 "useName": "Ryan",
#                 "useLastName": "Mountcastle",
#                 "middleName": "Lee",
#                 "boxscoreName": "Mountcastle",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2015,
#                 "mlbDebutDate": "2020-08-21",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Ryan Mountcastle",
#                 "nameSlug": "ryan-mountcastle-663624",
#                 "firstLastName": "Ryan Mountcastle",
#                 "lastFirstName": "Mountcastle, Ryan",
#                 "lastInitName": "Mountcastle, R",
#                 "initLastName": "R Mountcastle",
#                 "fullFMLName": "Ryan Lee Mountcastle",
#                 "fullLFMName": "Mountcastle, Ryan Lee",
#                 "strikeZoneTop": 3.76,
#                 "strikeZoneBottom": 1.83
#             },
#             "ID596115": {
#                 "id": 596115,
#                 "fullName": "Trevor Story",
#                 "link": "/api/v1/people/596115",
#                 "firstName": "Trevor",
#                 "lastName": "Story",
#                 "primaryNumber": "10",
#                 "birthDate": "1992-11-15",
#                 "currentAge": 32,
#                 "birthCity": "Irving",
#                 "birthStateProvince": "TX",
#                 "birthCountry": "USA",
#                 "height": "6' 1\"",
#                 "weight": 209,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "6",
#                     "name": "Shortstop",
#                     "type": "Infielder",
#                     "abbreviation": "SS"
#                 },
#                 "useName": "Trevor",
#                 "useLastName": "Story",
#                 "middleName": "John",
#                 "boxscoreName": "Story",
#                 "nickName": "True",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2011,
#                 "mlbDebutDate": "2016-04-04",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Trevor Story",
#                 "nameSlug": "trevor-story-596115",
#                 "firstLastName": "Trevor Story",
#                 "lastFirstName": "Story, Trevor",
#                 "lastInitName": "Story, T",
#                 "initLastName": "T Story",
#                 "fullFMLName": "Trevor John Story",
#                 "fullLFMName": "Story, Trevor John",
#                 "strikeZoneTop": 3.46,
#                 "strikeZoneBottom": 1.61
#             },
#             "ID608701": {
#                 "id": 608701,
#                 "fullName": "Rob Refsnyder",
#                 "link": "/api/v1/people/608701",
#                 "firstName": "Robert",
#                 "lastName": "Refsnyder",
#                 "primaryNumber": "30",
#                 "birthDate": "1991-03-26",
#                 "currentAge": 34,
#                 "birthCity": "Seoul",
#                 "birthCountry": "Republic of Korea",
#                 "height": "6' 0\"",
#                 "weight": 215,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "9",
#                     "name": "Outfielder",
#                     "type": "Outfielder",
#                     "abbreviation": "RF"
#                 },
#                 "useName": "Rob",
#                 "useLastName": "Refsnyder",
#                 "middleName": "Daniel",
#                 "boxscoreName": "Refsnyder",
#                 "nickName": "Ref",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2012,
#                 "mlbDebutDate": "2015-07-11",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Rob Refsnyder",
#                 "nameSlug": "rob-refsnyder-608701",
#                 "firstLastName": "Rob Refsnyder",
#                 "lastFirstName": "Refsnyder, Rob",
#                 "lastInitName": "Refsnyder, R",
#                 "initLastName": "R Refsnyder",
#                 "fullFMLName": "Robert Daniel Refsnyder",
#                 "fullLFMName": "Refsnyder, Robert Daniel",
#                 "strikeZoneTop": 3.56,
#                 "strikeZoneBottom": 1.59
#             },
#             "ID677008": {
#                 "id": 677008,
#                 "fullName": "Heston Kjerstad",
#                 "link": "/api/v1/people/677008",
#                 "firstName": "Heston",
#                 "lastName": "Kjerstad",
#                 "primaryNumber": "13",
#                 "birthDate": "1999-02-12",
#                 "currentAge": 26,
#                 "birthCity": "Amarillo",
#                 "birthStateProvince": "TX",
#                 "birthCountry": "USA",
#                 "height": "6' 2\"",
#                 "weight": 205,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "7",
#                     "name": "Outfielder",
#                     "type": "Outfielder",
#                     "abbreviation": "LF"
#                 },
#                 "useName": "Heston",
#                 "useLastName": "Kjerstad",
#                 "middleName": "Sawyer",
#                 "boxscoreName": "Kjerstad",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": false,
#                 "draftYear": 2020,
#                 "pronunciation": "KER-stad",
#                 "mlbDebutDate": "2023-09-14",
#                 "batSide": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Heston Kjerstad",
#                 "nameSlug": "heston-kjerstad-677008",
#                 "firstLastName": "Heston Kjerstad",
#                 "lastFirstName": "Kjerstad, Heston",
#                 "lastInitName": "Kjerstad, H",
#                 "initLastName": "H Kjerstad",
#                 "fullFMLName": "Heston Sawyer Kjerstad",
#                 "fullLFMName": "Kjerstad, Heston Sawyer",
#                 "strikeZoneTop": 3.87,
#                 "strikeZoneBottom": 1.74
#             },
#             "ID677800": {
#                 "id": 677800,
#                 "fullName": "Wilyer Abreu",
#                 "link": "/api/v1/people/677800",
#                 "firstName": "Wilyer",
#                 "lastName": "Abreu",
#                 "primaryNumber": "52",
#                 "birthDate": "1999-06-24",
#                 "currentAge": 25,
#                 "birthCity": "Maracaibo",
#                 "birthCountry": "Venezuela",
#                 "height": "5' 10\"",
#                 "weight": 215,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "9",
#                     "name": "Outfielder",
#                     "type": "Outfielder",
#                     "abbreviation": "RF"
#                 },
#                 "useName": "Wilyer",
#                 "useLastName": "Abreu",
#                 "middleName": "David",
#                 "boxscoreName": "Abreu, W",
#                 "gender": "M",
#                 "nameMatrilineal": "Villalobos",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "pronunciation": "WHEEL-yurr",
#                 "mlbDebutDate": "2023-08-22",
#                 "batSide": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "pitchHand": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "nameFirstLast": "Wilyer Abreu",
#                 "nameSlug": "wilyer-abreu-677800",
#                 "firstLastName": "Wilyer Abreu",
#                 "lastFirstName": "Abreu, Wilyer",
#                 "lastInitName": "Abreu, W",
#                 "initLastName": "W Abreu",
#                 "fullFMLName": "Wilyer David Abreu",
#                 "fullLFMName": "Abreu, Wilyer David",
#                 "strikeZoneTop": 3.27,
#                 "strikeZoneBottom": 1.55
#             },
#             "ID676477": {
#                 "id": 676477,
#                 "fullName": "Garrett Whitlock",
#                 "link": "/api/v1/people/676477",
#                 "firstName": "Garrett",
#                 "lastName": "Whitlock",
#                 "primaryNumber": "22",
#                 "birthDate": "1996-06-11",
#                 "currentAge": 28,
#                 "birthCity": "Snellville",
#                 "birthStateProvince": "GA",
#                 "birthCountry": "USA",
#                 "height": "6' 5\"",
#                 "weight": 222,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "1",
#                     "name": "Pitcher",
#                     "type": "Pitcher",
#                     "abbreviation": "P"
#                 },
#                 "useName": "Garrett",
#                 "useLastName": "Whitlock",
#                 "middleName": "Getts",
#                 "boxscoreName": "Whitlock",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2017,
#                 "mlbDebutDate": "2021-04-04",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Garrett Whitlock",
#                 "nameSlug": "garrett-whitlock-676477",
#                 "firstLastName": "Garrett Whitlock",
#                 "lastFirstName": "Whitlock, Garrett",
#                 "lastInitName": "Whitlock, G",
#                 "initLastName": "G Whitlock",
#                 "fullFMLName": "Garrett Getts Whitlock",
#                 "fullLFMName": "Whitlock, Garrett Getts",
#                 "strikeZoneTop": 3.575,
#                 "strikeZoneBottom": 1.681
#             },
#             "ID692225": {
#                 "id": 692225,
#                 "fullName": "Kristian Campbell",
#                 "link": "/api/v1/people/692225",
#                 "firstName": "Kristian",
#                 "lastName": "Campbell",
#                 "primaryNumber": "28",
#                 "birthDate": "2002-06-28",
#                 "currentAge": 22,
#                 "birthCity": "Chattanooga",
#                 "birthStateProvince": "TN",
#                 "birthCountry": "USA",
#                 "height": "6' 3\"",
#                 "weight": 191,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "4",
#                     "name": "Second Base",
#                     "type": "Infielder",
#                     "abbreviation": "2B"
#                 },
#                 "useName": "Kristian",
#                 "useLastName": "Campbell",
#                 "middleName": "Eron",
#                 "boxscoreName": "Campbell, K",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2023,
#                 "mlbDebutDate": "2025-03-27",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Kristian Campbell",
#                 "nameSlug": "kristian-campbell-692225",
#                 "firstLastName": "Kristian Campbell",
#                 "lastFirstName": "Campbell, Kristian",
#                 "lastInitName": "Campbell, K",
#                 "initLastName": "K Campbell",
#                 "fullFMLName": "Kristian Eron Campbell",
#                 "fullLFMName": "Campbell, Kristian Eron",
#                 "strikeZoneTop": 3.61,
#                 "strikeZoneBottom": 1.75
#             },
#             "ID657514": {
#                 "id": 657514,
#                 "fullName": "Brennan Bernardino",
#                 "link": "/api/v1/people/657514",
#                 "firstName": "Brennan",
#                 "lastName": "Bernardino",
#                 "primaryNumber": "83",
#                 "birthDate": "1992-01-15",
#                 "currentAge": 33,
#                 "birthCity": "Valencia",
#                 "birthStateProvince": "CA",
#                 "birthCountry": "USA",
#                 "height": "6' 4\"",
#                 "weight": 180,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "1",
#                     "name": "Pitcher",
#                     "type": "Pitcher",
#                     "abbreviation": "P"
#                 },
#                 "useName": "Brennan",
#                 "useLastName": "Bernardino",
#                 "middleName": "Allen",
#                 "boxscoreName": "Bernardino",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2014,
#                 "pronunciation": "ber-nar-DEEN-o",
#                 "mlbDebutDate": "2022-07-31",
#                 "batSide": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "pitchHand": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "nameFirstLast": "Brennan Bernardino",
#                 "nameSlug": "brennan-bernardino-657514",
#                 "firstLastName": "Brennan Bernardino",
#                 "lastFirstName": "Bernardino, Brennan",
#                 "lastInitName": "Bernardino, B",
#                 "initLastName": "B Bernardino",
#                 "fullFMLName": "Brennan Allen Bernardino",
#                 "fullLFMName": "Bernardino, Brennan Allen",
#                 "strikeZoneTop": 3.549,
#                 "strikeZoneBottom": 1.627
#             },
#             "ID676979": {
#                 "id": 676979,
#                 "fullName": "Garrett Crochet",
#                 "link": "/api/v1/people/676979",
#                 "firstName": "Garrett",
#                 "lastName": "Crochet",
#                 "primaryNumber": "35",
#                 "birthDate": "1999-06-21",
#                 "currentAge": 25,
#                 "birthCity": "Ocean Springs",
#                 "birthStateProvince": "MS",
#                 "birthCountry": "USA",
#                 "height": "6' 6\"",
#                 "weight": 245,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "1",
#                     "name": "Pitcher",
#                     "type": "Pitcher",
#                     "abbreviation": "P"
#                 },
#                 "useName": "Garrett",
#                 "useLastName": "Crochet",
#                 "middleName": "Nolan",
#                 "boxscoreName": "Crochet",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": false,
#                 "draftYear": 2020,
#                 "pronunciation": "crow-SHAY",
#                 "mlbDebutDate": "2020-09-18",
#                 "batSide": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "pitchHand": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "nameFirstLast": "Garrett Crochet",
#                 "nameSlug": "garrett-crochet-676979",
#                 "firstLastName": "Garrett Crochet",
#                 "lastFirstName": "Crochet, Garrett",
#                 "lastInitName": "Crochet, G",
#                 "initLastName": "G Crochet",
#                 "fullFMLName": "Garrett Nolan Crochet",
#                 "fullLFMName": "Crochet, Garrett Nolan",
#                 "strikeZoneTop": 3.66,
#                 "strikeZoneBottom": 1.68
#             },
#             "ID458677": {
#                 "id": 458677,
#                 "fullName": "Justin Wilson",
#                 "link": "/api/v1/people/458677",
#                 "firstName": "Justin",
#                 "lastName": "Wilson",
#                 "primaryNumber": "32",
#                 "birthDate": "1987-08-18",
#                 "currentAge": 37,
#                 "birthCity": "Anaheim",
#                 "birthStateProvince": "CA",
#                 "birthCountry": "USA",
#                 "height": "6' 2\"",
#                 "weight": 205,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "1",
#                     "name": "Pitcher",
#                     "type": "Pitcher",
#                     "abbreviation": "P"
#                 },
#                 "useName": "Justin",
#                 "useLastName": "Wilson",
#                 "middleName": "James",
#                 "boxscoreName": "Wilson, J",
#                 "nickName": "J Willy",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2008,
#                 "mlbDebutDate": "2012-08-20",
#                 "batSide": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "pitchHand": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "nameFirstLast": "Justin Wilson",
#                 "nameSlug": "justin-wilson-458677",
#                 "firstLastName": "Justin Wilson",
#                 "lastFirstName": "Wilson, Justin",
#                 "lastInitName": "Wilson, J",
#                 "initLastName": "J Wilson",
#                 "fullFMLName": "Justin James Wilson",
#                 "fullLFMName": "Wilson, Justin James",
#                 "strikeZoneTop": 3.467,
#                 "strikeZoneBottom": 1.589
#             },
#             "ID686580": {
#                 "id": 686580,
#                 "fullName": "Justin Slaten",
#                 "link": "/api/v1/people/686580",
#                 "firstName": "Justin",
#                 "lastName": "Slaten",
#                 "primaryNumber": "63",
#                 "birthDate": "1997-09-15",
#                 "currentAge": 27,
#                 "birthCity": "Longview",
#                 "birthStateProvince": "TX",
#                 "birthCountry": "USA",
#                 "height": "6' 4\"",
#                 "weight": 222,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "1",
#                     "name": "Pitcher",
#                     "type": "Pitcher",
#                     "abbreviation": "P"
#                 },
#                 "useName": "Justin",
#                 "useLastName": "Slaten",
#                 "middleName": "Michael",
#                 "boxscoreName": "Slaten",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2019,
#                 "pronunciation": "SLATE-in",
#                 "mlbDebutDate": "2024-03-30",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Justin Slaten",
#                 "nameSlug": "justin-slaten-686580",
#                 "firstLastName": "Justin Slaten",
#                 "lastFirstName": "Slaten, Justin",
#                 "lastInitName": "Slaten, J",
#                 "initLastName": "J Slaten",
#                 "fullFMLName": "Justin Michael Slaten",
#                 "fullLFMName": "Slaten, Justin Michael",
#                 "strikeZoneTop": 3.549,
#                 "strikeZoneBottom": 1.627
#             },
#             "ID666152": {
#                 "id": 666152,
#                 "fullName": "David Hamilton",
#                 "link": "/api/v1/people/666152",
#                 "firstName": "David",
#                 "lastName": "Hamilton",
#                 "primaryNumber": "17",
#                 "birthDate": "1997-09-29",
#                 "currentAge": 27,
#                 "birthCity": "San Marcos",
#                 "birthStateProvince": "TX",
#                 "birthCountry": "USA",
#                 "height": "5' 11\"",
#                 "weight": 188,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "4",
#                     "name": "Second Base",
#                     "type": "Infielder",
#                     "abbreviation": "2B"
#                 },
#                 "useName": "David",
#                 "useLastName": "Hamilton",
#                 "middleName": "Lewis",
#                 "boxscoreName": "Hamilton, D",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2019,
#                 "mlbDebutDate": "2023-06-21",
#                 "batSide": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "David Hamilton",
#                 "nameSlug": "david-hamilton-666152",
#                 "firstLastName": "David Hamilton",
#                 "lastFirstName": "Hamilton, David",
#                 "lastInitName": "Hamilton, D",
#                 "initLastName": "D Hamilton",
#                 "fullFMLName": "David Lewis Hamilton",
#                 "fullLFMName": "Hamilton, David Lewis",
#                 "strikeZoneTop": 3.29,
#                 "strikeZoneBottom": 1.5
#             },
#             "ID602104": {
#                 "id": 602104,
#                 "fullName": "Ram\u00f3n Ur\u00edas",
#                 "link": "/api/v1/people/602104",
#                 "firstName": "Ram\u00f3n",
#                 "lastName": "Ur\u00edas",
#                 "primaryNumber": "29",
#                 "birthDate": "1994-06-03",
#                 "currentAge": 30,
#                 "birthCity": "Magdalena de Kino",
#                 "birthStateProvince": "SO",
#                 "birthCountry": "Mexico",
#                 "height": "5' 9\"",
#                 "weight": 185,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "5",
#                     "name": "Third Base",
#                     "type": "Infielder",
#                     "abbreviation": "3B"
#                 },
#                 "useName": "Ram\u00f3n",
#                 "useLastName": "Ur\u00edas",
#                 "middleName": "Francisco",
#                 "boxscoreName": "Ur\u00edas, R",
#                 "gender": "M",
#                 "nameMatrilineal": "Figueroa",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "pronunciation": "oo-REE-ahs",
#                 "mlbDebutDate": "2020-08-20",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Ram\u00f3n Ur\u00edas",
#                 "nameSlug": "ramon-urias-602104",
#                 "firstLastName": "Ram\u00f3n Ur\u00edas",
#                 "lastFirstName": "Ur\u00edas, Ram\u00f3n",
#                 "lastInitName": "Ur\u00edas, R",
#                 "initLastName": "R Ur\u00edas",
#                 "fullFMLName": "Ram\u00f3n Francisco Ur\u00edas",
#                 "fullLFMName": "Ur\u00edas, Ram\u00f3n Francisco",
#                 "strikeZoneTop": 3.29,
#                 "strikeZoneBottom": 1.61
#             },
#             "ID646240": {
#                 "id": 646240,
#                 "fullName": "Rafael Devers",
#                 "link": "/api/v1/people/646240",
#                 "firstName": "Rafael",
#                 "lastName": "Devers",
#                 "primaryNumber": "11",
#                 "birthDate": "1996-10-24",
#                 "currentAge": 28,
#                 "birthCity": "Sanchez",
#                 "birthCountry": "Dominican Republic",
#                 "height": "6' 0\"",
#                 "weight": 235,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "10",
#                     "name": "Designated Hitter",
#                     "type": "Hitter",
#                     "abbreviation": "DH"
#                 },
#                 "useName": "Rafael",
#                 "useLastName": "Devers",
#                 "middleName": "Calcano",
#                 "boxscoreName": "Devers",
#                 "nickName": "Carita",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "pronunciation": "DEHV-ers",
#                 "mlbDebutDate": "2017-07-25",
#                 "batSide": {
#                     "code": "L",
#                     "description": "Left"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Rafael Devers",
#                 "nameSlug": "rafael-devers-646240",
#                 "firstLastName": "Rafael Devers",
#                 "lastFirstName": "Devers, Rafael",
#                 "lastInitName": "Devers, R",
#                 "initLastName": "R Devers",
#                 "fullFMLName": "Rafael Calcano Devers",
#                 "fullLFMName": "Devers, Rafael Calcano",
#                 "strikeZoneTop": 3.46,
#                 "strikeZoneBottom": 1.56
#             },
#             "ID668974": {
#                 "id": 668974,
#                 "fullName": "Maverick Handley",
#                 "link": "/api/v1/people/668974",
#                 "firstName": "Maverick",
#                 "lastName": "Handley",
#                 "primaryNumber": "98",
#                 "birthDate": "1998-03-10",
#                 "currentAge": 27,
#                 "birthCity": "Denver",
#                 "birthStateProvince": "CO",
#                 "birthCountry": "USA",
#                 "height": "5' 9\"",
#                 "weight": 210,
#                 "active": true,
#                 "primaryPosition": {
#                     "code": "2",
#                     "name": "Catcher",
#                     "type": "Catcher",
#                     "abbreviation": "C"
#                 },
#                 "useName": "Maverick",
#                 "useLastName": "Handley",
#                 "middleName": "Dayne",
#                 "boxscoreName": "Handley",
#                 "gender": "M",
#                 "isPlayer": true,
#                 "isVerified": true,
#                 "draftYear": 2019,
#                 "mlbDebutDate": "2025-04-29",
#                 "batSide": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "pitchHand": {
#                     "code": "R",
#                     "description": "Right"
#                 },
#                 "nameFirstLast": "Maverick Handley",
#                 "nameSlug": "maverick-handley-668974",
#                 "firstLastName": "Maverick Handley",
#                 "lastFirstName": "Handley, Maverick",
#                 "lastInitName": "Handley, M",
#                 "initLastName": "M Handley",
#                 "fullFMLName": "Maverick Dayne Handley",
# ...
#                                 "airOuts": 25,
#                                 "runs": 9,
#                                 "doubles": 3,
#                                 "triples": 0,
#                                 "homeRuns": 2,
#                                 "strikeOuts": 23,
#                                 "baseOnBalls": 11,
#                                 "intentionalWalks": 0,
#                                 "hits": 25,
#                                 "hitByPitch": 0,
#                                 "avg": ".272",
#                                 "atBats": 92,
#                                 "obp": ".340",
#                                 "slg": ".370",
#                                 "ops": ".710",
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "groundIntoDoublePlay": 2,
#                                 "groundIntoTriplePlay": 0,
#                                 "plateAppearances": 106,
#                                 "totalBases": 34,
#                                 "rbi": 12,
#                                 "leftOnBase": 46,
#                                 "sacBunts": 0,
#                                 "sacFlies": 3,
#                                 "babip": ".329",
#                                 "groundOutsToAirouts": "0.88",
#                                 "catchersInterference": 0,
#                                 "pickoffs": 0,
#                                 "atBatsPerHomeRun": "46.00",
#                                 "popOuts": 8,
#                                 "lineOuts": 4
#                             },
#                             "pitching": {
#                                 "gamesPlayed": 0,
#                                 "gamesStarted": 0,
#                                 "flyOuts": 0,
#                                 "groundOuts": 0,
#                                 "airOuts": 0,
#                                 "runs": 0,
#                                 "doubles": 0,
#                                 "triples": 0,
#                                 "homeRuns": 0,
#                                 "strikeOuts": 0,
#                                 "baseOnBalls": 0,
#                                 "intentionalWalks": 0,
#                                 "hits": 0,
#                                 "hitByPitch": 0,
#                                 "atBats": 0,
#                                 "obp": ".000",
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "numberOfPitches": 0,
#                                 "era": "-.--",
#                                 "inningsPitched": "0.0",
#                                 "wins": 0,
#                                 "losses": 0,
#                                 "saves": 0,
#                                 "saveOpportunities": 0,
#                                 "holds": 0,
#                                 "blownSaves": 0,
#                                 "earnedRuns": 0,
#                                 "whip": "-",
#                                 "battersFaced": 0,
#                                 "outs": 0,
#                                 "gamesPitched": 0,
#                                 "completeGames": 0,
#                                 "shutouts": 0,
#                                 "balls": 0,
#                                 "strikes": 0,
#                                 "strikePercentage": "-.--",
#                                 "hitBatsmen": 0,
#                                 "balks": 0,
#                                 "wildPitches": 0,
#                                 "pickoffs": 0,
#                                 "groundOutsToAirouts": "-.--",
#                                 "rbi": 0,
#                                 "winPercentage": ".---",
#                                 "pitchesPerInning": "-.--",
#                                 "gamesFinished": 0,
#                                 "strikeoutWalkRatio": "-.--",
#                                 "strikeoutsPer9Inn": "-.--",
#                                 "walksPer9Inn": "-.--",
#                                 "hitsPer9Inn": "-.--",
#                                 "runsScoredPer9": "-.--",
#                                 "homeRunsPer9": "-.--",
#                                 "inheritedRunners": 0,
#                                 "inheritedRunnersScored": 0,
#                                 "catchersInterference": 0,
#                                 "sacBunts": 0,
#                                 "sacFlies": 0,
#                                 "passedBall": 0,
#                                 "popOuts": 0,
#                                 "lineOuts": 0
#                             },
#                             "fielding": {
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "assists": 41,
#                                 "putOuts": 21,
#                                 "errors": 1,
#                                 "chances": 63,
#                                 "fielding": ".984",
#                                 "passedBall": 0,
#                                 "pickoffs": 0
#                             }
#                         },
#                         "gameStatus": {
#                             "isCurrentBatter": false,
#                             "isCurrentPitcher": false,
#                             "isOnBench": false,
#                             "isSubstitute": false
#                         },
#                         "allPositions": [
#                             {
#                                 "code": "5",
#                                 "name": "Third Base",
#                                 "type": "Infielder",
#                                 "abbreviation": "3B"
#                             }
#                         ]
#                     },
#                     "type": "hitter",
#                     "gameScore": 42,
#                     "hittingGameScore": 42
#                 },
#                 {
#                     "player": {
#                         "person": {
#                             "id": 608324,
#                             "fullName": "Alex Bregman",
#                             "link": "/api/v1/people/608324",
#                             "boxscoreName": "Bregman"
#                         },
#                         "jerseyNumber": "2",
#                         "position": {
#                             "code": "5",
#                             "name": "Third Base",
#                             "type": "Infielder",
#                             "abbreviation": "3B"
#                         },
#                         "status": {
#                             "code": "A",
#                             "description": "Active"
#                         },
#                         "parentTeamId": 111,
#                         "battingOrder": "300",
#                         "stats": {
#                             "batting": {
#                                 "summary": "0-0",
#                                 "gamesPlayed": 1,
#                                 "flyOuts": 0,
#                                 "groundOuts": 0,
#                                 "airOuts": 0,
#                                 "runs": 0,
#                                 "doubles": 0,
#                                 "triples": 0,
#                                 "homeRuns": 0,
#                                 "strikeOuts": 0,
#                                 "baseOnBalls": 0,
#                                 "intentionalWalks": 0,
#                                 "hits": 0,
#                                 "hitByPitch": 0,
#                                 "atBats": 0,
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "groundIntoDoublePlay": 0,
#                                 "groundIntoTriplePlay": 0,
#                                 "plateAppearances": 0,
#                                 "totalBases": 0,
#                                 "rbi": 0,
#                                 "leftOnBase": 0,
#                                 "sacBunts": 0,
#                                 "sacFlies": 0,
#                                 "catchersInterference": 0,
#                                 "pickoffs": 0,
#                                 "atBatsPerHomeRun": "-.--",
#                                 "popOuts": 0,
#                                 "lineOuts": 0
#                             },
#                             "pitching": {},
#                             "fielding": {
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "assists": 0,
#                                 "putOuts": 0,
#                                 "errors": 0,
#                                 "chances": 0,
#                                 "fielding": ".000",
#                                 "passedBall": 0,
#                                 "pickoffs": 0
#                             }
#                         },
#                         "seasonStats": {
#                             "batting": {
#                                 "gamesPlayed": 51,
#                                 "flyOuts": 34,
#                                 "groundOuts": 39,
#                                 "airOuts": 57,
#                                 "runs": 32,
#                                 "doubles": 17,
#                                 "triples": 0,
#                                 "homeRuns": 11,
#                                 "strikeOuts": 42,
#                                 "baseOnBalls": 21,
#                                 "intentionalWalks": 1,
#                                 "hits": 58,
#                                 "hitByPitch": 6,
#                                 "avg": ".297",
#                                 "atBats": 195,
#                                 "obp": ".381",
#                                 "slg": ".554",
#                                 "ops": ".935",
#                                 "caughtStealing": 1,
#                                 "stolenBases": 1,
#                                 "stolenBasePercentage": ".500",
#                                 "groundIntoDoublePlay": 3,
#                                 "groundIntoTriplePlay": 0,
#                                 "plateAppearances": 223,
#                                 "totalBases": 108,
#                                 "rbi": 35,
#                                 "leftOnBase": 98,
#                                 "sacBunts": 0,
#                                 "sacFlies": 1,
#                                 "babip": ".329",
#                                 "groundOutsToAirouts": "0.68",
#                                 "catchersInterference": 0,
#                                 "pickoffs": 0,
#                                 "atBatsPerHomeRun": "17.73",
#                                 "popOuts": 15,
#                                 "lineOuts": 8
#                             },
#                             "pitching": {
#                                 "gamesPlayed": 0,
#                                 "gamesStarted": 0,
#                                 "flyOuts": 0,
#                                 "groundOuts": 0,
#                                 "airOuts": 0,
#                                 "runs": 0,
#                                 "doubles": 0,
#                                 "triples": 0,
#                                 "homeRuns": 0,
#                                 "strikeOuts": 0,
#                                 "baseOnBalls": 0,
#                                 "intentionalWalks": 0,
#                                 "hits": 0,
#                                 "hitByPitch": 0,
#                                 "atBats": 0,
#                                 "obp": ".000",
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "numberOfPitches": 0,
#                                 "era": "-.--",
#                                 "inningsPitched": "0.0",
#                                 "wins": 0,
#                                 "losses": 0,
#                                 "saves": 0,
#                                 "saveOpportunities": 0,
#                                 "holds": 0,
#                                 "blownSaves": 0,
#                                 "earnedRuns": 0,
#                                 "whip": "-",
#                                 "battersFaced": 0,
#                                 "outs": 0,
#                                 "gamesPitched": 0,
#                                 "completeGames": 0,
#                                 "shutouts": 0,
#                                 "balls": 0,
#                                 "strikes": 0,
#                                 "strikePercentage": "-.--",
#                                 "hitBatsmen": 0,
#                                 "balks": 0,
#                                 "wildPitches": 0,
#                                 "pickoffs": 0,
#                                 "groundOutsToAirouts": "-.--",
#                                 "rbi": 0,
#                                 "winPercentage": ".---",
#                                 "pitchesPerInning": "-.--",
#                                 "gamesFinished": 0,
#                                 "strikeoutWalkRatio": "-.--",
#                                 "strikeoutsPer9Inn": "-.--",
#                                 "walksPer9Inn": "-.--",
#                                 "hitsPer9Inn": "-.--",
#                                 "runsScoredPer9": "-.--",
#                                 "homeRunsPer9": "-.--",
#                                 "inheritedRunners": 0,
#                                 "inheritedRunnersScored": 0,
#                                 "catchersInterference": 0,
#                                 "sacBunts": 0,
#                                 "sacFlies": 0,
#                                 "passedBall": 0,
#                                 "popOuts": 0,
#                                 "lineOuts": 0
#                             },
#                             "fielding": {
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "assists": 106,
#                                 "putOuts": 35,
#                                 "errors": 5,
#                                 "chances": 146,
#                                 "fielding": ".966",
#                                 "passedBall": 0,
#                                 "pickoffs": 0
#                             }
#                         },
#                         "gameStatus": {
#                             "isCurrentBatter": false,
#                             "isCurrentPitcher": false,
#                             "isOnBench": false,
#                             "isSubstitute": false
#                         },
#                         "allPositions": [
#                             {
#                                 "code": "5",
#                                 "name": "Third Base",
#                                 "type": "Infielder",
#                                 "abbreviation": "3B"
#                             }
#                         ]
#                     },
#                     "type": "hitter",
#                     "gameScore": 42,
#                     "hittingGameScore": 42
#                 }
#             ]
#         },
#         "leaders": {
#             "hitDistance": {},
#             "hitSpeed": {},
#             "pitchSpeed": {}
#         }
#     }
# }

# %%
example_dh_json = """{livedata{boxscore{teams{away{ID683002": {
                            "person": {
                                "id": 683002,
                                "fullName": "Gunnar Henderson",
                                "link": "/api/v1/people/683002"
                            },
                            "jerseyNumber": "2",
                            "position": {
                                "code": "10",
                                "name": "Designated Hitter",
                                "type": "Hitter",
                                "abbreviation": "DH"
"""

# %%
# next go through and get the last games for each of the teams in teams_playing_today.json file
